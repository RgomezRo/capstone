# %% [markdown]
# Posibles preguntas a resolver:
# - De los paises que no están en KIOTO, cuales lo hacen peor y mejor
# - Lo mismo para los que si están en KIOTO.

# %% [markdown]
# #Cuotas de Emisiones GEI

# %% [markdown]
# ##1. Importar el drive y las librerias y descargar el csv

# %% [markdown]
# ###1.1. Importar drive

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %% [markdown]
# ###1.2. Importar librerias

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import folium
import math
plt.style.use("ggplot")
from sklearn import model_selection 
from sklearn import metrics

# time calculation to track some processes
import time

# python core library for machine learning and data science
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.impute import KNNImputer, SimpleImputer
from sklearn.cluster import KMeans

# %% [markdown]
# ### 1.3. Descargar csv

# %%
df_emis_sec = pd.read_csv("/content/drive/MyDrive/Formació/MASTER NUCLIO/Capstone Project/datasets/Environment_Emissions_by_Sector_E_All_Data_(Normalized).zip (Unzipped Files)/Environment_Emissions_by_Sector_E_All_Data_(Normalized).csv", sep=",", index_col=0, encoding='latin-1')
df_alim = pd.read_csv("/content/drive/MyDrive/Formació/MASTER NUCLIO/Capstone Project/datasets/FoodBalanceSheets_E_All_Data_(Normalized)/FoodBalanceSheets_E_All_Data_(Normalized).csv", sep=",", index_col=0, encoding='latin-1')
df_emis_tot = pd.read_csv("/content/drive/MyDrive/Formació/MASTER NUCLIO/Capstone Project/datasets/Emissions_Totals_E_All_Data_(Normalized)/Emissions_Totals_E_All_Data_(Normalized).csv", sep=",", encoding='latin-1')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (13) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
# Descargamos el csv con info de agrupaciones de países.

df_agrup_pais = pd.read_csv("/content/drive/MyDrive/Formació/MASTER NUCLIO/Capstone Project/datasets/Agrupaciones Paises.csv")
df_agrup_pais
# Out:
#       Country Group Code Country Group  Country Code       Country  M49 Code  \
# 0                   5100        Africa             4       Algeria      12.0
# 1                   5100        Africa             7        Angola      24.0
# 2                   5100        Africa            53         Benin     204.0
# 3                   5100        Africa            20      Botswana      72.0
# 4                   5100        Africa           233  Burkina Faso     854.0
# ...                  ...           ...           ...           ...       ...
# 1964                5000         World           246   Yemen Ar Rp     886.0
# 1965                5000         World           247     Yemen Dem     720.0
# 1966                5000         World           248  Yugoslav SFR     890.0
# 1967                5000         World           251        Zambia     894.0
# 1968                5000         World           181      Zimbabwe     716.0
#
#      ISO2 Code ISO3 Code
# 0           DZ       DZA
# 1           AO       AGO
# 2           BJ       BEN
# 3           BW       BWA
# 4           BF       BFA
# ...        ...       ...
# 1964       NaN       NaN
# 1965       NaN       NaN
# 1966       NaN       NaN
# 1967        ZM       ZMB
# 1968        ZW       ZWE
#
# [1969 rows x 7 columns]

# %%
df_agrup_pais["Country Group"].unique()
# Out:
# array(['Africa', 'Americas', 'Annex I countries', 'Antarctic Region',
#        'Asia', 'Australia and New Zealand', 'Caribbean',
#        'Caucasus and Central Asia', 'Central America', 'Central Asia',
#        'Central Asia and Southern Asia', 'East Asia (excluding China)',
#        'Eastern Africa', 'Eastern Asia',
#        'Eastern Asia (excluding Japan and China)',
#        'Eastern Asia (excluding Japan)',
#        'Eastern Asia and South-eastern Asia', 'Eastern Europe', 'Europe',
#        'European Union (27)', 'European Union (28)',
#        'High-income economies', 'Land Locked Developing Countries',
#        'Latin America and the Caribbean', 'Least Developed Countries',
#        'Low income economies', 'Low Income Food Deficit Countries',
#        'Lower-middle-income economies', 'Melanesia', 'Micronesia',
#        'Middle Africa', 'Net Food Importing Developing Countries',
#        'Non-Annex I countries', 'North Africa (excluding Sudan)',
#        'Northern Africa', 'Northern America',
#        'Northern America and Europe', 'Northern Europe', 'Oceania',
#        'Oceania excluding Australia and New Zealand', 'OECD', 'Polynesia',
#        'Small Island Developing States', 'South America',
#        'South Asia (excluding India)', 'South-eastern Asia',
#        'Southern Africa', 'Southern Asia', 'Southern Europe',
#        'Sub-Saharan Africa', 'Sub-Saharan Africa (including Sudan)',
#        'Upper-middle-income economies', 'Western Africa', 'Western Asia',
#        'Western Asia (exc. Armenia, Azerbaijan, Cyprus, Israel and Georgia)',
#        'Western Asia and Northern Africa', 'Western Europe', 'World'],
#       dtype=object)

# %%
df_agrup_pais[df_agrup_pais["Country Group"]=="Annex I countries"].Country.unique()
# Out:
# array(['American Samoa', 'Anguilla', 'Aruba', 'Australia', 'Austria',
#        'Belarus', 'Belgium', 'Belgium-Luxembourg', 'Bermuda',
#        'British Virgin Islands', 'Bulgaria', 'Canada', 'Cayman Islands',
#        'Channel Islands', 'Croatia', 'Cyprus', 'Czechia',
#        'Czechoslovakia', 'Denmark', 'Estonia',
#        'Falkland Islands (Malvinas)', 'Faroe Islands', 'Finland',
#        'France', 'French Guyana', 'French Polynesia', 'Germany',
#        'Gibraltar', 'Greece', 'Greenland', 'Guadeloupe', 'Guam',
#        'Hungary', 'Iceland', 'Ireland', 'Isle of Man', 'Italy', 'Japan',
#        'Latvia', 'Liechtenstein', 'Lithuania', 'Luxembourg', 'Malta',
#        'Martinique', 'Mayotte', 'Monaco', 'Montserrat', 'Netherlands',
#        'Netherlands Antilles (former)', 'New Caledonia', 'New Zealand',
#        'Norfolk Island', 'Northern Mariana Islands', 'Norway', 'Pitcairn',
#        'Poland', 'Portugal', 'Puerto Rico', 'R?union', 'Romania',
#        'Russian Federation',
#        'Saint Helena, Ascension and Tristan da Cunha',
#        'Saint Pierre and Miquelon', 'Slovakia', 'Slovenia', 'Spain',
#        'Svalbard and Jan Mayen Islands', 'Sweden', 'Switzerland',
#        'Tokelau', 'Turkey', 'Turks and Caicos Islands', 'Ukraine',
#        'United Kingdom of Great Britain and Northern Ireland',
#        'United States of America', 'United States Virgin Islands', 'USSR',
#        'Wallis and Futuna Islands'], dtype=object)

# %%
df_agrup_pais_transp = df_agrup_pais.pivot_table(index=["Country Code","Country"],columns="Country Group",values="Country Group Code",aggfunc="count").fillna(0)

# %%
df_agrup_pais_transp.head()
# Out:
# Country Group                Africa  Americas  Annex I countries  \
# Country Code Country
# 1            Armenia            0.0       0.0                0.0
# 2            Afghanistan        0.0       0.0                0.0
# 3            Albania            0.0       0.0                0.0
# 4            Algeria            1.0       0.0                0.0
# 5            American Samoa     0.0       0.0                1.0
#
# Country Group                Antarctic Region  Asia  \
# Country Code Country
# 1            Armenia                      0.0   1.0
# 2            Afghanistan                  0.0   1.0
# 3            Albania                      0.0   0.0
# 4            Algeria                      0.0   0.0
# 5            American Samoa               0.0   0.0
#
# Country Group                Australia and New Zealand  Caribbean  \
# Country Code Country
# 1            Armenia                               0.0        0.0
# 2            Afghanistan                           0.0        0.0
# 3            Albania                               0.0        0.0
# 4            Algeria                               0.0        0.0
# 5            American Samoa                        0.0        0.0
#
# Country Group                Caucasus and Central Asia  Central America  \
# Country Code Country
# 1            Armenia                               1.0              0.0
# 2            Afghanistan                           0.0              0.0
# 3            Albania                               0.0              0.0
# 4            Algeria                               0.0              0.0
# 5            American Samoa                        0.0              0.0
#
# Country Group                Central Asia  ...  Southern Europe  \
# Country Code Country                       ...
# 1            Armenia                  0.0  ...              0.0
# 2            Afghanistan              0.0  ...              0.0
# 3            Albania                  0.0  ...              1.0
# 4            Algeria                  0.0  ...              0.0
# 5            American Samoa           0.0  ...              0.0
#
# Country Group                Sub-Saharan Africa  \
# Country Code Country
# 1            Armenia                        0.0
# 2            Afghanistan                    0.0
# 3            Albania                        0.0
# 4            Algeria                        0.0
# 5            American Samoa                 0.0
#
# Country Group                Sub-Saharan Africa (including Sudan)  \
# Country Code Country
# 1            Armenia                                          0.0
# 2            Afghanistan                                      0.0
# 3            Albania                                          0.0
# 4            Algeria                                          0.0
# 5            American Samoa                                   0.0
#
# Country Group                Upper-middle-income economies  Western Africa  \
# Country Code Country
# 1            Armenia                                   1.0             0.0
# 2            Afghanistan                               0.0             0.0
# 3            Albania                                   1.0             0.0
# 4            Algeria                                   1.0             0.0
# 5            American Samoa                            1.0             0.0
#
# Country Group                Western Asia  \
# Country Code Country
# 1            Armenia                  1.0
# 2            Afghanistan              0.0
# 3            Albania                  0.0
# 4            Algeria                  0.0
# 5            American Samoa           0.0
#
# Country Group                Western Asia (exc. Armenia, Azerbaijan, Cyprus, Israel and Georgia)  \
# Country Code Country
# 1            Armenia                                                       0.0
# 2            Afghanistan                                                   0.0
# 3            Albania                                                       0.0
# 4            Algeria                                                       0.0
# 5            American Samoa                                                0.0
#
# Country Group                Western Asia and Northern Africa  Western Europe  \
# Country Code Country
# 1            Armenia                                      1.0             0.0
# 2            Afghanistan                                  0.0             0.0
# 3            Albania                                      0.0             0.0
# 4            Algeria                                      1.0             0.0
# 5            American Samoa                               0.0             0.0
#
# Country Group                World
# Country Code Country
# 1            Armenia           1.0
# 2            Afghanistan       1.0
# 3            Albania           1.0
# 4            Algeria           1.0
# 5            American Samoa    1.0
#
# [5 rows x 58 columns]

# %%
# Comprobamos si lo ha hecho bien.

df_agrup_pais_transp["Annex I countries"].sum()  == df_agrup_pais[df_agrup_pais["Country Group"]=="Annex I countries"].Country.nunique()
# Out:
# True

# %%
df_paises_Kyoto = df_agrup_pais_transp[["Annex I countries"]]

# %%
df_paises_Kyoto = df_paises_Kyoto.reset_index().rename(columns={"Country Code":"Area Code"})

# %% [markdown]
# Descargamos el dataset que hemos creado a partir de la trade Matrix

# %%
# Descargamos el dataset que hemos creado a partir de la Trade Matrix, con la información de importación y expotación de cada país a cada continente.
df_Imp_Exp_Cont = pd.read_pickle("/content/drive/MyDrive/Formació/MASTER NUCLIO/Capstone Project/datasets/df_Import_Export_Continentes.pkl")

df_Imp_Exp_Cont
# Out:
# Grupo de países  Reporter Country Code Reporter Countries  Year Code  \
# 0                                    2        Afghanistan       2009
# 1                                    2        Afghanistan       2010
# 2                                    2        Afghanistan       2011
# 3                                    2        Afghanistan       2014
# 4                                    2        Afghanistan       2015
# ..                                 ...                ...        ...
# 24                                 181           Zimbabwe       2016
# 25                                 181           Zimbabwe       2017
# 26                                 181           Zimbabwe       2018
# 27                                 181           Zimbabwe       2019
# 28                                 181           Zimbabwe       2020
#
# Grupo de países  Américas       Asia    Europa  Oceanía    África  \
# 0                 42795.0  1249016.0  129430.0    151.0    3324.0
# 1                 89333.0  1117140.0   29063.0    757.0   13314.0
# 2                 63995.0  1150962.0   14128.0    816.0   31800.0
# 3                 65068.0  3345901.0   49020.0    176.0      76.0
# 4                 66864.0  4935864.0   51525.0    222.0      59.0
# ..                    ...        ...       ...      ...       ...
# 24                    2.0       57.0    1025.0      1.0  417711.0
# 25                    3.0      511.0    1000.0      1.0  373519.0
# 26                   62.0     5335.0    2468.0     17.0  447414.0
# 27                  110.0      427.0     375.0      2.0  509272.0
# 28                    4.0       75.0     925.0      0.0  488998.0
#
# Grupo de países          Element
# 0                Import Quantity
# 1                Import Quantity
# 2                Import Quantity
# 3                Import Quantity
# 4                Import Quantity
# ..                           ...
# 24               Export Quantity
# 25               Export Quantity
# 26               Export Quantity
# 27               Export Quantity
# 28               Export Quantity
#
# [8622 rows x 9 columns]

# %% [markdown]
# ## Tabla de Información Macroeconomica

# %%
df_macro = pd.read_csv("/content/drive/MyDrive/Formació/MASTER NUCLIO/Capstone Project/datasets/Macro-Statistics_Key_Indicators_E_All_Data_(Normalized)/Macro-Statistics_Key_Indicators_E_All_Data_(Normalized).csv", sep=",", encoding='latin-1')
df_macro
# Out:
#         Area Code                                     Area  Item Code  \
# 0               2                              Afghanistan      22008
# 1               2                              Afghanistan      22008
# 2               2                              Afghanistan      22008
# 3               2                              Afghanistan      22008
# 4               2                              Afghanistan      22008
# ...           ...                                      ...        ...
# 660656       5817  Net Food Importing Developing Countries      22073
# 660657       5817  Net Food Importing Developing Countries      22073
# 660658       5817  Net Food Importing Developing Countries      22073
# 660659       5817  Net Food Importing Developing Countries      22073
# 660660       5817  Net Food Importing Developing Countries      22073
#
#                               Item  Element Code               Element  \
# 0           Gross Domestic Product          6109  Value Local Currency
# 1           Gross Domestic Product          6109  Value Local Currency
# 2           Gross Domestic Product          6109  Value Local Currency
# 3           Gross Domestic Product          6109  Value Local Currency
# 4           Gross Domestic Product          6109  Value Local Currency
# ...                            ...           ...                   ...
# 660656  Gross Output (Agriculture)          6129     Annual growth US$
# 660657  Gross Output (Agriculture)          6129     Annual growth US$
# 660658  Gross Output (Agriculture)          6129     Annual growth US$
# 660659  Gross Output (Agriculture)          6129     Annual growth US$
# 660660  Gross Output (Agriculture)          6129     Annual growth US$
#
#         Year Code  Year      Unit      Value Flag  Note
# 0            1970  1970  millions  77.911878    X   NaN
# 1            1971  1971  millions  81.574837    X   NaN
# 2            1972  1972  millions  74.152916    X   NaN
# 3            1973  1973  millions  76.619555    X   NaN
# 4            1974  1974  millions  92.774575    X   NaN
# ...           ...   ...       ...        ...  ...   ...
# 660656       2015  2015         %   5.113972   Fc   NaN
# 660657       2016  2016         %   0.938010   Fc   NaN
# 660658       2017  2017         %   7.441454   Fc   NaN
# 660659       2018  2018         %  -4.559164   Fc   NaN
# 660660       2019  2019         % -15.834998   Fc   NaN
#
# [660661 rows x 12 columns]

# %%
df_PIB = df_macro[df_macro["Item Code"] == 22008]
df_PIB
# Out:
#         Area Code                                     Area  Item Code  \
# 0               2                              Afghanistan      22008
# 1               2                              Afghanistan      22008
# 2               2                              Afghanistan      22008
# 3               2                              Afghanistan      22008
# 4               2                              Afghanistan      22008
# ...           ...                                      ...        ...
# 658721       5817  Net Food Importing Developing Countries      22008
# 658722       5817  Net Food Importing Developing Countries      22008
# 658723       5817  Net Food Importing Developing Countries      22008
# 658724       5817  Net Food Importing Developing Countries      22008
# 658725       5817  Net Food Importing Developing Countries      22008
#
#                           Item  Element Code  \
# 0       Gross Domestic Product          6109
# 1       Gross Domestic Product          6109
# 2       Gross Domestic Product          6109
# 3       Gross Domestic Product          6109
# 4       Gross Domestic Product          6109
# ...                        ...           ...
# 658721  Gross Domestic Product         61820
# 658722  Gross Domestic Product         61820
# 658723  Gross Domestic Product         61820
# 658724  Gross Domestic Product         61820
# 658725  Gross Domestic Product         61820
#
#                                           Element  Year Code  Year      Unit  \
# 0                            Value Local Currency       1970  1970  millions
# 1                            Value Local Currency       1971  1971  millions
# 2                            Value Local Currency       1972  1972  millions
# 3                            Value Local Currency       1973  1973  millions
# 4                            Value Local Currency       1974  1974  millions
# ...                                           ...        ...   ...       ...
# 658721  Annual growth US$ per capita, 2015 prices       2015  2015         %
# 658722  Annual growth US$ per capita, 2015 prices       2016  2016         %
# 658723  Annual growth US$ per capita, 2015 prices       2017  2017         %
# 658724  Annual growth US$ per capita, 2015 prices       2018  2018         %
# 658725  Annual growth US$ per capita, 2015 prices       2019  2019         %
#
#             Value Flag  Note
# 0       77.911878    X   NaN
# 1       81.574837    X   NaN
# 2       74.152916    X   NaN
# 3       76.619555    X   NaN
# 4       92.774575    X   NaN
# ...           ...  ...   ...
# 658721   0.502341   Fc   NaN
# 658722  -0.860343   Fc   NaN
# 658723   0.117292   Fc   NaN
# 658724   0.578572   Fc   NaN
# 658725  -0.586085   Fc   NaN
#
# [132562 rows x 12 columns]

# %%
df_PIB.Element.unique()
# Out:
# array(['Value Local Currency', 'Value US$', 'Value US$ per capita',
#        'Value Local Currency, 2015 prices',
#        'Value US$ per capita, 2015 prices', 'Value US$, 2015 prices',
#        'Annual growth Local Currency',
#        'Annual growth Local Currency, 2015 prices', 'Annual growth US$',
#        'Annual growth US$ per capita', 'Annual growth US$, 2015 prices',
#        'Annual growth US$ per capita, 2015 prices'], dtype=object)

# %%
df_PIB_Dol_Cap = df_PIB[df_PIB["Element"] == 'Value US$ per capita']

# %% [markdown]
# ## Tabla de Población

# %%
df_pop = pd.read_csv("/content/drive/MyDrive/Formació/MASTER NUCLIO/Capstone Project/datasets/Population_E_All_Data_(Normalized).zip (Unzipped Files)/Population_E_All_Data_(Normalized).csv", sep=",", encoding='latin-1')

# %% [markdown]
# ###1.4. Visualización del DataFrame

# %%
df_pop.head()
# Out:
#    Area Code         Area  Item Code                       Item  Element Code  \
# 0          2  Afghanistan       3010  Population - Est. & Proj.           511
# 1          2  Afghanistan       3010  Population - Est. & Proj.           511
# 2          2  Afghanistan       3010  Population - Est. & Proj.           511
# 3          2  Afghanistan       3010  Population - Est. & Proj.           511
# 4          2  Afghanistan       3010  Population - Est. & Proj.           511
#
#                          Element  Year Code  Year          Unit     Value  \
# 0  Total Population - Both sexes       1950  1950  1000 persons  7752.118
# 1  Total Population - Both sexes       1951  1951  1000 persons  7840.156
# 2  Total Population - Both sexes       1952  1952  1000 persons  7935.997
# 3  Total Population - Both sexes       1953  1953  1000 persons  8039.694
# 4  Total Population - Both sexes       1954  1954  1000 persons  8151.317
#
#   Flag  Note
# 0    X   NaN
# 1    X   NaN
# 2    X   NaN
# 3    X   NaN
# 4    X   NaN

# %%
df_pop.Item.unique()
# Out:
# array(['Population - Est. & Proj.'], dtype=object)

# %%
df_pop.Element.unique()
# Out:
# array(['Total Population - Both sexes', 'Total Population - Male',
#        'Total Population - Female', 'Rural population',
#        'Urban population'], dtype=object)

# %% [markdown]
# ## Tabla de Emisiones por sector

# %%
df_emis_sec[df_emis_sec.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [Area, Item Code, Item, Element Code, Element, Year Code, Year, Unit, Value, Flag]
# Index: []

# %%
df_emis_sec
# Out:
#                   Area  Item Code                            Item  \
# Area Code
# 2          Afghanistan       6996             Farm-gate emissions
# 2          Afghanistan       6996             Farm-gate emissions
# 2          Afghanistan       6996             Farm-gate emissions
# 2          Afghanistan       6996             Farm-gate emissions
# 2          Afghanistan       6996             Farm-gate emissions
# ...                ...        ...                             ...
# 5873              OECD       6995  Emissions on agricultural land
# 5873              OECD       6995  Emissions on agricultural land
# 5873              OECD       6995  Emissions on agricultural land
# 5873              OECD       6995  Emissions on agricultural land
# 5873              OECD       6995  Emissions on agricultural land
#
#            Element Code                        Element  Year Code  Year  \
# Area Code
# 2                726313  Emissions Share (CO2eq) (AR5)       1990  1990
# 2                726313  Emissions Share (CO2eq) (AR5)       1991  1991
# 2                726313  Emissions Share (CO2eq) (AR5)       1992  1992
# 2                726313  Emissions Share (CO2eq) (AR5)       1993  1993
# 2                726313  Emissions Share (CO2eq) (AR5)       1994  1994
# ...                 ...                            ...        ...   ...
# 5873               7274            Emissions (F-gases)       2015  2015
# 5873               7274            Emissions (F-gases)       2016  2016
# 5873               7274            Emissions (F-gases)       2017  2017
# 5873               7274            Emissions (F-gases)       2018  2018
# 5873               7274            Emissions (F-gases)       2019  2019
#
#                  Unit    Value Flag
# Area Code
# 2                   %  80.2607   Fc
# 2                   %  80.8281   Fc
# 2                   %  86.8858   Fc
# 2                   %  86.1400   Fc
# 2                   %  85.3637   Fc
# ...               ...      ...  ...
# 5873       kilotonnes   0.0000    A
# 5873       kilotonnes   0.0000    A
# 5873       kilotonnes   0.0000    A
# 5873       kilotonnes   0.0000    A
# 5873       kilotonnes   0.0000    A
#
# [1683948 rows x 10 columns]

# %% [markdown]
# ## 2. Data Understanding

# %% [markdown]
# ###2.1. Análisis univariante de datos

# %% [markdown]
# 2.1.1. Distibución de los valores TARGET
#
# La variable TARGET puede hacer referencia a distintos tipos de información. Por el momento dejamos su análisis para más adelante.

# %%
TARGET = "Value"

# %% [markdown]
# 2.1.2. Distribución de las variables independientes

# %% [markdown]
# ###3. Data Preparation

# %% [markdown]
# No hay nulos

# %% [markdown]
# ###4. Visualización cuotas Emisiones GEI

# %% [markdown]
# ###4.1. Gráfico de barras horizontales   - RICARD

# %% [markdown]
# ####Cuotas Emisiones GEI por Áreas

# %%
df_emis_sec["Item"].unique()
# Out:
# array(['Farm-gate emissions', 'Land Use change',
#        'Pre- and post- production', 'Fertilizers Manufacturing',
#        'IPCC Agriculture', 'LULUCF', 'On-farm electricity use',
#        'LULUCF - food systems', 'Energy', 'Food Processing',
#        'Energy - food systems', 'Food Transport', 'IPPU', 'Food Retail',
#        'Food Waste Disposal', 'Waste', 'Waste - food systems',
#        'Food Household Consumption', 'Food Packaging',
#        'All sectors with LULUCF', 'All sectors without LULUCF', 'Other',
#        'Food systems', 'AFOLU', 'Emissions on agricultural land',
#        'IPPU - food systems', 'Food Transport - International Bunkers',
#        'International bunkers', 'International bunkers - food systems'],
#       dtype=object)

# %%
df_emis_sec
# Out:
#                   Area  Item Code                            Item  \
# Area Code
# 2          Afghanistan       6996             Farm-gate emissions
# 2          Afghanistan       6996             Farm-gate emissions
# 2          Afghanistan       6996             Farm-gate emissions
# 2          Afghanistan       6996             Farm-gate emissions
# 2          Afghanistan       6996             Farm-gate emissions
# ...                ...        ...                             ...
# 5873              OECD       6995  Emissions on agricultural land
# 5873              OECD       6995  Emissions on agricultural land
# 5873              OECD       6995  Emissions on agricultural land
# 5873              OECD       6995  Emissions on agricultural land
# 5873              OECD       6995  Emissions on agricultural land
#
#            Element Code                        Element  Year Code  Year  \
# Area Code
# 2                726313  Emissions Share (CO2eq) (AR5)       1990  1990
# 2                726313  Emissions Share (CO2eq) (AR5)       1991  1991
# 2                726313  Emissions Share (CO2eq) (AR5)       1992  1992
# 2                726313  Emissions Share (CO2eq) (AR5)       1993  1993
# 2                726313  Emissions Share (CO2eq) (AR5)       1994  1994
# ...                 ...                            ...        ...   ...
# 5873               7274            Emissions (F-gases)       2015  2015
# 5873               7274            Emissions (F-gases)       2016  2016
# 5873               7274            Emissions (F-gases)       2017  2017
# 5873               7274            Emissions (F-gases)       2018  2018
# 5873               7274            Emissions (F-gases)       2019  2019
#
#                  Unit    Value Flag
# Area Code
# 2                   %  80.2607   Fc
# 2                   %  80.8281   Fc
# 2                   %  86.8858   Fc
# 2                   %  86.1400   Fc
# 2                   %  85.3637   Fc
# ...               ...      ...  ...
# 5873       kilotonnes   0.0000    A
# 5873       kilotonnes   0.0000    A
# 5873       kilotonnes   0.0000    A
# 5873       kilotonnes   0.0000    A
# 5873       kilotonnes   0.0000    A
#
# [1683948 rows x 10 columns]

# %%
df_ultimo_año = df_emis_sec[df_emis_sec["Year"]==max(df_emis_sec["Year"])].reset_index(drop=True)

# %%
df_ultimo_año.head()
# Out:
#           Area  Item Code                 Item  Element Code  \
# 0  Afghanistan       6996  Farm-gate emissions        726313
# 1  Afghanistan       6996  Farm-gate emissions          7264
# 2  Afghanistan       6996  Farm-gate emissions          7265
# 3  Afghanistan       6996  Farm-gate emissions          7266
# 4  Afghanistan       6996  Farm-gate emissions        723113
#
#                          Element  Year Code  Year        Unit       Value Flag
# 0  Emissions Share (CO2eq) (AR5)       2019  2019           %     49.7945   Fc
# 1          Emissions Share (CO2)       2019  2019           %      1.1861   Fc
# 2          Emissions Share (CH4)       2019  2019           %     65.6026   Fc
# 3          Emissions Share (N2O)       2019  2019           %     90.3443   Fc
# 4        Emissions (CO2eq) (AR5)       2019  2019  kilotonnes  16471.2413   Fc

# %%
df_ultimo_año = df_ultimo_año[ (df_ultimo_año["Element"]=="Emissions (CO2eq) (AR5)") &  (df_ultimo_año["Item"]=='All sectors with LULUCF')]
df_ultimo_año_area = df_ultimo_año.groupby("Area")[[TARGET]].sum().reset_index()
df_ultimo_año_area
# Out:
#                Area         Value
# 0       Afghanistan  3.307847e+04
# 1            Africa  4.777883e+06
# 2           Albania  9.346266e+03
# 3           Algeria  2.815507e+05
# 4    American Samoa -4.114590e+01
# ..              ...           ...
# 260  Western Sahara -1.043568e+02
# 261           World  5.399973e+07
# 262           Yemen  3.657652e+04
# 263          Zambia  9.439525e+04
# 264        Zimbabwe  1.175619e+05
#
# [265 rows x 2 columns]

# %%
tabla_orden = df_ultimo_año_area.sort_values(TARGET,ascending=True).tail(20).reset_index(drop=True)
tabla_orden
# Out:
#                                        Area         Value
# 0                       European Union (27)  3.644844e+06
# 1                                     India  3.848732e+06
# 2                       European Union (28)  4.094367e+06
# 3                        South-eastern Asia  4.108186e+06
# 4                                    Africa  4.777883e+06
# 5   Net Food Importing Developing Countries  5.270700e+06
# 6                             Southern Asia  5.809754e+06
# 7                  United States of America  6.229081e+06
# 8                                    Europe  6.756433e+06
# 9                          Northern America  7.076020e+06
# 10        Low Income Food Deficit Countries  7.549987e+06
# 11                                 Americas  1.152551e+07
# 12                          China, mainland  1.281286e+07
# 13                                    China  1.318653e+07
# 14                                     OECD  1.527015e+07
# 15                             Eastern Asia  1.533066e+07
# 16                        Annex I countries  1.622600e+07
# 17                                     Asia  2.879241e+07
# 18                    Non-Annex I countries  3.642739e+07
# 19                                    World  5.399973e+07

# %%
fig = px.bar(tabla_orden, x=TARGET, y="Area", title="Cuotas Emisiones GEI por Área", text=TARGET, orientation="h", width=700, height=700, range_x =[0, max(df_ultimo_año_area[TARGET])+100000000])

fig.update_traces(marker_color="#46cdcf", opacity=0.8, textposition="outside")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="bf923907-fad5-46f1-b55b-3d13c97225da" class="plotly-graph-div" style="height:700px; width:700px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bf923907-fad5-46f1-b55b-3d13c97225da")) {                    Plotly.newPlot(                        "bf923907-fad5-46f1-b55b-3d13c97225da",                        [{"alignmentgroup":"True","hovertemplate":"Value=%{text}<br>Area=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#46cdcf","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"text":[3644844.3827,3848731.5737,4094366.5753,4108185.6714,4777882.5769,5270700.1959,5809754.4545,6229080.6211,6756433.4077,7076020.383,7549987.1402,11525509.6141,12812856.4595,13186532.07,15270149.7961,15330659.9364,16225996.8569,28792408.1047,36427391.7407,53999725.2497],"textposition":"outside","x":[3644844.3827,3848731.5737,4094366.5753,4108185.6714,4777882.5769,5270700.1959,5809754.4545,6229080.6211,6756433.4077,7076020.383,7549987.1402,11525509.6141,12812856.4595,13186532.07,15270149.7961,15330659.9364,16225996.8569,28792408.1047,36427391.7407,53999725.2497],"xaxis":"x","y":["European Union (27)","India","European Union (28)","South-eastern Asia","Africa","Net Food Importing Developing Countries","Southern Asia","United States of America","Europe","Northern America","Low Income Food Deficit Countries","Americas","China, mainland","China","OECD","Eastern Asia","Annex I countries","Asia","Non-Annex I countries","World"],"yaxis":"y","type":"bar","opacity":0.8}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.555555555 ...

# %% [markdown]
# Terminología:
#
# Países No Anexo 1: Paises que no forman parte de l protocolo de Kyoto
#
# Paises Anexo 1: 35 países desarrollados (industrializados) que acordaron limitar sus emisiones de gases que incrementan el efecto invernadero (GEI/GHGs.Protocolo de Kyoto
#
# OECD: organismo de cooperación internacional compuesto por 38 estados, cuyo objetivo es coordinar sus políticas económicas y sociales
#
# Países con bajos ingresos y deficit alimentario: Benin, Burkina Faso, Burundi, Camerún, Chad, Comoras, Congo, Côte d'Ivoire1, Eritrea, Etiopía, Gambia, Ghana1,Guinea, Guinea-Bissau, Kenya, Lesotho, Liberia, Madagascar, Malawi, Malí,Mauritania, Mozambique, Níger, República Centroafricana, República Democrática del Congo, República Unida de Tanzanía, Rwanda, Santo Tomé y Príncipe, Senegal,Sierra Leona, Somalia, Sudán, Sudán del Sur, Togo, Uganda, Zimbabwe, Haití, Nicaragua, Afganistán, Bangladesh, Kirguistán, Nepal, República Popular, Democrática de Corea, República Árabe Siria, Tayikistán, Uzbekistán y Yemen

# %% [markdown]
# Conclusiones:
#
# 1. Los países que no forman parte del tratado de Kyoto emiten mas Gases GEI que los que si forman parte.
# 2. Los continentes que emiten más gases GEI son Asia, America y Europa
# 3. Los países que emiten más gases GEI son China, EEUU y Unión Europea

# %% [markdown]
# ####Cuotas de emisiones GEI por Sector

# %%
df_ultimo_año = df_emis_sec[df_emis_sec["Year"]==max(df_emis_sec["Year"])].reset_index(drop=True)

# %%
df_ultimo_año_producto = df_ultimo_año.groupby("Item")[[TARGET]].sum().reset_index()
df_ultimo_año_producto
# Out:
#                                       Item         Value
# 0                                    AFOLU  5.929608e+07
# 1                  All sectors with LULUCF  5.511669e+08
# 2               All sectors without LULUCF  5.304495e+08
# 3           Emissions on agricultural land  9.556327e+07
# 4                                   Energy  4.250511e+08
# 5                    Energy - food systems  5.335777e+07
# 6                      Farm-gate emissions  5.333568e+07
# 7                Fertilizers Manufacturing  4.513034e+06
# 8               Food Household Consumption  1.524405e+07
# 9                           Food Packaging  3.580216e+06
# 10                         Food Processing  5.995404e+06
# 11                             Food Retail  8.386281e+06
# 12                          Food Transport  6.406230e+06
# 13  Food Transport - International Bunkers  1.069531e+05
# 14                     Food Waste Disposal  8.196959e+06
# 15                            Food systems  1.537951e+08
# 16                        IPCC Agriculture  3.857877e+07
# 17                                    IPPU  4.738155e+07
# 18                     IPPU - food systems  2.833139e+06
# 19                   International bunkers  2.644272e+06
# 20    International bunkers - food systems  1.069531e+05
# 21                                  LULUCF  2.071731e+07
# 22                   LULUCF - food systems  5.072149e+07
# 23                         Land Use change  4.222759e+07
# 24                 On-farm electricity use  5.802682e+06
# 25                                   Other  1.531602e+06
# 26               Pre- and post- production  5.823181e+07
# 27                                   Waste  1.526221e+07
# 28                    Waste - food systems  8.196959e+06

# %%
tabla_orden = df_ultimo_año_producto.sort_values(TARGET,ascending=True).tail(20).reset_index(drop=True)
tabla_orden
# Out:
#                               Item         Value
# 0                   Food Transport  6.406230e+06
# 1              Food Waste Disposal  8.196959e+06
# 2             Waste - food systems  8.196959e+06
# 3                      Food Retail  8.386281e+06
# 4       Food Household Consumption  1.524405e+07
# 5                            Waste  1.526221e+07
# 6                           LULUCF  2.071731e+07
# 7                 IPCC Agriculture  3.857877e+07
# 8                  Land Use change  4.222759e+07
# 9                             IPPU  4.738155e+07
# 10           LULUCF - food systems  5.072149e+07
# 11             Farm-gate emissions  5.333568e+07
# 12           Energy - food systems  5.335777e+07
# 13       Pre- and post- production  5.823181e+07
# 14                           AFOLU  5.929608e+07
# 15  Emissions on agricultural land  9.556327e+07
# 16                    Food systems  1.537951e+08
# 17                          Energy  4.250511e+08
# 18      All sectors without LULUCF  5.304495e+08
# 19         All sectors with LULUCF  5.511669e+08

# %%
fig = px.bar(tabla_orden, x=TARGET, y="Item", title="Cuotas Emisiones GEI por Producto", text=TARGET, orientation="h", width=1000, height=700, range_x =[0, max(df_ultimo_año_producto[TARGET])+10000000])

fig.update_traces(marker_color="#46cdcf", opacity=0.8, textposition="outside")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="f1fa02f9-1e1f-43b7-855c-d794fc85b556" class="plotly-graph-div" style="height:700px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f1fa02f9-1e1f-43b7-855c-d794fc85b556")) {                    Plotly.newPlot(                        "f1fa02f9-1e1f-43b7-855c-d794fc85b556",                        [{"alignmentgroup":"True","hovertemplate":"Value=%{text}<br>Item=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#46cdcf","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"text":[6406229.6769,8196959.2784,8196959.2784,8386281.2721,15244054.3661,15262208.7561,20717309.5698,38578770.5458,42227589.3425,47381551.1321,50721492.4,53335678.0584,53357771.0802,58231813.2032,59296080.6365,95563267.3915,153795080.6023,425051141.887,530449546.5053,551166856.0751],"textposition":"outside","x":[6406229.6769,8196959.2784,8196959.2784,8386281.2721,15244054.3661,15262208.7561,20717309.5698,38578770.5458,42227589.3425,47381551.1321,50721492.4,53335678.0584,53357771.0802,58231813.2032,59296080.6365,95563267.3915,153795080.6023,425051141.887,530449546.5053,551166856.0751],"xaxis":"x","y":["Food Transport","Food Waste Disposal","Waste - food systems","Food Retail","Food Household Consumption","Waste","LULUCF","IPCC Agriculture","Land Use change","IPPU","LULUCF - food systems","Farm-gate emissions","Energy - food systems","Pre- and post- production","AFOLU","Emissions on agricultural land","Food systems","Energy","All sectors without LULUCF","All sectors with LULUCF"],"yaxis":"y","type":"bar","opacity":0.8}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.333333333333333 ...

# %% [markdown]
# Acronimos:
#
# LULUCF: Land Use, Land-Use Change and Forestry (Uso de la Tierra, Cambio de Uso de la Tierra y Silvicultura)
#
# AFOLU: Agriculture, Forestry and Other Land Uses (Agricultura, Silvicultura y Otros Usos de la Tierra)

# %% [markdown]
# Conclusiones:
#
# 1. Las emisiones totales que incluyen el uso de la tierra, cambio de uso y silvicultura son mayores les que las que no las incluyen
# 2. La mayor parte de las emisiones GEI provienen de la energía, los sistemas alimentarios y las emisiones en tierras agrícolas

# %% [markdown]
# ####Cuotas de Emisiones GEI por Elemento

# %%
df_ultimo_año = df_emis_sec[df_emis_sec["Year"]==max(df_emis_sec["Year"])].reset_index(drop=True)

# %%
df_ultimo_año_elemento = df_ultimo_año.groupby("Element")[[TARGET]].sum().reset_index()
df_ultimo_año_elemento
# Out:
#                          Element         Value
# 0                Emissions (CH4)  1.150947e+07
# 1                Emissions (CO2)  8.900890e+08
# 2        Emissions (CO2eq) (AR5)  1.366081e+09
# 3            Emissions (F-gases)  8.072512e+03
# 4                Emissions (N2O)  4.218482e+05
# 5          Emissions Share (CH4)  1.301334e+05
# 6          Emissions Share (CO2)  1.098135e+05
# 7  Emissions Share (CO2eq) (AR5)  1.185640e+05
# 8      Emissions Share (F-gases)  6.979445e+04
# 9          Emissions Share (N2O)  1.435626e+05

# %%
tabla_orden = df_ultimo_año_elemento.sort_values(TARGET,ascending=True).tail(20).reset_index(drop=True)
tabla_orden
# Out:
#                          Element         Value
# 0            Emissions (F-gases)  8.072512e+03
# 1      Emissions Share (F-gases)  6.979445e+04
# 2          Emissions Share (CO2)  1.098135e+05
# 3  Emissions Share (CO2eq) (AR5)  1.185640e+05
# 4          Emissions Share (CH4)  1.301334e+05
# 5          Emissions Share (N2O)  1.435626e+05
# 6                Emissions (N2O)  4.218482e+05
# 7                Emissions (CH4)  1.150947e+07
# 8                Emissions (CO2)  8.900890e+08
# 9        Emissions (CO2eq) (AR5)  1.366081e+09

# %%
fig = px.bar(tabla_orden, x=TARGET, y="Element", title="Cuotas Emisiones GEI por Elemento", text=TARGET, orientation="h", width=700, height=700, range_x =[0, max(df_ultimo_año_area[TARGET])+10000000])

fig.update_traces(marker_color="#46cdcf", opacity=0.8, textposition="outside")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="f2372e09-1860-4655-ba8b-367c88c38339" class="plotly-graph-div" style="height:700px; width:700px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f2372e09-1860-4655-ba8b-367c88c38339")) {                    Plotly.newPlot(                        "f2372e09-1860-4655-ba8b-367c88c38339",                        [{"alignmentgroup":"True","hovertemplate":"Value=%{text}<br>Element=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#46cdcf","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"text":[8072.5121,69794.446,109813.5494,118563.9892,130133.3531,143562.6011,421848.1965,11509470.8088,890088988.7432,1366080648.1827],"textposition":"outside","x":[8072.5121,69794.446,109813.5494,118563.9892,130133.3531,143562.6011,421848.1965,11509470.8088,890088988.7432,1366080648.1827],"xaxis":"x","y":["Emissions (F-gases)","Emissions Share (F-gases)","Emissions Share (CO2)","Emissions Share (CO2eq) (AR5)","Emissions Share (CH4)","Emissions Share (N2O)","Emissions (N2O)","Emissions (CH4)","Emissions (CO2)","Emissions (CO2eq) (AR5)"],"yaxis":"y","type":"bar","opacity":0.8}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8 ...

# %% [markdown]
# Terminología:
#
# CO2eq: El dióxido de carbono equivalente es una medida universal utilizada para indicar en términos de CO2, el equivalente de cada uno de los gases de efecto invernadero con respecto a su potencial de calentamiento global
#
# Co2: está ligado fundamentalmente a la quema de los combustibles fósiles (el carbón, el petróleo y el gas)
#
# CH4: se produce de forma natural por la descomposición de la materia orgánica. Los humedales, el ganado (fermentación entérica) y la energía son las principales fuentes que emiten metano a la atmósfera
#
# Conclusiones:
#
# 1. La emisiones totales de CO2eq a la atmosfera son de 1.366.080.648 mil toneladas
# 2. Los elementos GEI más abundantes son el CO2 y en menor proporción CH4

# %% [markdown]
# ###4.2. Gráfico evolutivo lineal

# %% [markdown]
# ####Evolutivo Cuotas Emisiones GEI por Area

# %%
evolutivo_lineas_Area = df_emis_sec.groupby(["Area","Year"])[TARGET].sum().reset_index().sort_values(TARGET,ascending=False)

evolutivo_lineas_Area
# Out:
#          Area  Year         Value
# 7815    World  2019  3.809741e+08
# 7814    World  2018  3.766757e+08
# 7813    World  2017  3.691497e+08
# 7811    World  2015  3.666066e+08
# 7810    World  2014  3.654270e+08
# ...       ...   ...           ...
# 5894  Romania  2011 -8.926611e+05
# 5895  Romania  2012 -9.157295e+05
# 5896  Romania  2013 -9.577192e+05
# 5897  Romania  2014 -9.592754e+05
# 5898  Romania  2015 -9.599719e+05
#
# [7908 rows x 3 columns]

# %%
px.line(evolutivo_lineas_Area,x="Year",y=TARGET,color="Area",title="Evolutivo Cuotas Emisiones GEI por Área")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="17d7a25c-9ae2-455e-92af-faf139d3b169" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("17d7a25c-9ae2-455e-92af-faf139d3b169")) {                    Plotly.newPlot(                        "17d7a25c-9ae2-455e-92af-faf139d3b169",                        [{"hovertemplate":"Area=World<br>Year=%{x}<br>Value=%{y}<extra></extra>","legendgroup":"World","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"World","showlegend":true,"x":[2019,2018,2017,2015,2014,2016,2013,2012,2011,2010,2009,2008,2007,2006,2005,2004,2003,2002,1997,2000,1999,1998,2001,1996,1995,1994,1993,1991,1992,1990],"xaxis":"x","y":[380974059.3071,376675739.83419997,369149668.4209,366606640.3132,365427008.8834,364876308.3614,357252669.963,354761885.9697,350051226.84929997,349489942.83640003,342275091.6489,340108622.7217,334663011.2626,334384524.80770004,321308307.7286,316620855.7568,301666501.9955,295841131.6272,295308654.282,291161895.6066,286955838.1486,285806874.47650003,285676654.7542,282850824.8976,279937420.9529,274932485.4633,272791538.2826,272286294.3272,271870976.2413,267928280.4663],"yaxis":"y","type":"scattergl"},{"hovertemplate":"Area=Non-Annex I countries<br>Year=%{x}<br>Value=%{y}<extra></extra>","legendgroup":"Non-Annex I countries","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Non-Annex I countries","showlegend":true,"x":[2019,2018,2015,2014,2017,2016,2013,2012,2011,2010,2009,2008,2006,2007,2005,2004,2003,1997,2002,2000,1999,1998,2001,1996,1995,1994,1993,1992,1991,1990],"xaxis":"x","y":[262080954.8642,255468165.2729,252046656.519,250321323.7394,249342985.7615,246342373.46829998,241617837.2805,238621908.2814,232455758.4362,228885463.13549998,225022732.5099,215583288.9872,209023031.9249,208286387.5651,196871367.5149,193054443.4064,179812840.0308,176346458.5837,175805227.8907,168833164.694,166828897.1267,166810213.6361,166026310.09579998,163032819.6519,161723754.9916,157581246.1144,154053556.2316,151687934.8276,147772652.3481,142293368.4755],"yaxis":"y","type":"scattergl"},{"hovertemplate":"Area=Asia<br>Year=%{x}<br>Value=%{y}<extra></extra>","legendgroup":"Asia","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Asia","showlegend":true,"x":[2019,2018,2015,2014,2017,2016,2013,2012,2011,2010,2009,2008,2006,2007,2005,2004,1997,2003,2002,2000,1999,1998,1996,2001,1995,1994,1993,1992,1991,1990],"xaxis":"x","y":[194490363.0635,188434269.3512,185051847.2308,183329667.3157,182439924.5559,179535304.3735,175564830.0867,173108608.877,167522442.3264,155177579.1415,152479888.9916,143271263.8567,138814637.3931,137385194.2263,126868805.1678,124371582.4143,112127990.9835,111797977.9852,109145094.5751,103986258.8294,101632051.10080001,101275442.1337,99724194.1195,99563897.3311,99238960.0709,96047825.1578,92950417.43270001,90647411.6756,86739049.33150001,81581839.3516],"yaxis":"y","type":"scattergl"},{"hovertemplate":"Area=Annex I countries<br>Year=%{x}<br>Value=%{y}<extra></extra>","legendgroup":"Annex I countries","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Annex I countries","showlegend":true,"x":[1990,1991,2007,2006,2005,2004,2008,2000,2003,1992,1996,1999,2002,1993,2001,1997,1998,1995,2010,1994,2018,2017,2016,2019,2009,2011,2012,2013,2014,2015],"xaxis":"x","y":[121547447.0429,120378595.5071,119293833.2222,118593754.81289999,118011289.7328,117433260.7555,117381844.6396,116800051.5238,116227235.1486,115807323.1002,115022777.5642,114764458.60069999,114472209.2944,114415247.4567,114327229.8762,114000530.2971,113877668.2267,113558827.5314,113343261.9152,112853876.7576,112741516.7345,111533521.298,110573581.8 ...

# %%
evolutivo_lineas_Area.sort_values("Year", inplace=True)
px.line(evolutivo_lineas_Area,x="Year",y=TARGET,color="Area",title="Evolutivo Cuotas Emisiones GEI por Área")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="4b84ec4e-9c83-4e4f-8ed4-f669cc102fc2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4b84ec4e-9c83-4e4f-8ed4-f669cc102fc2")) {                    Plotly.newPlot(                        "4b84ec4e-9c83-4e4f-8ed4-f669cc102fc2",                        [{"hovertemplate":"Area=Sierra Leone<br>Year=%{x}<br>Value=%{y}<extra></extra>","legendgroup":"Sierra Leone","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Sierra Leone","showlegend":true,"x":[1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019],"xaxis":"x","y":[82309.9088,82835.5674,81786.6073,80913.7614,81006.4436,78408.9317,72932.415,72737.9931,73239.715,70654.6024,72442.4944,77057.9409,79914.3576,85649.4329,88807.7638,88442.7035,99397.024,93506.8836,87916.6149,90388.0606,88385.0467,92771.3215,100863.2095,100361.3889,104246.6583,104914.789,103254.7529,102157.7374,100798.7267,98195.0803],"yaxis":"y","type":"scattergl"},{"hovertemplate":"Area=Asia<br>Year=%{x}<br>Value=%{y}<extra></extra>","legendgroup":"Asia","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Asia","showlegend":true,"x":[1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019],"xaxis":"x","y":[81581839.3516,86739049.33150001,90647411.6756,92950417.43270001,96047825.1578,99238960.0709,99724194.1195,112127990.9835,101275442.1337,101632051.10080001,103986258.8294,99563897.3311,109145094.5751,111797977.9852,124371582.4143,126868805.1678,138814637.3931,137385194.2263,143271263.8567,152479888.9916,155177579.1415,167522442.3264,173108608.877,175564830.0867,183329667.3157,185051847.2308,179535304.3735,182439924.5559,188434269.3512,194490363.0635],"yaxis":"y","type":"scattergl"},{"hovertemplate":"Area=Venezuela (Bolivarian Republic of)<br>Year=%{x}<br>Value=%{y}<extra></extra>","legendgroup":"Venezuela (Bolivarian Republic of)","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Venezuela (Bolivarian Republic of)","showlegend":true,"x":[1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019],"xaxis":"x","y":[3240516.4904,3210126.9532,3147028.5697,3258411.0425,3295069.8659,3377044.1975000002,3340404.8932,3428769.5368,3712189.3679,3731424.5466,3570720.8923,2897924.9074,2998502.7742,2999785.3235,2756747.2935,2851655.6130999997,2828461.4838,2737200.06,2858698.6955,2858923.2034,2957184.4772,3123675.0982,3344375.1541,3272020.788,3264739.6355,3129375.4153,2138914.9395,1975880.2245,1860885.8222,1792996.1469],"yaxis":"y","type":"scattergl"},{"hovertemplate":"Area=Ireland<br>Year=%{x}<br>Value=%{y}<extra></extra>","legendgroup":"Ireland","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Ireland","showlegend":true,"x":[1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019],"xaxis":"x","y":[422709.0933,424717.60370000004,420404.42470000003,426779.7482,439159.3655,442864.9257,456542.5266,469318.9645,488723.7001,502311.0328,522149.9435,541149.6537,537958.7628,526627.6854,529589.6272,529859.3782,525921.8134,526237.943,514441.6697,494534.3956,486181.7114,454898.2215,464438.5119,462165.945,457585.5518,473821.8684,488998.1324,483917.0555,472012.548,462083.9492],"yaxis":"y","type":"scattergl"},{"hovertemplate":"Area=Land Locked Developing Countries<br>Year=%{x}<br>Value=%{y}<extra></extra>","legendgrou ...

# %% [markdown]
# Conclusiones:
#
# 1. A partir del 2003, la evolución de emisiones GEI, crecen más en los países que no forman parte del tratado de Kyoto y Asia que en el resto de áreas. Este periodo coincide con la entrada en vigor de dicho tratado (2005)
# 2. La crisis Subprime no supuso un cambio importante en las emisiones.

# %%
# Segun el gráfico anterior hay una correlación total entre las emisiones del mundo y Asia.
# Corroboramos en un gráfico que es China la que ha provocado este incremento en los últimos años.
# Visualizaremos en un gráfico los países que más han emitido en los últimos tiempos, junto con Asia. 

#cond_paises = df[["Area"]].drop_duplicates().reset_index()["Area Code"] < 1000  #loc[0:251]
#Area_codes_paises = df[["Area"]].drop_duplicates().reset_index()[cond_paises]["Area Code"].to_list()

# Buscamos los países que más han emitidos en los últimos años.

#df[(df["Area Code"]<1000) & (df["Item Code"]=="6825") & (df["Element Code"] == 723113)]["Area", ""]
df2 = df_emis_sec.reset_index()
df2 = df2[(df2["Area Code"]<1000) & (df2["Item Code"]==6825) & (df2["Element Code"] == 723113)]
ls_paises_mas_cont = df2.groupby("Area")[["Value"]].max().reset_index().sort_values("Value", ascending=False)["Area"].head(10).to_list()
ls_paises_mas_cont

df2_short = df2[df2["Area"].isin(ls_paises_mas_cont)][["Area", "Year", "Value"]]
df2_short
#df2 = df.reset_index()
#df2 = df2[df2[("Area Code"]<1000) | (df2['Area'] == "Asia")]
#evolutivo_lineas_Area = df2_short.groupby(["Area","Year"])[TARGET].sum().reset_index().sort_values(TARGET,ascending=False)
px.line(df2_short,x="Year",y=TARGET,color="Area",title="Evolutivo Cuotas Emisiones GEI por Área")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="18b5f604-2e4d-4281-bd3d-fee5eeab51f0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("18b5f604-2e4d-4281-bd3d-fee5eeab51f0")) {                    Plotly.newPlot(                        "18b5f604-2e4d-4281-bd3d-fee5eeab51f0",                        [{"hovertemplate":"Area=Brazil<br>Year=%{x}<br>Value=%{y}<extra></extra>","legendgroup":"Brazil","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Brazil","orientation":"v","showlegend":true,"x":[1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019],"xaxis":"x","y":[1770761.1707,1793488.9474,1804351.5416,1818652.5344,1843025.6266,1868170.5802,1879693.138,1910028.9962,1948451.1731,1955239.1607,1958545.7079,2047418.729,2078957.0137,2099280.4297,2150040.3011,2166449.8121,2154376.8923,2190148.5484,2194731.6778,2162810.8951,2273549.5616,1436531.7425,1474608.4032,1504506.5333,1548341.2474,1531790.8299,1642499.978,1662502.9124,1632873.7998,1644396.6072],"yaxis":"y","type":"scatter"},{"hovertemplate":"Area=China<br>Year=%{x}<br>Value=%{y}<extra></extra>","legendgroup":"China","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"China","orientation":"v","showlegend":true,"x":[1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019],"xaxis":"x","y":[3692808.9595,3834344.3959,3962672.8899,4160875.497,4410508.8111,4768796.4816,4943800.9475,4964425.1463,4823733.7541,4890305.1901,5035374.7043,5152883.4857,5593912.036,6400509.6266,7246607.7152,8043412.7505,8796282.1956,9351831.1386,9886669.1441,10299513.1722,11121059.2386,11795145.8773,12089955.2716,12387481.4688,12545141.3699,12431491.8522,12345469.4588,12592967.5941,12828436.6196,13186532.07],"yaxis":"y","type":"scatter"},{"hovertemplate":"Area=China, mainland<br>Year=%{x}<br>Value=%{y}<extra></extra>","legendgroup":"China, mainland","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"China, mainland","orientation":"v","showlegend":true,"x":[1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019],"xaxis":"x","y":[3515913.9492,3645094.0586,3760740.7459,3942594.261,4189985.6437,4539334.5231,4706902.2492,4708916.4108,4550802.0385,4604252.6228,4731420.7982,4846668.2197,5272281.7005,6066952.5296,6903621.2338,7694249.7226,8453975.7263,8979995.1114,9529199.0987,9957293.6233,10762167.5759,11427044.1169,11734321.2471,12025091.2765,12174877.4322,12070047.661,11974250.6329,12215005.9029,12450820.5556,12812856.4595],"yaxis":"y","type":"scatter"},{"hovertemplate":"Area=Germany<br>Year=%{x}<br>Value=%{y}<extra></extra>","legendgroup":"Germany","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Germany","orientation":"v","showlegend":true,"x":[1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019],"xaxis":"x","y":[1231631.1482,1147815.4418,1087226.5129,1062450.7013,1052565.3778,1046872.1626,1068840.3404,1034181.1733,1007641.2748,969639.9922,982629.849,1031298.2444,1002273.7161,993761.5461,985360.5356,965758.581,982218.1457,947806.5025,942723.8786,875301.0358,919710.0814,877618.8589,884984.0056,904347.1434,866897.8392,872596.6377,871727.3466,865468.1459,834087.6601,783489.5444],"yaxis":"y","type":"scatter"},{"hovertemplate":"Area=India<br>Year=%{x}<br>Value=%{y}<extra></extra>","legendgroup":"India","line":{"color":"#FFA15A","da ...

# %% [markdown]
# En los últimos 30 años, los paises más contaminantes se han mantenido estable y con una ligera tendencia a la baja, con la excepción de China, que és el que más contamina y el que más ha crecido.... probablemente relacionado con la población y exportaciones? O más con el PIB?

# %% [markdown]
# #Maismo gráfico que antes pero añadiendo el total mundial

# %%
# Buscamos los países que más han emitidos en los últimos años.

#df[(df["Area Code"]<1000) & (df["Item Code"]=="6825") & (df["Element Code"] == 723113)]["Area", ""]
df2 = df_emis_sec.reset_index()
df2 = df2[((df2["Area Code"]<1000)|(df2["Area Code"]==5000) )& (df2["Item Code"]==6825) & (df2["Element Code"] == 723113)]
ls_paises_mas_cont = df2.groupby("Area")[["Value"]].max().reset_index().sort_values("Value", ascending=False)["Area"].head(10).to_list()
ls_paises_mas_cont

df2_short = df2[df2["Area"].isin(ls_paises_mas_cont)][["Area", "Year", "Value"]]
df2_short
#df2 = df.reset_index()
#df2 = df2[df2[("Area Code"]<1000) | (df2['Area'] == "Asia")]
#evolutivo_lineas_Area = df2_short.groupby(["Area","Year"])[TARGET].sum().reset_index().sort_values(TARGET,ascending=False)
px.line(df2_short,x="Year",y=TARGET,color="Area",title="Evolutivo Cuotas Emisiones GEI por Área")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="fe947212-2a7b-455c-9687-261e1587e688" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fe947212-2a7b-455c-9687-261e1587e688")) {                    Plotly.newPlot(                        "fe947212-2a7b-455c-9687-261e1587e688",                        [{"hovertemplate":"Area=Brazil<br>Year=%{x}<br>Value=%{y}<extra></extra>","legendgroup":"Brazil","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Brazil","orientation":"v","showlegend":true,"x":[1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019],"xaxis":"x","y":[1770761.1707,1793488.9474,1804351.5416,1818652.5344,1843025.6266,1868170.5802,1879693.138,1910028.9962,1948451.1731,1955239.1607,1958545.7079,2047418.729,2078957.0137,2099280.4297,2150040.3011,2166449.8121,2154376.8923,2190148.5484,2194731.6778,2162810.8951,2273549.5616,1436531.7425,1474608.4032,1504506.5333,1548341.2474,1531790.8299,1642499.978,1662502.9124,1632873.7998,1644396.6072],"yaxis":"y","type":"scatter"},{"hovertemplate":"Area=China<br>Year=%{x}<br>Value=%{y}<extra></extra>","legendgroup":"China","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"China","orientation":"v","showlegend":true,"x":[1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019],"xaxis":"x","y":[3692808.9595,3834344.3959,3962672.8899,4160875.497,4410508.8111,4768796.4816,4943800.9475,4964425.1463,4823733.7541,4890305.1901,5035374.7043,5152883.4857,5593912.036,6400509.6266,7246607.7152,8043412.7505,8796282.1956,9351831.1386,9886669.1441,10299513.1722,11121059.2386,11795145.8773,12089955.2716,12387481.4688,12545141.3699,12431491.8522,12345469.4588,12592967.5941,12828436.6196,13186532.07],"yaxis":"y","type":"scatter"},{"hovertemplate":"Area=China, mainland<br>Year=%{x}<br>Value=%{y}<extra></extra>","legendgroup":"China, mainland","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"China, mainland","orientation":"v","showlegend":true,"x":[1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019],"xaxis":"x","y":[3515913.9492,3645094.0586,3760740.7459,3942594.261,4189985.6437,4539334.5231,4706902.2492,4708916.4108,4550802.0385,4604252.6228,4731420.7982,4846668.2197,5272281.7005,6066952.5296,6903621.2338,7694249.7226,8453975.7263,8979995.1114,9529199.0987,9957293.6233,10762167.5759,11427044.1169,11734321.2471,12025091.2765,12174877.4322,12070047.661,11974250.6329,12215005.9029,12450820.5556,12812856.4595],"yaxis":"y","type":"scatter"},{"hovertemplate":"Area=India<br>Year=%{x}<br>Value=%{y}<extra></extra>","legendgroup":"India","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"India","orientation":"v","showlegend":true,"x":[1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019],"xaxis":"x","y":[1263256.0678,1320331.7308,1376516.8448,1409620.618,1468491.7203,1532332.3076,1610034.9127,1657707.7167,1694016.9468,1765462.0012,1802314.3885,2041040.1184,2045931.0045,2114754.5982,2214816.6105,2287644.3832,2392019.5986,2525627.6682,2666979.0207,2857308.4814,2890881.3217,2945219.828,3131646.9436,3130882.4842,3345797.332,3458121.3285,3557263.0845,3653314.1328,3812262.449,3848731.5737],"yaxis":"y","type":"scatter"},{"hovertemplate":"Area=Indonesia<br>Year=%{x}<br>Value=%{y}<extra></extra>","legendgroup":"Indonesia","line":{"c ...

# %% [markdown]
# La mitad del augmento es de China. Se tendría que ver el resto como se comportan pero parece que la suma de muchos países, entre ellos India.
# Los más ricos y contaminantes se mantienen estables.

# %% [markdown]
# Preguntas que nos podemos hacer:
# - el crecimiento de China es debido al crecimiento de sus exportaciones, es decir, que en realidad los paises ricos estan contaminando más, indirectamente?
# - I el resto de paises, es también debido a sus exportaciones que no bajan más? De las exportaciones a China, quizás? Sabemos que CHina es uno de los más importadores.

# %% [markdown]
# ####Evolutivo Cuotas Emisiones GEI por Producto

# %%
evolutivo_lineas_Producto = df_emis_sec.groupby(["Item","Year"])["Value"].sum().reset_index().sort_values("Value",ascending=False)

evolutivo_lineas_Producto
# Out:
#                                        Item  Year         Value
# 59                  All sectors with LULUCF  2019  5.511669e+08
# 58                  All sectors with LULUCF  2018  5.473425e+08
# 57                  All sectors with LULUCF  2017  5.365010e+08
# 89               All sectors without LULUCF  2019  5.304495e+08
# 56                  All sectors with LULUCF  2016  5.295816e+08
# ..                                      ...   ...           ...
# 390  Food Transport - International Bunkers  1990  5.624660e+04
# 600    International bunkers - food systems  1990  5.624660e+04
# 542                     IPPU - food systems  1992  3.752685e+04
# 541                     IPPU - food systems  1991  1.042320e+04
# 540                     IPPU - food systems  1990  3.795365e+03
#
# [870 rows x 3 columns]

# %%
# No terminaba de salir bien, pero con un Sort_values ha quedado arreglado
evolutivo_lineas_Producto.sort_values("Year", inplace=True)
px.line(evolutivo_lineas_Producto,x="Year",y="Value",color="Item",title="Evolutivo Cuotas Emisiones GEI por Producto")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="c23fe26e-e495-494e-9077-3a17ac368b5b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c23fe26e-e495-494e-9077-3a17ac368b5b")) {                    Plotly.newPlot(                        "c23fe26e-e495-494e-9077-3a17ac368b5b",                        [{"hovertemplate":"Item=IPPU - food systems<br>Year=%{x}<br>Value=%{y}<extra></extra>","legendgroup":"IPPU - food systems","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"IPPU - food systems","orientation":"v","showlegend":true,"x":[1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019],"xaxis":"x","y":[3795.3645,10423.196899999999,37526.8459,80894.02590000001,158495.1867,269886.5355,404526.1807,571146.6467,763446.0477,974600.5787000001,1210291.1971,1433033.4823,1646663.9642999999,1870062.2122,2090246.94,2334470.2558,2546421.0025,2744019.2699,2774868.8966,2785068.9065,2787424.8764,2782797.4731,2816833.7119,2766590.3098,2766324.4397,2766110.7747,2708621.5754,2750078.2696,2791563.8709,2833139.4632],"yaxis":"y","type":"scatter"},{"hovertemplate":"Item=LULUCF<br>Year=%{x}<br>Value=%{y}<extra></extra>","legendgroup":"LULUCF","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"LULUCF","orientation":"v","showlegend":true,"x":[1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019],"xaxis":"x","y":[21292547.738,21542928.9923,21129687.7701,21076683.6371,21074743.3522,21144164.1827,19245667.4251,27823659.4381,21726165.3141,20207029.8513,19013177.0311,16281856.270499999,20844897.1993,18008887.8141,21264045.6322,18807819.6932,22125976.6217,17326865.9412,17048387.2012,20594817.5896,17487112.0116,5874866.2407,6105611.8204,5758891.3535,8902938.688000001,9292772.816599999,17428168.0392,16976500.2226,18551026.8754,20717309.5698],"yaxis":"y","type":"scatter"},{"hovertemplate":"Item=Energy - food systems<br>Year=%{x}<br>Value=%{y}<extra></extra>","legendgroup":"Energy - food systems","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Energy - food systems","orientation":"v","showlegend":true,"x":[1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019],"xaxis":"x","y":[31058941.6152,32685525.162299998,33876629.4394,33591900.7292,34204786.8106,35936992.8474,37367043.222500004,36805932.2154,36076023.2485,36372238.5366,36406910.691,36872299.148,36801600.2847,37900984.0759,39138557.6304,40873236.8599,41984591.2571,43012574.1515,43718319.7251,43599681.719399996,44741765.9285,45319012.9732,45823886.2909,49078403.3305,49863154.3457,49980801.0562,51505930.0745,52353761.4526,52797767.259,53357771.0802],"yaxis":"y","type":"scatter"},{"hovertemplate":"Item=Food Retail<br>Year=%{x}<br>Value=%{y}<extra></extra>","legendgroup":"Food Retail","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Food Retail","orientation":"v","showlegend":true,"x":[1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019],"xaxis":"x","y":[1633746.3801,1958183.3166,3238710.4472,3347303.149,3879356.5056,3747486.6952,4016274.9541,4051189.8004,4497071.5569,4849178.0529,4858680.0405,4871242.6027,5146404.5171,5523052.4271,5831460.8253,6755447.4003,7073324.4369,7561918.637,7780235.9836,7717726.377,7586177.0631,7517061.21,7614494.5386,7901928.7242,7941704.7139,7981144.1448,8085288.2873,8267574.7282,8239937.15269 ...

# %% [markdown]
# Conclusiones:
#
# 1. A partir del 2002, la evolución de emisiones GEI procedentes de la energía crecen más que en el resto de productos
#
# - Hay algunos que están bastante correlados con el total, como la energía. Es la que más aumenta.

# %% [markdown]
# ####Evolutivo Cuotas Emisiones GEI por Elemento

# %%
evolutivo_lineas_Elemento = df_emis_sec.groupby(["Element","Year"])["Value"].sum().reset_index().sort_values("Value",ascending=False)

evolutivo_lineas_Elemento
# Out:
#                      Element  Year         Value
# 89   Emissions (CO2eq) (AR5)  2019  1.366081e+09
# 88   Emissions (CO2eq) (AR5)  2018  1.352327e+09
# 87   Emissions (CO2eq) (AR5)  2017  1.330534e+09
# 85   Emissions (CO2eq) (AR5)  2015  1.316190e+09
# 86   Emissions (CO2eq) (AR5)  2016  1.314938e+09
# ..                       ...   ...           ...
# 93       Emissions (F-gases)  1993  1.396647e+03
# 92       Emissions (F-gases)  1992  1.281729e+03
# 91       Emissions (F-gases)  1991  1.258933e+03
# 90       Emissions (F-gases)  1990  1.182245e+03
# 181    Emissions Share (CO2)  1991 -1.081330e+05
#
# [300 rows x 3 columns]

# %%
evolutivo_lineas_Elemento = evolutivo_lineas_Elemento.sort_values("Year")
px.line(evolutivo_lineas_Elemento,x="Year",y="Value",color="Element",title="Evolutivo Cuotas Emisiones GEI por Elemento")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="816ce263-45cd-4d09-ad73-4f318d482d32" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("816ce263-45cd-4d09-ad73-4f318d482d32")) {                    Plotly.newPlot(                        "816ce263-45cd-4d09-ad73-4f318d482d32",                        [{"hovertemplate":"Element=Emissions Share (N2O)<br>Year=%{x}<br>Value=%{y}<extra></extra>","legendgroup":"Emissions Share (N2O)","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Emissions Share (N2O)","orientation":"v","showlegend":true,"x":[1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019],"xaxis":"x","y":[134714.5617,134492.4828,146267.8957,147273.2612,146819.9546,146714.4735,146316.3758,146258.7177,146526.2563,146601.764,144329.2535,144608.6245,144611.9424,144160.0847,143928.3937,143625.811,144327.5374,143966.1046,144579.7263,144863.3403,144366.5541,143958.5983,144102.1292,144077.2146,143980.6992,143907.0323,143788.6828,144175.4074,143968.6835,143562.6011],"yaxis":"y","type":"scatter"},{"hovertemplate":"Element=Emissions (CO2eq) (AR5)<br>Year=%{x}<br>Value=%{y}<extra></extra>","legendgroup":"Emissions (CO2eq) (AR5)","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Emissions (CO2eq) (AR5)","orientation":"v","showlegend":true,"x":[1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019],"xaxis":"x","y":[969605398.9648,981419941.3582,984723063.4192001,990384497.3739,998725717.7716,1017391082.8256,1028535545.0054,1064806472.2076,1040116976.2896,1043833060.6281,1055946879.7705,1043816525.9398,1075362388.8203,1097099402.8081,1144313465.4713001,1161269749.1834,1202014125.7745,1206650525.7821,1222692853.5287,1227682476.3367,1253826851.9395,1263623172.1274,1280320483.1817,1287615392.7085,1311629871.425,1316189908.3553,1314938473.549,1330533535.7846,1352326845.1948,1366080648.1827],"yaxis":"y","type":"scatter"},{"hovertemplate":"Element=Emissions Share (CO2)<br>Year=%{x}<br>Value=%{y}<extra></extra>","legendgroup":"Emissions Share (CO2)","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Emissions Share (CO2)","orientation":"v","showlegend":true,"x":[1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019],"xaxis":"x","y":[103042.0858,-108132.97439999996,117052.7435,109792.6098,122189.8048,116131.7171,115701.111,114479.9429,115373.1026,113235.871,112918.0023,111985.163,112835.4416,111152.8446,110966.598,111262.7678,111512.4148,110910.6084,109673.8389,132173.7017,114539.9264,115037.09300000001,111384.1981,114681.6272,103250.9122,111356.1712,109912.0902,109028.1444,108980.9688,109813.5494],"yaxis":"y","type":"scatter"},{"hovertemplate":"Element=Emissions Share (CH4)<br>Year=%{x}<br>Value=%{y}<extra></extra>","legendgroup":"Emissions Share (CH4)","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Emissions Share (CH4)","orientation":"v","showlegend":true,"x":[1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019],"xaxis":"x","y":[128665.1642,130043.7321,140245.866,140658.5828,140374.5975,140431.8948,139219.7518,138820.982,138593.8268,141262.9332,132662.03830000001,132750.3967,132841.3308,132550.2247,131997.0709,131357.6292,131894.6749,131933.0416,131568.2552,131867.8935,131638.4614,130965.1364,131954.7667,131513.7691,131080.5158,130982.6843,130948.90 ...

# %% [markdown]
# # Clustering.

# %% [markdown]
# Haremos merge de quantitat exportada i/o població i/o PIB?
# Añadimos promedio últimos años?

# %% [markdown]
# ## Clustering por emisiones por sector

# %% [markdown]
# Nos fijamos en el año 2019 por ser el 2020 considerado un outlier debido a la pandemia.  Podríamos hacer un promedio de los últimos 5 años.

# %%
AÑO_CLUSTER = 2019
TARGET_ELEMENT = 'Emissions (CO2eq) (AR5)'

# %%
df_emis_sec.columns
# Out:
# Index(['Area', 'Item Code', 'Item', 'Element Code', 'Element', 'Year Code',
#        'Year', 'Unit', 'Value', 'Flag'],
#       dtype='object')

# %%
df_emis_sec = df_emis_sec.reset_index()

# %%
# Seleccionamos el año 2019, el Elemento 'Emissions (CO2eq) (AR5)', y sólo los paises, no agrupaciones.

df_2019_CO2eq = df_emis_sec[(df_emis_sec["Year"]== AÑO_CLUSTER) & (df_emis_sec['Element']==TARGET_ELEMENT) & (df_emis_sec["Area Code"]<1000)]

# %%
# Comprobamos que ha cogido bien el Elemento

df_2019_CO2eq.Element.unique()
# Out:
# array(['Emissions (CO2eq) (AR5)'], dtype=object)

# %%
df_2019_CO2eq.Item.unique()
# Out:
# array(['Farm-gate emissions', 'Land Use change',
#        'Pre- and post- production', 'Fertilizers Manufacturing',
#        'IPCC Agriculture', 'LULUCF', 'On-farm electricity use',
#        'LULUCF - food systems', 'Energy', 'Food Processing',
#        'Energy - food systems', 'Food Transport', 'IPPU', 'Food Retail',
#        'Food Waste Disposal', 'Waste', 'Waste - food systems',
#        'Food Household Consumption', 'Food Packaging',
#        'All sectors with LULUCF', 'All sectors without LULUCF', 'Other',
#        'Food systems', 'AFOLU', 'Emissions on agricultural land',
#        'IPPU - food systems'], dtype=object)

# %%
df_2019_CO2eq["Area Code"].hist()

# %%
df_2019_CO2eq.head()
# Out:
#       Area Code         Area  Item Code                       Item  \
# 149           2  Afghanistan       6996        Farm-gate emissions
# 419           2  Afghanistan       6516            Land Use change
# 689           2  Afghanistan       6517  Pre- and post- production
# 899           2  Afghanistan       6504  Fertilizers Manufacturing
# 1109          2  Afghanistan       1711           IPCC Agriculture
#
#       Element Code                  Element  Year Code  Year        Unit  \
# 149         723113  Emissions (CO2eq) (AR5)       2019  2019  kilotonnes
# 419         723113  Emissions (CO2eq) (AR5)       2019  2019  kilotonnes
# 689         723113  Emissions (CO2eq) (AR5)       2019  2019  kilotonnes
# 899         723113  Emissions (CO2eq) (AR5)       2019  2019  kilotonnes
# 1109        723113  Emissions (CO2eq) (AR5)       2019  2019  kilotonnes
#
#            Value Flag
# 149   16471.2413   Fc
# 419       0.0000   Fc
# 689    4435.8857    A
# 899      23.2331   Fc
# 1109  16342.7221    A

# %%
# Comprobamos nulos

df_2019_CO2eq.isnull().sum()
# Out:
# Area Code       0
# Area            0
# Item Code       0
# Item            0
# Element Code    0
# Element         0
# Year Code       0
# Year            0
# Unit            0
# Value           0
# Flag            0
# dtype: int64

# %%
# Hacemos pivot table para poner los Items como columnas

df_2019_CO2eq_transp = df_2019_CO2eq.pivot_table(index="Area",columns="Item",values="Value",aggfunc="mean")
df_2019_CO2eq_transp.head(1)
# Out:
# Item              AFOLU  All sectors with LULUCF  All sectors without LULUCF  \
# Area
# Afghanistan  16497.3795               33078.4675                  32923.8101
#
# Item         Emissions on agricultural land    Energy  Energy - food systems  \
# Area
# Afghanistan                      16471.2413  10612.83              1061.0057
#
# Item         Farm-gate emissions  Fertilizers Manufacturing  \
# Area
# Afghanistan           16471.2413                    23.2331
#
# Item         Food Household Consumption  Food Packaging  ...     IPPU  \
# Area                                                     ...
# Afghanistan                     486.414         12.1979  ...  308.968
#
# Item         IPPU - food systems    LULUCF  LULUCF - food systems  \
# Area
# Afghanistan                  NaN  154.6574                    0.0
#
# Item         Land Use change  On-farm electricity use  Other  \
# Area
# Afghanistan              0.0                  43.9521  89.04
#
# Item         Pre- and post- production    Waste  Waste - food systems
# Area
# Afghanistan                  4435.8857  5570.25             3503.3924
#
# [1 rows x 26 columns]

# %%
# Miramos nulos

df_2019_CO2eq_transp.isnull().sum()
# Out:
# Item
# AFOLU                               1
# All sectors with LULUCF             1
# All sectors without LULUCF          1
# Emissions on agricultural land      0
# Energy                             28
# Energy - food systems               3
# Farm-gate emissions                 0
# Fertilizers Manufacturing         165
# Food Household Consumption          5
# Food Packaging                     29
# Food Processing                    28
# Food Retail                        11
# Food Transport                     21
# Food Waste Disposal                 4
# Food systems                        0
# IPCC Agriculture                    1
# IPPU                               28
# IPPU - food systems               133
# LULUCF                              1
# LULUCF - food systems               1
# Land Use change                     1
# On-farm electricity use            10
# Other                              32
# Pre- and post- production           2
# Waste                              27
# Waste - food systems                4
# dtype: int64

# %%
# Observamos los nulos (Estamos sólo con los datos del último año)

gb_df_ = df_2019_CO2eq_transp.isnull().T
order_of_columns = list(gb_df_.sum().sort_values().index)
gb_df_ = gb_df_[order_of_columns]

plt.figure(figsize = (20, 10))
plot = sns.heatmap(gb_df_, cbar = True, cmap = "inferno")
plot.set_title("Null sales by item_id and day");

# %%
df_2019_CO2eq_transp["IPPU - food systems"].isnull()
# Out:
# Area
# Afghanistan                   True
# Albania                      False
# Algeria                      False
# American Samoa                True
# Angola                       False
#                              ...
# Wallis and Futuna Islands     True
# Western Sahara                True
# Yemen                         True
# Zambia                       False
# Zimbabwe                      True
# Name: IPPU - food systems, Length: 228, dtype: bool

# %%
# Estos nulos se han creado al generar la pivot_table, que significa que para esos nulos no había ningún registro. Hay algunos Elmentos que deberían de tener información.
# Podríamos llenar los nulos según su parecido con el algortimo KNN, aunque hay algunas variables con tantos nulos que no sé sería la mejor opción.
# En el caso del "IPPU - Food systems" 

df_emis_sec["Value"].isnull().sum()
# Out:
# 0

# %% [markdown]
# La base de dataos iniciano no tenía nulos

# %%
# cuantas filas tenemos?
df_2019_CO2eq_transp.shape
# Out:
# (228, 26)

# %% [markdown]
# Se han creado nulos al hacer la pivot_table. En algunos como "Fertilizers Manufacturing" hay muchos nulos, pero podría ser que no todos los países tengan la capacidad de fabricar fertilizantes. En este caso llenaría con 0's.

# %%
# VAR_TO_DROP = ["Food Transport - International Bunkers","International bunkers","International bunkers - food systems", "IPPU - food systems"]

VAR_TO_DROP = ["IPPU - food systems"]

# %%
df_clust = df_2019_CO2eq_transp.drop(VAR_TO_DROP, axis=1)

# %%
df_clust['Fertilizers Manufacturing'].fillna(0, inplace=True)

# %%
df_clust.isnull().sum()
# Out:
# Item
# AFOLU                              1
# All sectors with LULUCF            1
# All sectors without LULUCF         1
# Emissions on agricultural land     0
# Energy                            28
# Energy - food systems              3
# Farm-gate emissions                0
# Fertilizers Manufacturing          0
# Food Household Consumption         5
# Food Packaging                    29
# Food Processing                   28
# Food Retail                       11
# Food Transport                    21
# Food Waste Disposal                4
# Food systems                       0
# IPCC Agriculture                   1
# IPPU                              28
# LULUCF                             1
# LULUCF - food systems              1
# Land Use change                    1
# On-farm electricity use           10
# Other                             32
# Pre- and post- production          2
# Waste                             27
# Waste - food systems               4
# dtype: int64

# %% [markdown]
# Hay varias variables con el mismo número de nulos. Vemos cuales son.

# %%
def ver_nulos_columna(df,col):
  return df[df[col].isnull()][col]


#df_clust[df_clust['Food Packaging'].isnull()]['Food Packaging']

# %%
ver_nulos_columna(df_clust,'Food Packaging')
# Out:
# Area
# American Samoa                 NaN
# Bermuda                        NaN
# Cayman Islands                 NaN
# Channel Islands                NaN
# Falkland Islands (Malvinas)    NaN
# Faroe Islands                  NaN
# French Guyana                  NaN
# French Polynesia               NaN
# Gibraltar                      NaN
# Greenland                      NaN
# Guadeloupe                     NaN
# Guam                           NaN
# Isle of Man                    NaN
# Madagascar                     NaN
# Martinique                     NaN
# Mayotte                        NaN
# Montserrat                     NaN
# New Caledonia                  NaN
# Norfolk Island                 NaN
# Northern Mariana Islands       NaN
# Pitcairn                       NaN
# Puerto Rico                    NaN
# Republic of Moldova            NaN
# Réunion                        NaN
# Saint Pierre and Miquelon      NaN
# Tokelau                        NaN
# United States Virgin Islands   NaN
# Wallis and Futuna Islands      NaN
# Western Sahara                 NaN
# Name: Food Packaging, dtype: float64

# %% [markdown]
# La mayoría són islas. Vamos a imputar 0's a los nulos que quedan en el dataset.

# %%
ver_nulos_columna(df_clust,'IPPU')
# Out:
# Area
# American Samoa                 NaN
# Bermuda                        NaN
# Cayman Islands                 NaN
# Channel Islands                NaN
# Falkland Islands (Malvinas)    NaN
# Faroe Islands                  NaN
# French Guyana                  NaN
# French Polynesia               NaN
# Gibraltar                      NaN
# Greenland                      NaN
# Guadeloupe                     NaN
# Guam                           NaN
# Isle of Man                    NaN
# Martinique                     NaN
# Mayotte                        NaN
# Montserrat                     NaN
# New Caledonia                  NaN
# Norfolk Island                 NaN
# Northern Mariana Islands       NaN
# Palestine                      NaN
# Pitcairn                       NaN
# Puerto Rico                    NaN
# Réunion                        NaN
# Saint Pierre and Miquelon      NaN
# Tokelau                        NaN
# United States Virgin Islands   NaN
# Wallis and Futuna Islands      NaN
# Western Sahara                 NaN
# Name: IPPU, dtype: float64

# %%
ver_nulos_columna(df_clust,'Energy')
# Out:
# Area
# American Samoa                 NaN
# Bermuda                        NaN
# Cayman Islands                 NaN
# Channel Islands                NaN
# Falkland Islands (Malvinas)    NaN
# Faroe Islands                  NaN
# French Guyana                  NaN
# French Polynesia               NaN
# Gibraltar                      NaN
# Greenland                      NaN
# Guadeloupe                     NaN
# Guam                           NaN
# Isle of Man                    NaN
# Martinique                     NaN
# Mayotte                        NaN
# Montserrat                     NaN
# New Caledonia                  NaN
# Norfolk Island                 NaN
# Northern Mariana Islands       NaN
# Palestine                      NaN
# Pitcairn                       NaN
# Puerto Rico                    NaN
# Réunion                        NaN
# Saint Pierre and Miquelon      NaN
# Tokelau                        NaN
# United States Virgin Islands   NaN
# Wallis and Futuna Islands      NaN
# Western Sahara                 NaN
# Name: Energy, dtype: float64

# %%
ver_nulos_columna(df_clust,'Energy - food systems')
# Out:
# Area
# Norfolk Island   NaN
# Pitcairn         NaN
# Tokelau          NaN
# Name: Energy - food systems, dtype: float64

# %% [markdown]
# Se repiten los mismos paiese, que són básicamente islas. Lo imputaremos por KNN.
#
# Antes, los guardamos en una lista, para ver qué valores se les imputan.

# %%
indices_nulls = ver_nulos_columna(df_clust,'Energy').index

# %% [markdown]
# Declaramos algunas funciones que crean transformers por si creamos un pipeline

# %%
class ArrayToDataFrame(BaseEstimator, TransformerMixin):
    '''
    Clase que transforma un array en un DataFrame.
    Necesita como parámetros el nombre de las columnas y el índice.
    '''
    
    def __init__(self, columns, index = None):
        self.columns = columns
        self.index = index
        
    def fit(self, X, y = None):
        return self
    
    def transform(self, X, y = None):
        
        if self.index != None:
            df = pd.DataFrame(X, columns = self.columns, index = self.index)
            
        else:
            df = pd.DataFrame(X, columns = self.columns)
            
        return df

# %%
imputer = KNNImputer()

# %%
imputer.fit(df_clust)
# Out:
# KNNImputer()

# %%
df_clust_imputed = pd.DataFrame(imputer.transform(df_clust), columns = df_clust.columns, index = df_clust.index)

# %% [markdown]
# Comprobamos los nulos que ha puesto.

# %%
df_clust_imputed.loc[indices_nulls]['Energy']
# Out:
# Area
# American Samoa                    41.93084
# Bermuda                           41.93084
# Cayman Islands                    41.06178
# Channel Islands                  101.91800
# Falkland Islands (Malvinas)      432.02606
# Faroe Islands                    169.16942
# French Guyana                    715.85990
# French Polynesia                 112.67894
# Gibraltar                         41.93084
# Greenland                         41.06178
# Guadeloupe                       238.03470
# Guam                              41.93084
# Isle of Man                       41.93084
# Martinique                        96.37038
# Mayotte                           41.93084
# Montserrat                        41.93084
# New Caledonia                    248.02138
# Norfolk Island                    41.93084
# Northern Mariana Islands         254.00064
# Palestine                        368.83212
# Pitcairn                          41.93084
# Puerto Rico                     1260.69568
# Réunion                          286.67668
# Saint Pierre and Miquelon         41.93084
# Tokelau                           41.93084
# United States Virgin Islands      41.93084
# Wallis and Futuna Islands         41.93084
# Western Sahara                    41.93084
# Name: Energy, dtype: float64

# %% [markdown]
# Vempos que ha tratado de diferente manera a Puetro Rico y otros países, y ha puesto el mismo valor en países muy pequeños. Seguramente si tuvieramos la variable de población o producción de alimentos, se verían incluso mejores resultados.

# %%
df_clust_imputed.loc[indices_nulls]['Food Packaging']
# Out:
# Area
# American Samoa                  0.02242
# Bermuda                         0.02242
# Cayman Islands                  0.02454
# Channel Islands                 0.07788
# Falkland Islands (Malvinas)     0.21808
# Faroe Islands                   0.09738
# French Guyana                   0.23064
# French Polynesia                0.06618
# Gibraltar                       0.02242
# Greenland                       0.02454
# Guadeloupe                      0.11262
# Guam                            0.02242
# Isle of Man                     0.02242
# Martinique                      0.04342
# Mayotte                         0.02242
# Montserrat                      0.02242
# New Caledonia                   0.14762
# Norfolk Island                  0.02242
# Northern Mariana Islands        0.14632
# Palestine                       0.32510
# Pitcairn                        0.02242
# Puerto Rico                     0.81664
# Réunion                         0.13228
# Saint Pierre and Miquelon       0.02242
# Tokelau                         0.02242
# United States Virgin Islands    0.02242
# Wallis and Futuna Islands       0.02242
# Western Sahara                  0.02242
# Name: Food Packaging, dtype: float64

# %% [markdown]
# Empezamos con la clusterizacion

# %%
df_final = df_clust.copy(deep = True)
columns = list(df_final.columns)
index = list(df_final.index)
cols_to_filter = list(df_clust.columns)

# %% [markdown]
# Creamos transformer para eliminar outliers

# %%
## Hay que indicar la lista de variables a clipear.

class OutlierFilter(BaseEstimator, TransformerMixin):
    '''
    Clase que filtra los outliers utilizando np.quantile()
    Los cuantiles a filtrar así como las columnas a filtrar son los parámetros de la clase.
    '''
    
    def __init__(self, q, col_to_filter):
        self.q = q
        self.col_to_filter = col_to_filter
        
    def fit(self, X, y = None):
        return self
    
    def transform(self, X, y = None):
        '''
        El método considera outlier a aquel cliente que es outlier en todas las columnas que le pasas.
        Es decir: si tiene que filtrar importe y número de pedidos, sólo va a eliminar aquellos clientes
        que son outlier tanto en importe como número de pedidos. Si eres outlier en importe pero no en pedido
        no se te va a filtrar del dataset.
        '''
        
        # lista vacía
        criteria_list = []
        
        # agregamos a la lista los clientes que son outliers
        for col in self.col_to_filter:
            criteria = X[col] < np.quantile(X[col], q = self.q)
            criteria_list.append(criteria)
            
        # si hay más de 1 columna
        if len(self.col_to_filter) > 1:
            
            # creamos el criterio global: es decir outlier en todas las columnas
            global_criteria = criteria_list[0]
            
            for criteria in criteria_list[1:]:
                global_criteria = global_criteria & criteria
                
        else:
            global_criteria = criteria_list[0]
            
        # filtramos nuestra dataframe
        X = X[global_criteria]
        
        # guardamos el índice como parámetro de la clase porque en caso contrario lo perderíamos.
        self.index = X.index
        
        return X

# %%
# Visualicamos los outliers

for col in df_clust.columns:
  plt.figure()
  df_clust[col].hist()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: RuntimeWarning:
#
# More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).

# %%
# separamos el pipeline del a loop, para no tener que volver a hacer los primeros 5 pasos para cada k de la loop
pipe = Pipeline(steps = [
    ("Imputer", KNNImputer()),
    ("ArrayToDataFrame", ArrayToDataFrame(columns, index = index)),
#    ("FeatureGenerator", FeatureGenerator()),
    ("OutlierFilter", OutlierFilter(q = 0.99, col_to_filter = cols_to_filter)),
    ("StandardScaler", StandardScaler())
])

# %%
df_scaled_transformed_no_outliers = pipe.fit_transform(df_final)

# %%
CALCULATE_ELBOW = True

if CALCULATE_ELBOW:
    st = time.time()

    sse = {}

    for k in range(2, 15):

        print(f"Fitting pipe with {k} clusters")

        clustering_model = KMeans(n_clusters = k)

        clustering_model.fit(df_scaled_transformed_no_outliers)

        sse[k] = clustering_model.inertia_

    et = time.time()
    print("Elbow curve took {} minutes.".format(round((et - st)/60), 2))
# Out:
# Fitting pipe with 2 clusters
# Fitting pipe with 3 clusters
# Fitting pipe with 4 clusters
# Fitting pipe with 5 clusters
# Fitting pipe with 6 clusters
# Fitting pipe with 7 clusters
# Fitting pipe with 8 clusters
# Fitting pipe with 9 clusters
# Fitting pipe with 10 clusters
# Fitting pipe with 11 clusters
# Fitting pipe with 12 clusters
# Fitting pipe with 13 clusters
# Fitting pipe with 14 clusters
# Elbow curve took 0 minutes.

# %%
if CALCULATE_ELBOW:
    fig = plt.figure(figsize = (16, 8))
    ax = fig.add_subplot()

    x_values = list(sse.keys())
    y_values = list(sse.values())

    ax.plot(x_values, y_values, label = "Inertia/dispersión de los clústers")
    fig.suptitle("Variación de la dispersión de los clústers en función de la k", fontsize = 16);

# %% [markdown]
# Parece que el número idoneo de clusers podría ser 6.

# %%
# Creamos de nuevo el pipeline usando 6 clusters

pipe = Pipeline(steps = [
    ("Imputer", KNNImputer()),
    ("ArrayToDataFrame", ArrayToDataFrame(columns, index = index)),
#    ("FeatureGenerator", FeatureGenerator()),
    ("OutlierFilter", OutlierFilter(q = 0.99, col_to_filter = cols_to_filter)),
    ("StandardScaler", StandardScaler()),
    ("Clustering", KMeans(n_clusters = 6))
])

# %%
df_final.shape
# Out:
# (228, 25)

# %%
pipe.fit(df_final)
# Out:
# Pipeline(steps=[('Imputer', KNNImputer()),
#                 ('ArrayToDataFrame',
#                  ArrayToDataFrame(columns=['AFOLU', 'All sectors with LULUCF',
#                                            'All sectors without LULUCF',
#                                            'Emissions on agricultural land',
#                                            'Energy', 'Energy - food systems',
#                                            'Farm-gate emissions',
#                                            'Fertilizers Manufacturing',
#                                            'Food Household Consumption',
#                                            'Food Packaging', 'Food Processing',
#                                            'Food Retail', 'Food Transport',
#                                            'Food Wast...
#                                               'Food Household Consumption',
#                                               'Food Packaging',
#                                               'Food Processing', 'Food Retail',
#                                               'Food Transport',
#                                               'Food Waste Disposal',
#                                               'Food systems',
#                                               'IPCC Agriculture', 'IPPU',
#                                               'LULUCF', 'LULUCF - food systems',
#                                               'Land Use change',
#                                               'On-farm electricity use',
#                                               'Other',
#                                               'Pre- and post- production',
#                                               'Waste', 'Waste - food systems'],
#                                q=0.99)),
#                 ('StandardScaler', StandardScaler()),
#                 ('Clustering', KMeans(n_clusters=6))])

# %%
# creamos un dataframe escalado con los pasos 1, 3 y 5
X_processed = pipe[:2].transform(df_final)
X_scaled = pipe["StandardScaler"].transform(X_processed)

X_scaled.shape
# Out:
# (228, 25)

# %%
# hacemos el predict, en este caso tendremos para cada cliente su centroide/clúster.
print(pipe["Clustering"].predict(X_scaled)[:20])
labels = pipe["Clustering"].predict(X_scaled)
# Out:
# [3 3 0 3 1 3 3 1 3 3 2 3 3 3 3 1 3 0 0 3]

# %%
# cuantos hay de cada grupo

plt.hist(labels)
# Out:
# (array([ 17.,   0.,  17.,   0.,  13.,   0., 167.,   0.,   5.,   9.]),
#  array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ]),
#  <a list of 10 Patch objects>)

# %%
# le asignamos al DataFrame procesado los centroides. (antes del escalado de variable)
# SI LO HACEMOS AL ESCALADO LOS NÚMEROS PERDERAN SU SIGNIFICADO ESCALA Y SERÁN MÁS DÍFICILES DE INTERPRETAR.
X_processed["cluster"] = labels

# %%
X_processed.shape
# Out:
# (228, 26)

# %%
# visualizamos nuestros grupos en base a las variables del modelo RFM, para ver que tal han quedado.
selected_columns = ['Farm-gate emissions', 'All sectors with LULUCF', 'Food Processing']

sns.pairplot(X_processed, vars = selected_columns, hue = 'cluster');

# %% [markdown]
# Añadimos más variables, de producción y Exportación e Importación. TAmbién población y quizás PIB. Lo podemos hacer con transformers.
#
# Variacion de emisiones desde tratado de Kioto. Quizás un la tendencia de antes y después de Kioto?   Ahora sólo hemos cogido las emisiones del último año.

# %% [markdown]
# ## Clustering por emisiones por sector **per cápita**

# %% [markdown]
# ### Añadimos la población al dataset de emisiones

# %%
print(df_clust.shape)
# Out:
# (228, 25)

# %%
df_pop.Element.unique()
# Out:
# array(['Total Population - Both sexes', 'Total Population - Male',
#        'Total Population - Female', 'Rural population',
#        'Urban population'], dtype=object)

# %%
# Hay agrupaciones de paises? Si

df_pop["Area Code"].hist()

# %%
df_pop_both_2019 = df_pop[(df_pop.Element == 'Total Population - Both sexes') & (df_pop.Year == 2019) & (df_pop["Area Code"] < 1000)]
print(df_pop_both_2019.shape)
# Out:
# (237, 12)

# %%
df_pop_both_2019.columns
# Out:
# Index(['Area Code', 'Area', 'Item Code', 'Item', 'Element Code', 'Element',
#        'Year Code', 'Year', 'Unit', 'Value', 'Flag', 'Note'],
#       dtype='object')

# %%
df_pop_both_2019.head()
# Out:
#       Area Code            Area  Item Code                       Item  \
# 69            2     Afghanistan       3010  Population - Est. & Proj.
# 724           3         Albania       3010  Population - Est. & Proj.
# 1379          4         Algeria       3010  Population - Est. & Proj.
# 2034          5  American Samoa       3010  Population - Est. & Proj.
# 2387          6         Andorra       3010  Population - Est. & Proj.
#
#       Element Code                        Element  Year Code  Year  \
# 69             511  Total Population - Both sexes       2019  2019
# 724            511  Total Population - Both sexes       2019  2019
# 1379           511  Total Population - Both sexes       2019  2019
# 2034           511  Total Population - Both sexes       2019  2019
# 2387           511  Total Population - Both sexes       2019  2019
#
#               Unit      Value Flag  Note
# 69    1000 persons  38041.754    X   NaN
# 724   1000 persons   2880.917    X   NaN
# 1379  1000 persons  43053.054    X   NaN
# 2034  1000 persons     55.312    X   NaN
# 2387  1000 persons     77.142    X   NaN

# %%
#plt.plot(df_pop_both_2019["Area"], df_pop_both_2019["Value"])
#fig = px.bar(tabla_orden, x=TARGET, y="Area", title="Cuotas Emisiones GEI por Área", text=TARGET, orientation="h", width=700, height=700, range_x =[0, max(df_ultimo_año_area[TARGET])+100000000])

#fig.update_traces(marker_color="#46cdcf", opacity=0.8, textposition="outside")

#plt.bar(x=df_pop_both_2019["pxArea"].values, height=df_pop_both_2019["Value"].values)

# %%
# Hacemos pivot table

df_pop_both_2019_pivot = df_pop_both_2019.pivot_table(index="Area",columns="Element",values="Value",aggfunc="mean")

# %%
df_pop_both_2019_pivot.head()
# Out:
# Element         Total Population - Both sexes
# Area
# Afghanistan                         38041.754
# Albania                              2880.917
# Algeria                             43053.054
# American Samoa                         55.312
# Andorra                                77.142

# %%
# En la tabla de poblacion hay más Areas que en la de Emisiones. Haremos un merge left de la tabla de emisiones, para que no falte ningun Area
print(df_clust.shape)
df_emis_pop_2019 = pd.merge(df_clust, df_pop_both_2019_pivot, on = "Area", how="left")
print(df_emis_pop_2019.shape)
# Out:
# (228, 25)
# (228, 26)

# %%
# Comprobamos si hay alguna fila que no se le ha podido asignar población.

df_emis_pop_2019[df_emis_pop_2019["Total Population - Both sexes"].isnull()]
# Out:
#                  AFOLU  All sectors with LULUCF  All sectors without LULUCF  \
# Area
# Norfolk Island  0.1275                   0.1275                         0.0
# Pitcairn        0.0000                   0.0000                         0.0
#
#                 Emissions on agricultural land  Energy  Energy - food systems  \
# Area
# Norfolk Island                             0.0     NaN                    NaN
# Pitcairn                                   0.0     NaN                    NaN
#
#                 Farm-gate emissions  Fertilizers Manufacturing  \
# Area
# Norfolk Island                  0.0                        0.0
# Pitcairn                        0.0                        0.0
#
#                 Food Household Consumption  Food Packaging  ...  IPPU  LULUCF  \
# Area                                                        ...
# Norfolk Island                         NaN             NaN  ...   NaN  0.1275
# Pitcairn                               NaN             NaN  ...   NaN  0.0000
#
#                 LULUCF - food systems  Land Use change  \
# Area
# Norfolk Island                    0.0              0.0
# Pitcairn                          0.0              0.0
#
#                 On-farm electricity use  Other  Pre- and post- production  \
# Area
# Norfolk Island                      NaN    NaN                        NaN
# Pitcairn                            NaN    NaN                        NaN
#
#                 Waste  Waste - food systems  Total Population - Both sexes
# Area
# Norfolk Island    NaN                   NaN                            NaN
# Pitcairn          NaN                   NaN                            NaN
#
# [2 rows x 26 columns]

# %%
 ## Estos dos países se podrían eliminar porque está prácticamente todos sus variables a 0 o Nulos!

# %%
df_emis_pop_2019 = df_emis_pop_2019.drop(index=["Pitcairn", "Norfolk Island"])

# %%
df_emis_pop_2019.shape
# Out:
# (226, 26)

# %%
df_emis_pop_2019.columns
# Out:
# Index(['AFOLU', 'All sectors with LULUCF', 'All sectors without LULUCF',
#        'Emissions on agricultural land', 'Energy', 'Energy - food systems',
#        'Farm-gate emissions', 'Fertilizers Manufacturing',
#        'Food Household Consumption', 'Food Packaging', 'Food Processing',
#        'Food Retail', 'Food Transport', 'Food Waste Disposal', 'Food systems',
#        'IPCC Agriculture', 'IPPU', 'LULUCF', 'LULUCF - food systems',
#        'Land Use change', 'On-farm electricity use', 'Other',
#        'Pre- and post- production', 'Waste', 'Waste - food systems',
#        'Total Population - Both sexes'],
#       dtype='object')

# %% [markdown]
# Comprobamos la correlación entre ellos y eliminaremos columnas que sean combinaciones lineales de las demás.

# %%
corr = df_emis_pop_2019.corr()
corr.style.background_gradient(cmap="coolwarm")
# Out:
# <style type="text/css">
# #T_676ea_row0_col0, #T_676ea_row1_col1, #T_676ea_row1_col2, #T_676ea_row1_col4, #T_676ea_row2_col1, #T_676ea_row2_col2, #T_676ea_row2_col4, #T_676ea_row3_col3, #T_676ea_row4_col1, #T_676ea_row4_col2, #T_676ea_row4_col4, #T_676ea_row5_col5, #T_676ea_row6_col6, #T_676ea_row7_col7, #T_676ea_row8_col8, #T_676ea_row9_col9, #T_676ea_row10_col10, #T_676ea_row11_col11, #T_676ea_row12_col12, #T_676ea_row13_col13, #T_676ea_row13_col24, #T_676ea_row14_col14, #T_676ea_row15_col15, #T_676ea_row16_col16, #T_676ea_row17_col17, #T_676ea_row18_col18, #T_676ea_row19_col19, #T_676ea_row20_col20, #T_676ea_row21_col21, #T_676ea_row22_col22, #T_676ea_row23_col23, #T_676ea_row24_col13, #T_676ea_row24_col24, #T_676ea_row25_col25 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_676ea_row0_col1, #T_676ea_row13_col11, #T_676ea_row24_col11 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_676ea_row0_col2, #T_676ea_row11_col25, #T_676ea_row13_col0, #T_676ea_row19_col13, #T_676ea_row19_col24, #T_676ea_row24_col0 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_676ea_row0_col3, #T_676ea_row3_col5, #T_676ea_row3_col12, #T_676ea_row3_col19, #T_676ea_row16_col20, #T_676ea_row20_col14 {
#   background-color: #f39577;
#   color: #000000;
# }
# #T_676ea_row0_col4, #T_676ea_row16_col10, #T_676ea_row18_col22, #T_676ea_row19_col1 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_676ea_row0_col5, #T_676ea_row13_col10, #T_676ea_row19_col23, #T_676ea_row20_col3, #T_676ea_row24_col10 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_676ea_row0_col6, #T_676ea_row11_col5 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_676ea_row0_col7, #T_676ea_row7_col10, #T_676ea_row19_col5 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_676ea_row0_col8, #T_676ea_row16_col3, #T_676ea_row18_col12, #T_676ea_row21_col10 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_676ea_row0_col9, #T_676ea_row18_col8 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_676ea_row0_col10 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_676ea_row0_col11 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_676ea_row0_col12, #T_676ea_row7_col11, #T_676ea_row11_col14 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_676ea_row0_col13, #T_676ea_row0_col24 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_676ea_row0_col14 {
#   background-color: #f5c4ac;
#   color: #000000;
# }
# #T_676ea_row0_col15, #T_676ea_row25_col3 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_676ea_row0_col16, #T_676ea_row11_col20 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_676ea_row0_col17, #T_676ea_row3_col23, #T_676ea_row7_col6, #T_676ea_row15_col9, #T_676ea_row25_col12 {
#   background-color: #ec7f63;
#   color: #f1f1f1;
# }
# #T_676ea_row0_col18, #T_676ea_row5_col20 {
#   background-color: #e36c55;
#   color: #f1f1f1;
# }
# #T_676ea_row0_col19, #T_676ea_row4_col6, #T_676ea_row12_col15, #T_676ea_row14_col9, #T_676ea_row15_col16 {
#   background-color: #e57058;
#   color: #f1f1f1;
# }
# #T_676ea_row0_col20, #T_676ea_row10_col13, #T_676ea_row10_col24, #T_676ea_row15_col11 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_676ea_row0_col21, #T_676ea_row10_col25, #T_676ea_row11_col15 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_676ea_row0_col22 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_676ea_row0_col23, #T_676ea_row10_col6 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_676ea_row0_col25, #T_676ea_row5_col3, #T_676ea_row14_col18 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_676ea_row1_col0, #T_676ea_row22_col0 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_676ea_row1_col3 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_676ea_row1_col5, #T_676ea_row1_col21, #T_676ea_row2_col21, #T_676ea_row2_col22, #T_676ea_row5_col1, #T_676ea_row7_col16, #T_676ea_row8_col21, #T_676ea_row9_col16, #T_676ea_row16_col1, #T_676ea_row16_col7, #T_676ea_row16_col9, #T_676ea_row21_col1, #T_676ea_row21_col2, #T_676ea_row21_col8, #T_676ea_row22_col2 {
#   background-color: #b8122a;
#   color: #f1f1f1;
# }
# #T_676ea_row1_col6, #T_676ea_row6_col4, #T_676ea_row20_col13, #T_676ea_row20_col24 {
#   background-color: #dc5d4a;
#   color: #f1f1f1;
# }
# #T_676ea_row1_col7, #T_676ea_row1_col8, #T_676ea_row2_col23, #T_676ea_row4_col8, #T_676ea_row5_col7, #T_676ea_row5_col8, #T_676ea_row5_col16, #T_676ea_row5_col23, #T_676ea_row7_col1, #T_676ea_row7_col5, #T_676ea_row7_col8, #T_676ea_row8_col1, #T_676ea_row8_col4, #T_676ea_row8_col5, #T_676ea_row8_col7, #T_676ea_row13_col25, #T_676ea_row16_col5, #T_676ea_row21_col22, #T_676ea_row22_col21, #T_676ea_row23_col2, #T_676ea_row23_col5, #T_676ea_row23_col13, #T_676ea_row23_col24, #T_676ea_row24_col25 {
#   background-color: #bb1b2c;
#   color: #f1f1f1;
# }
# #T_676ea_row1_col9, #T_676ea_row4_col23, #T_676ea_row7_col9, #T_676ea_row7_col21, #T_676ea_row8_col23, #T_676ea_row9_col2, #T_676ea_row9_col7, #T_676ea_row21_col7, #T_676ea_row21_col25, #T_676ea_row22_col23 {
#   background-color: #be242e;
#   color: #f1f1f1;
# }
# #T_676ea_row1_col10, #T_676ea_row10_col14, #T_676ea_row15_col10 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_676ea_row1_col11 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_676ea_row1_col12, #T_676ea_row5_col6, #T_676ea_row6_col8, #T_676ea_row9_col13, #T_676ea_row9_col24, #T_676ea_row14_col8, #T_676ea_row20_col15, #T_676ea_row20_col22, #T_676ea_row21_col14 {
#   background-color: #de614d;
#   color: #f1f1f1;
# }
# #T_676ea_row1_col13, #T_676ea_row1_col24, #T_676ea_row5_col13, #T_676ea_row5_col24, #T_676ea_row5_col25, #T_676ea_row8_col25, #T_676ea_row13_col2, #T_676ea_row13_col14, #T_676ea_row14_col15, #T_676ea_row22_col25, #T_676ea_row23_col9, #T_676ea_row24_col2, #T_676ea_row24_col14 {
#   background-color: #c73635;
#   color: #f1f1f1;
# }
# #T_676ea_row1_col14, #T_676ea_row13_col9, #T_676ea_row14_col4, #T_676ea_row21_col15, #T_676ea_row24_col9 {
#   background-color: #d85646;
#   color: #f1f1f1;
# }
# #T_676ea_row1_col15, #T_676ea_row2_col12, #T_676ea_row2_col14, #T_676ea_row3_col15, #T_676ea_row6_col12, #T_676ea_row9_col25, #T_676ea_row12_col23, #T_676ea_row14_col7, #T_676ea_row15_col4, #T_676ea_row15_col8, #T_676ea_row20_col5 {
#   background-color: #df634e;
#   color: #f1f1f1;
# }
# #T_676ea_row1_col16, #T_676ea_row2_col5, #T_676ea_row4_col5, #T_676ea_row5_col2, #T_676ea_row5_col4, #T_676ea_row16_col2 {
#   background-color: #b70d28;
#   color: #f1f1f1;
# }
# #T_676ea_row1_col17, #T_676ea_row5_col18, #T_676ea_row10_col19, #T_676ea_row11_col19, #T_676ea_row21_col18 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_676ea_row1_col18, #T_676ea_row8_col0 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_676ea_row1_col19, #T_676ea_row25_col18 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_676ea_row1_col20, #T_676ea_row2_col20, #T_676ea_row14_col20, #T_676ea_row16_col6, #T_676ea_row16_col15 {
#   background-color: #ed8366;
#   color: #f1f1f1;
# }
# #T_676ea_row1_col22, #T_676ea_row1_col23, #T_676ea_row2_col7, #T_676ea_row2_col8, #T_676ea_row4_col7, #T_676ea_row4_col21, #T_676ea_row4_col22, #T_676ea_row5_col21, #T_676ea_row6_col15, #T_676ea_row7_col2, #T_676ea_row7_col4, #T_676ea_row8_col2, #T_676ea_row8_col16, #T_676ea_row13_col23, #T_676ea_row15_col6, #T_676ea_row16_col8, #T_676ea_row18_col19, #T_676ea_row19_col18, #T_676ea_row21_col4, #T_676ea_row21_col5, #T_676ea_row21_col23, #T_676ea_row22_col1, #T_676ea_row22_col4, #T_676ea_row23_col1, #T_676ea_row23_col21, #T_676ea_row24_col23 {
#   background-color: #ba162b;
#   color: #f1f1f1;
# }
# #T_676ea_row1_col25, #T_676ea_row8_col13, #T_676ea_row8_col24, #T_676ea_row9_col22, #T_676ea_row10_col11 {
#   background-color: #cc403a;
#   color: #f1f1f1;
# }
# #T_676ea_row2_col0 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_676ea_row2_col3 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_676ea_row2_col6, #T_676ea_row6_col3, #T_676ea_row12_col13, #T_676ea_row12_col24 {
#   background-color: #e16751;
#   color: #f1f1f1;
# }
# #T_676ea_row2_col9, #T_676ea_row4_col9, #T_676ea_row6_col14, #T_676ea_row9_col4, #T_676ea_row14_col6, #T_676ea_row16_col21, #T_676ea_r

# %% [markdown]
# Hay bastante correlación! Elimino las que son sumas de las demás, que son las más correladas con el resto

# %%
a = list(df_emis_pop_2019.columns)
for col in ['All sectors with LULUCF', 'All sectors without LULUCF']:
  a.remove(col)
a
df_emis_pop_2019 = df_emis_pop_2019[a]

corr = df_emis_pop_2019.corr()
corr.style.background_gradient(cmap="coolwarm")
# Out:
# <style type="text/css">
# #T_cb780_row0_col0, #T_cb780_row1_col1, #T_cb780_row2_col2, #T_cb780_row3_col3, #T_cb780_row4_col4, #T_cb780_row5_col5, #T_cb780_row6_col6, #T_cb780_row7_col7, #T_cb780_row8_col8, #T_cb780_row9_col9, #T_cb780_row10_col10, #T_cb780_row11_col11, #T_cb780_row11_col22, #T_cb780_row12_col12, #T_cb780_row13_col13, #T_cb780_row14_col14, #T_cb780_row15_col15, #T_cb780_row16_col16, #T_cb780_row17_col17, #T_cb780_row18_col18, #T_cb780_row19_col19, #T_cb780_row20_col20, #T_cb780_row21_col21, #T_cb780_row22_col11, #T_cb780_row22_col22, #T_cb780_row23_col23 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_cb780_row0_col1, #T_cb780_row1_col3, #T_cb780_row1_col10, #T_cb780_row1_col17, #T_cb780_row14_col18, #T_cb780_row18_col12 {
#   background-color: #f39577;
#   color: #000000;
# }
# #T_cb780_row0_col2, #T_cb780_row14_col8, #T_cb780_row16_col20 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_cb780_row0_col3, #T_cb780_row11_col8, #T_cb780_row17_col21, #T_cb780_row18_col1, #T_cb780_row22_col8 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_cb780_row0_col4, #T_cb780_row9_col3 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_cb780_row0_col5, #T_cb780_row5_col8, #T_cb780_row17_col3 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_cb780_row0_col6, #T_cb780_row14_col1, #T_cb780_row16_col10, #T_cb780_row19_col8 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_cb780_row0_col7, #T_cb780_row16_col6 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_cb780_row0_col8 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_cb780_row0_col9 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_cb780_row0_col10, #T_cb780_row5_col9, #T_cb780_row9_col12 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_cb780_row0_col11, #T_cb780_row0_col22 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_cb780_row0_col12 {
#   background-color: #f5c4ac;
#   color: #000000;
# }
# #T_cb780_row0_col13, #T_cb780_row23_col1 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_cb780_row0_col14, #T_cb780_row9_col18 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_cb780_row0_col15, #T_cb780_row1_col21, #T_cb780_row5_col4, #T_cb780_row13_col7, #T_cb780_row23_col10 {
#   background-color: #ec7f63;
#   color: #f1f1f1;
# }
# #T_cb780_row0_col16, #T_cb780_row3_col18 {
#   background-color: #e36c55;
#   color: #f1f1f1;
# }
# #T_cb780_row0_col17, #T_cb780_row2_col4, #T_cb780_row10_col13, #T_cb780_row12_col7, #T_cb780_row13_col14 {
#   background-color: #e57058;
#   color: #f1f1f1;
# }
# #T_cb780_row0_col18, #T_cb780_row8_col11, #T_cb780_row8_col22, #T_cb780_row13_col9 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_cb780_row0_col19, #T_cb780_row8_col23, #T_cb780_row9_col13 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_cb780_row0_col20 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_cb780_row0_col21, #T_cb780_row8_col4 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_cb780_row0_col23, #T_cb780_row3_col1, #T_cb780_row12_col16 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_cb780_row1_col0, #T_cb780_row5_col12, #T_cb780_row10_col6, #T_cb780_row10_col7, #T_cb780_row10_col23, #T_cb780_row16_col15 {
#   background-color: #ea7b60;
#   color: #f1f1f1;
# }
# #T_cb780_row1_col2, #T_cb780_row9_col10 {
#   background-color: #f59d7e;
#   color: #000000;
# }
# #T_cb780_row1_col4, #T_cb780_row5_col11, #T_cb780_row5_col22, #T_cb780_row5_col23, #T_cb780_row12_col23 {
#   background-color: #d44e41;
#   color: #f1f1f1;
# }
# #T_cb780_row1_col5 {
#   background-color: #f6a586;
#   color: #000000;
# }
# #T_cb780_row1_col6 {
#   background-color: #f6a385;
#   color: #000000;
# }
# #T_cb780_row1_col7, #T_cb780_row17_col1 {
#   background-color: #f7af91;
#   color: #000000;
# }
# #T_cb780_row1_col8 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_cb780_row1_col9, #T_cb780_row8_col18, #T_cb780_row17_col13 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_cb780_row1_col11, #T_cb780_row1_col22, #T_cb780_row10_col14, #T_cb780_row13_col5, #T_cb780_row17_col0, #T_cb780_row18_col21 {
#   background-color: #e46e56;
#   color: #f1f1f1;
# }
# #T_cb780_row1_col12 {
#   background-color: #ca3b37;
#   color: #f1f1f1;
# }
# #T_cb780_row1_col13, #T_cb780_row4_col10, #T_cb780_row7_col23, #T_cb780_row10_col21, #T_cb780_row12_col5, #T_cb780_row13_col2, #T_cb780_row13_col6, #T_cb780_row18_col3 {
#   background-color: #df634e;
#   color: #f1f1f1;
# }
# #T_cb780_row1_col14, #T_cb780_row7_col18, #T_cb780_row15_col0, #T_cb780_row15_col16 {
#   background-color: #f7a889;
#   color: #000000;
# }
# #T_cb780_row1_col15, #T_cb780_row8_col13, #T_cb780_row12_col17 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_cb780_row1_col16, #T_cb780_row7_col4 {
#   background-color: #f29274;
#   color: #f1f1f1;
# }
# #T_cb780_row1_col18 {
#   background-color: #f7b599;
#   color: #000000;
# }
# #T_cb780_row1_col19, #T_cb780_row10_col8 {
#   background-color: #f39778;
#   color: #000000;
# }
# #T_cb780_row1_col20, #T_cb780_row7_col12, #T_cb780_row8_col10 {
#   background-color: #f18d6f;
#   color: #f1f1f1;
# }
# #T_cb780_row1_col23 {
#   background-color: #f08b6e;
#   color: #f1f1f1;
# }
# #T_cb780_row2_col0, #T_cb780_row23_col17 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_cb780_row2_col1, #T_cb780_row9_col6 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_cb780_row2_col3, #T_cb780_row3_col2 {
#   background-color: #b70d28;
#   color: #f1f1f1;
# }
# #T_cb780_row2_col5, #T_cb780_row2_col19, #T_cb780_row2_col20, #T_cb780_row3_col19, #T_cb780_row4_col13, #T_cb780_row5_col2, #T_cb780_row6_col14, #T_cb780_row11_col21, #T_cb780_row13_col4, #T_cb780_row14_col6, #T_cb780_row16_col17, #T_cb780_row17_col16, #T_cb780_row19_col2, #T_cb780_row19_col3, #T_cb780_row19_col21, #T_cb780_row20_col2, #T_cb780_row21_col19, #T_cb780_row22_col21 {
#   background-color: #ba162b;
#   color: #f1f1f1;
# }
# #T_cb780_row2_col6, #T_cb780_row3_col5, #T_cb780_row3_col6, #T_cb780_row3_col14, #T_cb780_row3_col21, #T_cb780_row5_col3, #T_cb780_row5_col6, #T_cb780_row6_col2, #T_cb780_row6_col3, #T_cb780_row6_col5, #T_cb780_row11_col23, #T_cb780_row14_col3, #T_cb780_row19_col20, #T_cb780_row20_col19, #T_cb780_row21_col3, #T_cb780_row21_col11, #T_cb780_row21_col22, #T_cb780_row22_col23 {
#   background-color: #bb1b2c;
#   color: #f1f1f1;
# }
# #T_cb780_row2_col7, #T_cb780_row4_col12, #T_cb780_row7_col2, #T_cb780_row12_col4, #T_cb780_row14_col19, #T_cb780_row19_col14, #T_cb780_row21_col2, #T_cb780_row21_col6, #T_cb780_row21_col20, #T_cb780_row23_col11, #T_cb780_row23_col19, #T_cb780_row23_col22 {
#   background-color: #bd1f2d;
#   color: #f1f1f1;
# }
# #T_cb780_row2_col8, #T_cb780_row4_col8, #T_cb780_row4_col9 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_cb780_row2_col9, #T_cb780_row8_col14, #T_cb780_row12_col9 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_cb780_row2_col10, #T_cb780_row10_col12, #T_cb780_row11_col10, #T_cb780_row12_col14, #T_cb780_row22_col10 {
#   background-color: #e0654f;
#   color: #f1f1f1;
# }
# #T_cb780_row2_col11, #T_cb780_row2_col22, #T_cb780_row4_col20, #T_cb780_row9_col8, #T_cb780_row11_col5, #T_cb780_row22_col5, #T_cb780_row23_col4 {
#   background-color: #cf453c;
#   color: #f1f1f1;
# }
# #T_cb780_row2_col12, #T_cb780_row4_col14, #T_cb780_row4_col18, #T_cb780_row10_col4, #T_cb780_row10_col19, #T_cb780_row13_col10, #T_cb780_row18_col6 {
#   background-color: #e36b54;
#   color: #f1f1f1;
# }
# #T_cb780_row2_col13, #T_cb780_row6_col13, #T_cb780_row21_col18 {
#   background-color: #e67259;
#   color: #f1f1f1;
# }
# #T_cb780_row2_col14, #T_cb780_row3_col20, #T_cb780_row14_col2, #T_cb780_row20_col3 {
#   background-color: #b50927;
#   color: #f1f1f1;
# }
# #T_cb780_row2_col15 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_cb780_row2_col16, #T_cb780_row19_col17 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_cb780_row2_col17, #T_cb780_row5_col16, #T_cb780_row19_col15 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_cb780_row2_col18, #T_cb780_row6_col10, #T_cb780_row13_col1, #T_cb780_row18_col14 {
#   background-color: #ef886b;
#   color: #f1f1f1;
# }
# #T_cb780_row2_col21, #T_cb780_row5_col7, #T_cb780_row5_col19, #T_cb780_row6_col21, #T_cb780_row7_col5, #T_cb780_row

# %% [markdown]
# Dividimos todas las columnas por la población. Lo hacemos de una forma un tanto rara... no sé hacerlo de otra forma, pero funciona. En la misma instrucción eliminamos la variable de la población.

# %%
df_emis_2019_per_cap = (df_emis_pop_2019.T / df_emis_pop_2019["Total Population - Both sexes"]).T.drop("Total Population - Both sexes",axis="columns")

# %%
# Otra forma de hacerlo sería con un for

#for col in df_emis_pop_2019.columns:
#   df_emis_pop_2019[col+"_per_cap"] = df_emis_pop_2019[col] / df_emis_pop_2019["Total Population - Both sexes"]

# %% [markdown]
# Las siguientes dos instrucciones eran para comprobar que dividía bien.

# %%
df_emis_pop_2019[:3]
# Out:
#                   AFOLU  Emissions on agricultural land     Energy  \
# Area
# Afghanistan  16497.3795                      16471.2413   10612.83
# Albania       2698.4834                       3404.1936    4954.57
# Algeria      12891.2501                      13669.4246  230456.05
#
#              Energy - food systems  Farm-gate emissions  \
# Area
# Afghanistan              1061.0057           16471.2413
# Albania                   978.4455            3404.1936
# Algeria                 29628.8000           13031.5272
#
#              Fertilizers Manufacturing  Food Household Consumption  \
# Area
# Afghanistan                    23.2331                    486.4140
# Albania                         0.0000                    181.1625
# Algeria                      3491.4354                  16621.8374
#
#              Food Packaging  Food Processing  Food Retail  ...        IPPU  \
# Area                                                       ...
# Afghanistan         12.1979          79.0806      12.9683  ...    308.9680
# Albania             19.2829          79.8585     123.0311  ...   1115.1180
# Algeria           1199.6502        2474.1799     262.6890  ...  16977.3199
#
#                LULUCF  LULUCF - food systems  Land Use change  \
# Area
# Afghanistan  154.6574                 0.0000           0.0000
# Albania     -237.8793               114.1346           0.0000
# Algeria      224.1426               637.8973         637.8973
#
#              On-farm electricity use    Other  Pre- and post- production  \
# Area
# Afghanistan                  43.9521   89.040                  4435.8857
# Albania                       5.8923   33.125                  1408.5844
# Algeria                     725.9750  614.800                 38962.6826
#
#                 Waste  Waste - food systems  Total Population - Both sexes
# Area
# Afghanistan   5570.25             3503.3924                      38041.754
# Albania        544.97              685.7718                       2880.917
# Algeria      20611.25             9435.6250                      43053.054
#
# [3 rows x 24 columns]

# %%
df_emis_2019_per_cap[:3]
# Out:
#                 AFOLU  Emissions on agricultural land    Energy  \
# Area
# Afghanistan  0.433665                        0.432978  0.278978
# Albania      0.936675                        1.181635  1.719789
# Algeria      0.299427                        0.317502  5.352839
#
#              Energy - food systems  Farm-gate emissions  \
# Area
# Afghanistan               0.027891             0.432978
# Albania                   0.339630             1.181635
# Algeria                   0.688193             0.302685
#
#              Fertilizers Manufacturing  Food Household Consumption  \
# Area
# Afghanistan                   0.000611                    0.012786
# Albania                       0.000000                    0.062884
# Algeria                       0.081096                    0.386078
#
#              Food Packaging  Food Processing  Food Retail  ...  \
# Area                                                       ...
# Afghanistan        0.000321         0.002079     0.000341  ...
# Albania            0.006693         0.027720     0.042706  ...
# Algeria            0.027864         0.057468     0.006102  ...
#
#              IPCC Agriculture      IPPU    LULUCF  LULUCF - food systems  \
# Area
# Afghanistan          0.429600  0.008122  0.004065               0.000000
# Albania              1.019246  0.387071 -0.082571               0.039617
# Algeria              0.294221  0.394335  0.005206               0.014817
#
#              Land Use change  On-farm electricity use     Other  \
# Area
# Afghanistan         0.000000                 0.001155  0.002341
# Albania             0.000000                 0.002045  0.011498
# Algeria             0.014817                 0.016862  0.014280
#
#              Pre- and post- production     Waste  Waste - food systems
# Area
# Afghanistan                   0.116606  0.146425              0.092093
# Albania                       0.488936  0.189165              0.238039
# Algeria                       0.904992  0.478741              0.219163
#
# [3 rows x 23 columns]

# %%
df_emis_pop_2019[:3]
# Out:
#                   AFOLU  Emissions on agricultural land     Energy  \
# Area
# Afghanistan  16497.3795                      16471.2413   10612.83
# Albania       2698.4834                       3404.1936    4954.57
# Algeria      12891.2501                      13669.4246  230456.05
#
#              Energy - food systems  Farm-gate emissions  \
# Area
# Afghanistan              1061.0057           16471.2413
# Albania                   978.4455            3404.1936
# Algeria                 29628.8000           13031.5272
#
#              Fertilizers Manufacturing  Food Household Consumption  \
# Area
# Afghanistan                    23.2331                    486.4140
# Albania                         0.0000                    181.1625
# Algeria                      3491.4354                  16621.8374
#
#              Food Packaging  Food Processing  Food Retail  ...        IPPU  \
# Area                                                       ...
# Afghanistan         12.1979          79.0806      12.9683  ...    308.9680
# Albania             19.2829          79.8585     123.0311  ...   1115.1180
# Algeria           1199.6502        2474.1799     262.6890  ...  16977.3199
#
#                LULUCF  LULUCF - food systems  Land Use change  \
# Area
# Afghanistan  154.6574                 0.0000           0.0000
# Albania     -237.8793               114.1346           0.0000
# Algeria      224.1426               637.8973         637.8973
#
#              On-farm electricity use    Other  Pre- and post- production  \
# Area
# Afghanistan                  43.9521   89.040                  4435.8857
# Albania                       5.8923   33.125                  1408.5844
# Algeria                     725.9750  614.800                 38962.6826
#
#                 Waste  Waste - food systems  Total Population - Both sexes
# Area
# Afghanistan   5570.25             3503.3924                      38041.754
# Albania        544.97              685.7718                       2880.917
# Algeria      20611.25             9435.6250                      43053.054
#
# [3 rows x 24 columns]

# %%
df_final = df_emis_2019_per_cap.copy(deep = True)
columns = list(df_final.columns)
index = list(df_final.index)
cols_to_filter = list(df_final.columns)

# %%
# separamos el pipeline del a loop, para no tener que volver a hacer los primeros 5 pasos para cada k de la loop
pipe = Pipeline(steps = [
    ("Imputer", KNNImputer()),
    ("ArrayToDataFrame", ArrayToDataFrame(columns, index = index)),
#    ("FeatureGenerator", FeatureGenerator()),
    ("OutlierFilter", OutlierFilter(q = 0.99, col_to_filter = cols_to_filter)),
    ("StandardScaler", StandardScaler())
])

# %%
df_scaled_transformed_no_outliers = pipe.fit_transform(df_final)

# %%
CALCULATE_ELBOW = True

if CALCULATE_ELBOW:
    st = time.time()

    sse = {}

    for k in range(2, 15):

        print(f"Fitting pipe with {k} clusters")

        clustering_model = KMeans(n_clusters = k)

        clustering_model.fit(df_scaled_transformed_no_outliers)

        sse[k] = clustering_model.inertia_

    et = time.time()
    print("Elbow curve took {} minutes.".format(round((et - st)/60), 2))
# Out:
# Fitting pipe with 2 clusters
# Fitting pipe with 3 clusters
# Fitting pipe with 4 clusters
# Fitting pipe with 5 clusters
# Fitting pipe with 6 clusters
# Fitting pipe with 7 clusters
# Fitting pipe with 8 clusters
# Fitting pipe with 9 clusters
# Fitting pipe with 10 clusters
# Fitting pipe with 11 clusters
# Fitting pipe with 12 clusters
# Fitting pipe with 13 clusters
# Fitting pipe with 14 clusters
# Elbow curve took 0 minutes.

# %%
if CALCULATE_ELBOW:
    fig = plt.figure(figsize = (16, 8))
    ax = fig.add_subplot()

    x_values = list(sse.keys())
    y_values = list(sse.values())

    ax.plot(x_values, y_values, label = "Inertia/dispersión de los clústers")
    fig.suptitle("Variación de la dispersión de los clústers en función de la k", fontsize = 16);

# %% [markdown]
# La curba no acaba de hacer forma de codo. Las variables no son del todo informativas como para hacer grupos bien esparados. Tendremos que añadir otras variables, como las de producción, exportación/exportacion
# Variacion antes y despues de Kioto.

# %%
# Creamos de nuevo el pipeline usando 3 clusters

n_clusters = 3

pipe = Pipeline(steps = [
    ("Imputer", KNNImputer()),
    ("ArrayToDataFrame", ArrayToDataFrame(columns, index = index)),
#    ("FeatureGenerator", FeatureGenerator()),
    ("OutlierFilter", OutlierFilter(q = 0.99, col_to_filter = cols_to_filter)),
    ("StandardScaler", StandardScaler()),
    ("Clustering", KMeans(n_clusters = n_clusters))
])

# %%
df_final.shape
# Out:
# (226, 23)

# %%
pipe.fit(df_final)
# Out:
# Pipeline(steps=[('Imputer', KNNImputer()),
#                 ('ArrayToDataFrame',
#                  ArrayToDataFrame(columns=['AFOLU',
#                                            'Emissions on agricultural land',
#                                            'Energy', 'Energy - food systems',
#                                            'Farm-gate emissions',
#                                            'Fertilizers Manufacturing',
#                                            'Food Household Consumption',
#                                            'Food Packaging', 'Food Processing',
#                                            'Food Retail', 'Food Transport',
#                                            'Food Waste Disposal',
#                                            'Food systems', 'IPCC Agriculture',
#                                            'IPPU'...
#                                               'Food Household Consumption',
#                                               'Food Packaging',
#                                               'Food Processing', 'Food Retail',
#                                               'Food Transport',
#                                               'Food Waste Disposal',
#                                               'Food systems',
#                                               'IPCC Agriculture', 'IPPU',
#                                               'LULUCF', 'LULUCF - food systems',
#                                               'Land Use change',
#                                               'On-farm electricity use',
#                                               'Other',
#                                               'Pre- and post- production',
#                                               'Waste', 'Waste - food systems'],
#                                q=0.99)),
#                 ('StandardScaler', StandardScaler()),
#                 ('Clustering', KMeans(n_clusters=3))])

# %%
# creamos un dataframe escalado con los pasos 1, 3 y 5
X_processed = pipe[:2].transform(df_final)
X_scaled = pipe["StandardScaler"].transform(X_processed)

X_scaled.shape
# Out:
# (226, 23)

# %%
# hacemos el predict, en este caso tendremos para cada cliente su centroide/clúster.
print(pipe["Clustering"].predict(X_scaled)[:20])
labels = pipe["Clustering"].predict(X_scaled)
# Out:
# [1 1 1 1 1 2 2 1 1 2 2 2 1 2 2 1 2 2 2 0]

# %%
pd.Series(labels).value_counts()
# Out:
# 1    121
# 2     85
# 0     20
# dtype: int64

# %%
# cuantos hay de cada grupo

plt.hist(labels,bins=n_clusters)
# Out:
# (array([ 20., 121.,  85.]),
#  array([0.        , 0.66666667, 1.33333333, 2.        ]),
#  <a list of 3 Patch objects>)

# %%
# le asignamos al DataFrame procesado los centroides. (antes del escalado de variable)
# SI LO HACEMOS AL ESCALADO LOS NÚMEROS PERDERAN SU SIGNIFICADO ESCALA Y SERÁN MÁS DÍFICILES DE INTERPRETAR.
X_processed["cluster"] = labels

# %%
X_processed.shape
# Out:
# (226, 24)

# %%
X_processed.columns
# Out:
# Index(['AFOLU', 'Emissions on agricultural land', 'Energy',
#        'Energy - food systems', 'Farm-gate emissions',
#        'Fertilizers Manufacturing', 'Food Household Consumption',
#        'Food Packaging', 'Food Processing', 'Food Retail', 'Food Transport',
#        'Food Waste Disposal', 'Food systems', 'IPCC Agriculture', 'IPPU',
#        'LULUCF', 'LULUCF - food systems', 'Land Use change',
#        'On-farm electricity use', 'Other', 'Pre- and post- production',
#        'Waste', 'Waste - food systems', 'cluster'],
#       dtype='object')

# %%
# visualizamos nuestros grupos en base a las variables del modelo RFM, para ver que tal han quedado.

for col in X_processed.columns[:-1]:
  print(col)
  plt.figure(figsize=(15,5))
  sns.boxplot(
    data = X_processed, 
    x = 'cluster',
    y = col
)
# Out:
# AFOLU
# Emissions on agricultural land
# Energy
# Energy - food systems
# Farm-gate emissions
# Fertilizers Manufacturing
# Food Household Consumption
# Food Packaging
# Food Processing
# Food Retail
# Food Transport
# Food Waste Disposal
# Food systems
# IPCC Agriculture
# IPPU
# LULUCF
# LULUCF - food systems
# Land Use change
# On-farm electricity use
# Other
# Pre- and post- production
# Waste
# Waste - food systems
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: RuntimeWarning:
#
# More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: RuntimeWarning:
#
# More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: RuntimeWarning:
#
# More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).

# %%
X_processed.columns
# Out:
# Index(['AFOLU', 'Emissions on agricultural land', 'Energy',
#        'Energy - food systems', 'Farm-gate emissions',
#        'Fertilizers Manufacturing', 'Food Household Consumption',
#        'Food Packaging', 'Food Processing', 'Food Retail', 'Food Transport',
#        'Food Waste Disposal', 'Food systems', 'IPCC Agriculture', 'IPPU',
#        'LULUCF', 'LULUCF - food systems', 'Land Use change',
#        'On-farm electricity use', 'Other', 'Pre- and post- production',
#        'Waste', 'Waste - food systems', 'cluster'],
#       dtype='object')

# %%
# visualizbamos nuestros grupos en base a las variables del modelo RFM, para ver que tal han quedado.
selected_columns = ['Food Retail', 'Farm-gate emissions', 'IPPU']

sns.pairplot(X_processed, vars = selected_columns, hue = 'cluster');

# %%
# visualizamos nuestros grupos en base a las variables del modelo RFM, para ver que tal han quedado.
selected_columns = ['Food Retail', 'Farm-gate emissions', 'Land Use change','Energy - food systems']

sns.pairplot(X_processed, vars = selected_columns, hue = 'cluster');

# %% [markdown]
# Vemos que hay un cluster de países que las emisiones por venta de comida ("Food Retail") es mucho más elevado en los demás clusters, y otro de los clusters en los que las emisiones por "Land Use Change" son también más elevadas.

# %% [markdown]
# Miramos qué países son los del cluster 2 (ya que son tan poquitos)

# %%
X_processed[X_processed.cluster == 2]
# Out:
#                                  AFOLU  Emissions on agricultural land  \
# Anguilla                      0.000000                        0.271054
# Antigua and Barbuda           0.213523                        0.249421
# Aruba                        -0.001149                        0.063692
# Australia                     5.999790                        5.606341
# Austria                       0.039918                        0.979497
# ...                                ...                             ...
# Turkmenistan                  1.744238                        1.925820
# Turks and Caicos Islands      0.000000                        0.080658
# United Arab Emirates          0.219112                        0.407156
# United States Virgin Islands -1.582167                        0.000000
# United States of America      0.474013                        1.630095
#
#                                  Energy  Energy - food systems  \
# Anguilla                      10.316114               2.236122
# Antigua and Barbuda            5.564907               0.963214
# Aruba                          9.459344               1.950016
# Australia                     16.127695               2.045670
# Austria                        7.202352               0.791503
# ...                                 ...                    ...
# Turkmenistan                  21.115778               1.716221
# Turks and Caicos Islands       6.530635               1.449737
# United Arab Emirates          22.319682               2.768636
# United States Virgin Islands   3.691671               0.519294
# United States of America      16.171672               1.356657
#
#                               Farm-gate emissions  Fertilizers Manufacturing  \
# Anguilla                                 0.271054                   0.000000
# Antigua and Barbuda                      0.249421                   0.000000
# Aruba                                    0.063692                   0.000000
# Australia                                5.554495                   0.000000
# Austria                                  0.954267                   0.000000
# ...                                           ...                        ...
# Turkmenistan                             1.925820                   0.000000
# Turks and Caicos Islands                 0.080658                   0.000000
# United Arab Emirates                     0.407156                   0.330749
# United States Virgin Islands             0.000000                   0.000000
# United States of America                 1.448588                   0.106155
#
#                               Food Household Consumption  Food Packaging  \
# Anguilla                                        0.874403        0.002744
# Antigua and Barbuda                             0.268305        0.001423
# Aruba                                           0.569922        0.003008
# Australia                                       0.371541        0.282338
# Austria                                         0.142756        0.068048
# ...                                                  ...             ...
# Turkmenistan                                    0.114193        0.011645
# Turks and Caicos Islands                        0.401841        0.001563
# United Arab Emirates                            0.435428        0.000002
# United States Virgin Islands                    0.314733        0.022620
# United States of America                        0.213445        0.077301
#
#                               Food Processing  Food Retail  ...      IPPU  \
# Anguilla                             0.344912     0.546654  ...  0.000000
# Antigua and Barbuda                  0.185404     0.292569  ...  0.213265
# Aruba                                0.315394     0.562533  ...  0.036969
# Australia                            0.349381     0.620068  ...  1.295672
# Austria                              0.149411     0.392770  ...  3.034657
# ...                                       ...          ...  ...       ...
# Turkmenistan                         0.217639     0.417874  ...  0.562709
# Turks and Caicos Islands             0.217889     0.527755  ...  0.008041
# United Arab Emirates                 0.683924     0.387191  ...  2.273292
# United States Virgin Islands         0.071832     0.204561  ...  0.566826
# United States of America             0.350649     0.888535  ...  1.755382
#
#                                 LULUCF  LULUCF - food systems  \
# Anguilla                      0.000000               0.000000
# Antigua and Barbuda           0.000000               0.000000
# Aruba                        -0.001149               0.000000
# Australia                     0.892778               0.151707
# Austria                      -0.795340               0.035460
# ...                                ...                    ...
# Turkmenistan                  0.000000               0.000000
# Turks and Caicos Islands      0.000000               0.000000
# United Arab Emirates          0.000000               0.000000
# United States Virgin Islands -1.582167               0.000000
# United States of America     -0.699579               0.302928
#
#                               Land Use change  On-farm electricity use  \
# Anguilla                             0.000000                 0.000000
# Antigua and Barbuda                  0.000000                 0.000000
# Aruba                                0.000000                 0.000000
# Australia                            0.051846                 0.071011
# Austria                              0.025230                 0.031254
# ...                                       ...                      ...
# Turkmenistan                         0.000000                 0.643181
# Turks and Caicos Islands             0.000000                 0.000000
# United Arab Emirates                 0.000000                 0.319822
# United States Virgin Islands         0.000000                 0.038340
# United States of America             0.181508                 0.084980
#
#                                  Other  Pre- and post- production     Waste  \
# Anguilla                      0.014043                   1.964315  0.291882
# Antigua and Barbuda           0.103961                   1.376650  0.507852
# Aruba                         0.051348                   2.194489  0.276914
# Australia                     0.076195                   2.310226  0.572021
# Austria                       0.020034                   1.167055  0.319460
# ...                                ...                        ...       ...
# Turkmenistan                  0.030014                   1.627726  0.312812
# Turks and Caicos Islands      0.026993                   1.405184  0.315991
# United Arab Emirates          0.078926                   2.814430  0.885205
# United States Virgin Islands  0.028366                   1.027913  0.335069
# United States of America      0.066788                   2.115190  0.461786
#
#                               Waste - food systems  cluster
# Anguilla                                  0.182008        2
# Antigua and Barbuda                       0.356840        2
# Aruba                                     0.308157        2
# Australia                                 0.216121        2
# Austria                                   0.163440        2
# ...                                            ...      ...
# Turkmenistan                              0.070489        2
# Turks and Caicos Islands                  0.035768        2
# United Arab Emirates                      0.233838        2
# United States Virgin Islands              0.508619        2
# United States of America                  0.221426        2
#
# [85 rows x 24 columns]

# %% [markdown]
# Los intentamos caracterizar usando PIB per capita, población, toneladas exportadas per capita

# %%
check_point = X_processed.copy(deep=True)

# %%
X_processed = check_point.copy(deep=True)

# %%
X_processed = X_processed.reset_index()

# %%
print(X_processed.shape)
# Out:
# (226, 25)

# %%
# HAcemos un merge del PIB per cápita

AÑO_CLUSTER = 2019
df_PIB_Dol_Cap_2019 = df_PIB_Dol_Cap[df_PIB_Dol_Cap["Year"] == AÑO_CLUSTER][["Area", "Value"]]

print(X_processed.shape)
X_processed = pd.merge(X_processed, df_PIB_Dol_Cap_2019, left_on="index", right_on= "Area", how="left")
print(X_processed.shape)
# Out:
# (226, 25)
# (226, 27)

# %%
X_processed.head()
# Out:
#             index     AFOLU  Emissions on agricultural land    Energy  \
# 0     Afghanistan  0.433665                        0.432978  0.278978
# 1         Albania  0.936675                        1.181635  1.719789
# 2         Algeria  0.299427                        0.317502  5.352839
# 3  American Samoa -0.743887                        0.166830  1.635057
# 4          Angola  2.670236                        2.666654  1.912714
#
#    Energy - food systems  Farm-gate emissions  Fertilizers Manufacturing  \
# 0               0.027891             0.432978                   0.000611
# 1               0.339630             1.181635                   0.000000
# 2               0.688193             0.302685                   0.081096
# 3               0.113675             0.000036                   0.000000
# 4               0.095980             1.162186                   0.000000
#
#    Food Household Consumption  Food Packaging  Food Processing  ...  \
# 0                    0.012786        0.000321         0.002079  ...
# 1                    0.062884        0.006693         0.027720  ...
# 2                    0.386078        0.027864         0.057468  ...
# 3                    0.059989        0.001442         0.031001  ...
# 4                    0.031261        0.013148         0.004474  ...
#
#    LULUCF - food systems  Land Use change  On-farm electricity use     Other  \
# 0               0.000000         0.000000                 0.001155  0.002341
# 1               0.039617         0.000000                 0.002045  0.011498
# 2               0.014817         0.014817                 0.016862  0.014280
# 3               0.166794         0.166794                 0.000008  0.022950
# 4               1.517771         1.504468                 0.000000  0.012740
#
#    Pre- and post- production     Waste  Waste - food systems  cluster  \
# 0                   0.116606  0.146425              0.092093        1
# 1                   0.488936  0.189165              0.238039        1
# 2                   0.904992  0.478741              0.219163        1
# 3                   0.149443  0.204912              0.035768        1
# 4                   0.173488  0.168654              0.082615        1
#
#           Area        Value
# 0  Afghanistan   469.919090
# 1      Albania  5303.197823
# 2      Algeria  3975.510381
# 3          NaN          NaN
# 4       Angola  2670.850732
#
# [5 rows x 27 columns]

# %%
X_processed = X_processed.rename(columns={"Value": "PIB_Cap"})
X_processed.head()
# Out:
#             index     AFOLU  Emissions on agricultural land    Energy  \
# 0     Afghanistan  0.433665                        0.432978  0.278978
# 1         Albania  0.936675                        1.181635  1.719789
# 2         Algeria  0.299427                        0.317502  5.352839
# 3  American Samoa -0.743887                        0.166830  1.635057
# 4          Angola  2.670236                        2.666654  1.912714
#
#    Energy - food systems  Farm-gate emissions  Fertilizers Manufacturing  \
# 0               0.027891             0.432978                   0.000611
# 1               0.339630             1.181635                   0.000000
# 2               0.688193             0.302685                   0.081096
# 3               0.113675             0.000036                   0.000000
# 4               0.095980             1.162186                   0.000000
#
#    Food Household Consumption  Food Packaging  Food Processing  ...  \
# 0                    0.012786        0.000321         0.002079  ...
# 1                    0.062884        0.006693         0.027720  ...
# 2                    0.386078        0.027864         0.057468  ...
# 3                    0.059989        0.001442         0.031001  ...
# 4                    0.031261        0.013148         0.004474  ...
#
#    LULUCF - food systems  Land Use change  On-farm electricity use     Other  \
# 0               0.000000         0.000000                 0.001155  0.002341
# 1               0.039617         0.000000                 0.002045  0.011498
# 2               0.014817         0.014817                 0.016862  0.014280
# 3               0.166794         0.166794                 0.000008  0.022950
# 4               1.517771         1.504468                 0.000000  0.012740
#
#    Pre- and post- production     Waste  Waste - food systems  cluster  \
# 0                   0.116606  0.146425              0.092093        1
# 1                   0.488936  0.189165              0.238039        1
# 2                   0.904992  0.478741              0.219163        1
# 3                   0.149443  0.204912              0.035768        1
# 4                   0.173488  0.168654              0.082615        1
#
#           Area      PIB_Cap
# 0  Afghanistan   469.919090
# 1      Albania  5303.197823
# 2      Algeria  3975.510381
# 3          NaN          NaN
# 4       Angola  2670.850732
#
# [5 rows x 27 columns]

# %%
X_processed.isnull().sum()
# Out:
# index                              0
# AFOLU                              0
# Emissions on agricultural land     0
# Energy                             0
# Energy - food systems              0
# Farm-gate emissions                0
# Fertilizers Manufacturing          0
# Food Household Consumption         0
# Food Packaging                     0
# Food Processing                    0
# Food Retail                        0
# Food Transport                     0
# Food Waste Disposal                0
# Food systems                       0
# IPCC Agriculture                   0
# IPPU                               0
# LULUCF                             0
# LULUCF - food systems              0
# Land Use change                    0
# On-farm electricity use            0
# Other                              0
# Pre- and post- production          0
# Waste                              0
# Waste - food systems               0
# cluster                            0
# Area                              21
# PIB_Cap                           21
# dtype: int64

# %%
X_processed.dropna(inplace=True)

# %%
X_processed.shape
# Out:
# (205, 27)

# %%
plt.figure(figsize=(15,5))
sns.boxenplot(
    data = X_processed, 
    x = 'cluster',
    y = "PIB_Cap"
)

# %%
X_processed[["index","cluster"]].rename(columns={"index": "Area"}).to_csv("Cluster_Paises.csv")

# %% [markdown]
# Vemos si cada cluster se puede caracterizar con la informacion de paises den el Anexo I de Kyoto

# %%
X_processed.head(1)
# Out:
#          index     AFOLU  Emissions on agricultural land    Energy  \
# 0  Afghanistan  0.433665                        0.432978  0.278978
#
#    Energy - food systems  Farm-gate emissions  Fertilizers Manufacturing  \
# 0               0.027891             0.432978                   0.000611
#
#    Food Household Consumption  Food Packaging  Food Processing  ...  \
# 0                    0.012786        0.000321         0.002079  ...
#
#    LULUCF - food systems  Land Use change  On-farm electricity use     Other  \
# 0                    0.0              0.0                 0.001155  0.002341
#
#    Pre- and post- production     Waste  Waste - food systems  cluster  \
# 0                   0.116606  0.146425              0.092093        1
#
#           Area    PIB_Cap
# 0  Afghanistan  469.91909
#
# [1 rows x 27 columns]

# %%
a = df_emis_sec[["Area Code", "Area"]].drop_duplicates()
print(a.shape)
a = pd.merge(a,df_paises_Kyoto, on="Area Code", how="left")
print(a.shape)
# Out:
# (275, 2)
# (275, 4)

# %%
df_paises_Kyoto.head()
# Out:
# Country Group  Area Code         Country  Annex I countries
# 0                      1         Armenia                0.0
# 1                      2     Afghanistan                0.0
# 2                      3         Albania                0.0
# 3                      4         Algeria                0.0
# 4                      5  American Samoa                1.0

# %%
a.head(5)
# Out:
#    Area Code            Area         Country  Annex I countries
# 0          2     Afghanistan     Afghanistan                0.0
# 1          3         Albania         Albania                0.0
# 2          4         Algeria         Algeria                0.0
# 3          5  American Samoa  American Samoa                1.0
# 4          7          Angola          Angola                0.0

# %%
# hacemos merge con la información del Anexo I

print(X_processed.shape)
X_processed = pd.merge(X_processed, a, left_on="index", right_on= "Area", how="left")
print(X_processed.shape)
# Out:
# (205, 27)
# (205, 31)

# %%
X_processed.drop(["Area_y","Country"], axis="columns", inplace = True)
X_processed.head(1)
# Out:
#          index     AFOLU  Emissions on agricultural land    Energy  \
# 0  Afghanistan  0.433665                        0.432978  0.278978
#
#    Energy - food systems  Farm-gate emissions  Fertilizers Manufacturing  \
# 0               0.027891             0.432978                   0.000611
#
#    Food Household Consumption  Food Packaging  Food Processing  ...  \
# 0                    0.012786        0.000321         0.002079  ...
#
#    On-farm electricity use     Other  Pre- and post- production     Waste  \
# 0                 0.001155  0.002341                   0.116606  0.146425
#
#    Waste - food systems  cluster       Area_x    PIB_Cap  Area Code  \
# 0              0.092093        1  Afghanistan  469.91909          2
#
#    Annex I countries
# 0                0.0
#
# [1 rows x 29 columns]

# %%
plot = pd.crosstab(index=X_processed['cluster'], columns=X_processed['Annex I countries']).apply(lambda r: r/r.sum() *100,
                                              axis=1).plot(kind='bar')

# %% [markdown]
# Vemos que los paises de los clusters 1 y 2 no pertenecen en su gran mayoría al Anexo I del tratado de Kioto. Son los países con menos PIB per Cápita. De los países del cluster 1, que tienen un PIB per cápita más alto (más desarrollados), la proporción de países que están en Kyoto es 40-60 aprox.

# %%
X_processed[X_processed["Area_x"]=="China"]
# Out:
#     index     AFOLU  Emissions on agricultural land    Energy  \
# 39  China  0.012129                        0.540246  7.382154
#
#     Energy - food systems  Farm-gate emissions  Fertilizers Manufacturing  \
# 39               0.691875             0.540246                   0.089645
#
#     Food Household Consumption  Food Packaging  Food Processing  ...  \
# 39                    0.320241        0.075597         0.004406  ...
#
#     On-farm electricity use     Other  Pre- and post- production     Waste  \
# 39                 0.075067  0.043497                   0.752177  0.334761
#
#     Waste - food systems  cluster  Area_x       PIB_Cap  Area Code  \
# 39               0.14305        2   China  10238.512141        351
#
#     Annex I countries
# 39                0.0
#
# [1 rows x 29 columns]

# %% [markdown]
# Probamos de añadir otro cluster para ver si separa los paíse del cluster 1

# %%
# Creamos de nuevo el pipeline usando 3 clusters

n_clusters = 4

pipe = Pipeline(steps = [
    ("Imputer", KNNImputer()),
    ("ArrayToDataFrame", ArrayToDataFrame(columns, index = index)),
#    ("FeatureGenerator", FeatureGenerator()),
    ("OutlierFilter", OutlierFilter(q = 0.99, col_to_filter = cols_to_filter)),
    ("StandardScaler", StandardScaler()),
    ("Clustering", KMeans(n_clusters = n_clusters))
])

# %%
df_final.shape
# Out:
# (226, 23)

# %%
pipe.fit(df_final)
# Out:
# Pipeline(steps=[('Imputer', KNNImputer()),
#                 ('ArrayToDataFrame',
#                  ArrayToDataFrame(columns=['AFOLU',
#                                            'Emissions on agricultural land',
#                                            'Energy', 'Energy - food systems',
#                                            'Farm-gate emissions',
#                                            'Fertilizers Manufacturing',
#                                            'Food Household Consumption',
#                                            'Food Packaging', 'Food Processing',
#                                            'Food Retail', 'Food Transport',
#                                            'Food Waste Disposal',
#                                            'Food systems', 'IPCC Agriculture',
#                                            'IPPU'...
#                                               'Food Household Consumption',
#                                               'Food Packaging',
#                                               'Food Processing', 'Food Retail',
#                                               'Food Transport',
#                                               'Food Waste Disposal',
#                                               'Food systems',
#                                               'IPCC Agriculture', 'IPPU',
#                                               'LULUCF', 'LULUCF - food systems',
#                                               'Land Use change',
#                                               'On-farm electricity use',
#                                               'Other',
#                                               'Pre- and post- production',
#                                               'Waste', 'Waste - food systems'],
#                                q=0.99)),
#                 ('StandardScaler', StandardScaler()),
#                 ('Clustering', KMeans(n_clusters=4))])

# %%
# creamos un dataframe escalado con los pasos 1, 3 y 5
X_processed = pipe[:2].transform(df_final)
X_scaled = pipe["StandardScaler"].transform(X_processed)

X_scaled.shape
# Out:
# (226, 23)

# %%
# hacemos el predict, en este caso tendremos para cada cliente su centroide/clúster.
print(pipe["Clustering"].predict(X_scaled)[:20])
labels = pipe["Clustering"].predict(X_scaled)
# Out:
# [0 0 1 0 0 1 1 0 0 1 3 1 0 1 3 0 1 3 1 2]

# %%
pd.Series(labels).value_counts()
# Out:
# 0    105
# 1     79
# 3     29
# 2     13
# dtype: int64

# %%
# cuantos hay de cada grupo

plt.hist(labels,bins=4)
# Out:
# (array([105.,  79.,  13.,  29.]),
#  array([0.  , 0.75, 1.5 , 2.25, 3.  ]),
#  <a list of 4 Patch objects>)

# %%
# le asignamos al DataFrame procesado los centroides. (antes del escalado de variable)
# SI LO HACEMOS AL ESCALADO LOS NÚMEROS PERDERAN SU SIGNIFICADO ESCALA Y SERÁN MÁS DÍFICILES DE INTERPRETAR.
X_processed["cluster"] = labels

# %%
X_processed.shape
# Out:
# (226, 24)

# %%
X_processed.columns
# Out:
# Index(['AFOLU', 'Emissions on agricultural land', 'Energy',
#        'Energy - food systems', 'Farm-gate emissions',
#        'Fertilizers Manufacturing', 'Food Household Consumption',
#        'Food Packaging', 'Food Processing', 'Food Retail', 'Food Transport',
#        'Food Waste Disposal', 'Food systems', 'IPCC Agriculture', 'IPPU',
#        'LULUCF', 'LULUCF - food systems', 'Land Use change',
#        'On-farm electricity use', 'Other', 'Pre- and post- production',
#        'Waste', 'Waste - food systems', 'cluster'],
#       dtype='object')

# %%
# visualizamos nuestros grupos en base a las variables del modelo RFM, para ver que tal han quedado.

for col in X_processed.columns[:-1]:
  print(col)
  plt.figure(figsize=(15,5))
  sns.boxplot(
    data = X_processed, 
    x = 'cluster',
    y = col
)
# Out:
# AFOLU
# Emissions on agricultural land
# Energy
# Energy - food systems
# Farm-gate emissions
# Fertilizers Manufacturing
# Food Household Consumption
# Food Packaging
# Food Processing
# Food Retail
# Food Transport
# Food Waste Disposal
# Food systems
# IPCC Agriculture
# IPPU
# LULUCF
# LULUCF - food systems
# Land Use change
# On-farm electricity use
# Other
# Pre- and post- production
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: RuntimeWarning:
#
# More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: RuntimeWarning:
#
# More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: RuntimeWarning:
#
# More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Waste
# Waste - food systems

# %%
X_processed.columns
# Out:
# Index(['AFOLU', 'Emissions on agricultural land', 'Energy',
#        'Energy - food systems', 'Farm-gate emissions',
#        'Fertilizers Manufacturing', 'Food Household Consumption',
#        'Food Packaging', 'Food Processing', 'Food Retail', 'Food Transport',
#        'Food Waste Disposal', 'Food systems', 'IPCC Agriculture', 'IPPU',
#        'LULUCF', 'LULUCF - food systems', 'Land Use change',
#        'On-farm electricity use', 'Other', 'Pre- and post- production',
#        'Waste', 'Waste - food systems', 'cluster'],
#       dtype='object')

# %%
# visualizbamos nuestros grupos en base a las variables del modelo RFM, para ver que tal han quedado.
selected_columns = ['Food Retail', 'Farm-gate emissions', 'IPPU']

sns.pairplot(X_processed, vars = selected_columns, hue = 'cluster');

# %%
# visualizamos nuestros grupos en base a las variables del modelo RFM, para ver que tal han quedado.
selected_columns = ['Food Retail', 'Farm-gate emissions', 'Land Use change','Energy - food systems']

sns.pairplot(X_processed, vars = selected_columns, hue = 'cluster');

# %%
check_point = X_processed.copy(deep=True)

# %%
X_processed = check_point.copy(deep=True)

# %%
X_processed = X_processed.reset_index()

# %%
print(X_processed.shape)
# Out:
# (226, 25)

# %%
# HAcemos un merge del PIB per cápita

AÑO_CLUSTER = 2019
df_PIB_Dol_Cap_2019 = df_PIB_Dol_Cap[df_PIB_Dol_Cap["Year"] == AÑO_CLUSTER][["Area", "Value"]]

print(X_processed.shape)
X_processed = pd.merge(X_processed, df_PIB_Dol_Cap_2019, left_on="index", right_on= "Area", how="left")
print(X_processed.shape)
# Out:
# (226, 25)
# (226, 27)

# %%
X_processed.head()
# Out:
#             index     AFOLU  Emissions on agricultural land    Energy  \
# 0     Afghanistan  0.433665                        0.432978  0.278978
# 1         Albania  0.936675                        1.181635  1.719789
# 2         Algeria  0.299427                        0.317502  5.352839
# 3  American Samoa -0.743887                        0.166830  1.635057
# 4          Angola  2.670236                        2.666654  1.912714
#
#    Energy - food systems  Farm-gate emissions  Fertilizers Manufacturing  \
# 0               0.027891             0.432978                   0.000611
# 1               0.339630             1.181635                   0.000000
# 2               0.688193             0.302685                   0.081096
# 3               0.113675             0.000036                   0.000000
# 4               0.095980             1.162186                   0.000000
#
#    Food Household Consumption  Food Packaging  Food Processing  ...  \
# 0                    0.012786        0.000321         0.002079  ...
# 1                    0.062884        0.006693         0.027720  ...
# 2                    0.386078        0.027864         0.057468  ...
# 3                    0.059989        0.001442         0.031001  ...
# 4                    0.031261        0.013148         0.004474  ...
#
#    LULUCF - food systems  Land Use change  On-farm electricity use     Other  \
# 0               0.000000         0.000000                 0.001155  0.002341
# 1               0.039617         0.000000                 0.002045  0.011498
# 2               0.014817         0.014817                 0.016862  0.014280
# 3               0.166794         0.166794                 0.000008  0.022950
# 4               1.517771         1.504468                 0.000000  0.012740
#
#    Pre- and post- production     Waste  Waste - food systems  cluster  \
# 0                   0.116606  0.146425              0.092093        0
# 1                   0.488936  0.189165              0.238039        0
# 2                   0.904992  0.478741              0.219163        1
# 3                   0.149443  0.204912              0.035768        0
# 4                   0.173488  0.168654              0.082615        0
#
#           Area        Value
# 0  Afghanistan   469.919090
# 1      Albania  5303.197823
# 2      Algeria  3975.510381
# 3          NaN          NaN
# 4       Angola  2670.850732
#
# [5 rows x 27 columns]

# %%
X_processed = X_processed.rename(columns={"Value": "PIB_Cap"})
X_processed.head()
# Out:
#             index     AFOLU  Emissions on agricultural land    Energy  \
# 0     Afghanistan  0.433665                        0.432978  0.278978
# 1         Albania  0.936675                        1.181635  1.719789
# 2         Algeria  0.299427                        0.317502  5.352839
# 3  American Samoa -0.743887                        0.166830  1.635057
# 4          Angola  2.670236                        2.666654  1.912714
#
#    Energy - food systems  Farm-gate emissions  Fertilizers Manufacturing  \
# 0               0.027891             0.432978                   0.000611
# 1               0.339630             1.181635                   0.000000
# 2               0.688193             0.302685                   0.081096
# 3               0.113675             0.000036                   0.000000
# 4               0.095980             1.162186                   0.000000
#
#    Food Household Consumption  Food Packaging  Food Processing  ...  \
# 0                    0.012786        0.000321         0.002079  ...
# 1                    0.062884        0.006693         0.027720  ...
# 2                    0.386078        0.027864         0.057468  ...
# 3                    0.059989        0.001442         0.031001  ...
# 4                    0.031261        0.013148         0.004474  ...
#
#    LULUCF - food systems  Land Use change  On-farm electricity use     Other  \
# 0               0.000000         0.000000                 0.001155  0.002341
# 1               0.039617         0.000000                 0.002045  0.011498
# 2               0.014817         0.014817                 0.016862  0.014280
# 3               0.166794         0.166794                 0.000008  0.022950
# 4               1.517771         1.504468                 0.000000  0.012740
#
#    Pre- and post- production     Waste  Waste - food systems  cluster  \
# 0                   0.116606  0.146425              0.092093        0
# 1                   0.488936  0.189165              0.238039        0
# 2                   0.904992  0.478741              0.219163        1
# 3                   0.149443  0.204912              0.035768        0
# 4                   0.173488  0.168654              0.082615        0
#
#           Area      PIB_Cap
# 0  Afghanistan   469.919090
# 1      Albania  5303.197823
# 2      Algeria  3975.510381
# 3          NaN          NaN
# 4       Angola  2670.850732
#
# [5 rows x 27 columns]

# %%
X_processed.isnull().sum()
# Out:
# index                              0
# AFOLU                              0
# Emissions on agricultural land     0
# Energy                             0
# Energy - food systems              0
# Farm-gate emissions                0
# Fertilizers Manufacturing          0
# Food Household Consumption         0
# Food Packaging                     0
# Food Processing                    0
# Food Retail                        0
# Food Transport                     0
# Food Waste Disposal                0
# Food systems                       0
# IPCC Agriculture                   0
# IPPU                               0
# LULUCF                             0
# LULUCF - food systems              0
# Land Use change                    0
# On-farm electricity use            0
# Other                              0
# Pre- and post- production          0
# Waste                              0
# Waste - food systems               0
# cluster                            0
# Area                              21
# PIB_Cap                           21
# dtype: int64

# %%
X_processed.dropna(inplace=True)

# %%
X_processed.shape
# Out:
# (205, 27)

# %%
plt.figure(figsize=(15,5))
sns.boxenplot(
    data = X_processed, 
    x = 'cluster',
    y = "PIB_Cap"
)

# %%
X_processed[["index","cluster"]].rename(columns={"index": "Area"}).to_csv("Cluster_Paises.csv")

# %%
X_processed.head(1)
# Out:
#          index     AFOLU  Emissions on agricultural land    Energy  \
# 0  Afghanistan  0.433665                        0.432978  0.278978
#
#    Energy - food systems  Farm-gate emissions  Fertilizers Manufacturing  \
# 0               0.027891             0.432978                   0.000611
#
#    Food Household Consumption  Food Packaging  Food Processing  ...  \
# 0                    0.012786        0.000321         0.002079  ...
#
#    LULUCF - food systems  Land Use change  On-farm electricity use     Other  \
# 0                    0.0              0.0                 0.001155  0.002341
#
#    Pre- and post- production     Waste  Waste - food systems  cluster  \
# 0                   0.116606  0.146425              0.092093        0
#
#           Area    PIB_Cap
# 0  Afghanistan  469.91909
#
# [1 rows x 27 columns]

# %%
a = df_emis_sec[["Area Code", "Area"]].drop_duplicates()
print(a.shape)
a = pd.merge(a,df_paises_Kyoto, on="Area Code", how="left")
print(a.shape)
# Out:
# (275, 2)
# (275, 4)

# %%
df_paises_Kyoto.head()
# Out:
# Country Group  Area Code         Country  Annex I countries
# 0                      1         Armenia                0.0
# 1                      2     Afghanistan                0.0
# 2                      3         Albania                0.0
# 3                      4         Algeria                0.0
# 4                      5  American Samoa                1.0

# %%
a.head(5)
# Out:
#    Area Code            Area         Country  Annex I countries
# 0          2     Afghanistan     Afghanistan                0.0
# 1          3         Albania         Albania                0.0
# 2          4         Algeria         Algeria                0.0
# 3          5  American Samoa  American Samoa                1.0
# 4          7          Angola          Angola                0.0

# %%
# hacemos merge con la información del Anexo I

print(X_processed.shape)
X_processed = pd.merge(X_processed, a, left_on="index", right_on= "Area", how="left")
print(X_processed.shape)
# Out:
# (205, 27)
# (205, 31)

# %%
X_processed.drop(["Area_y","Country"], axis="columns", inplace = True)
X_processed.head(1)
# Out:
#          index     AFOLU  Emissions on agricultural land    Energy  \
# 0  Afghanistan  0.433665                        0.432978  0.278978
#
#    Energy - food systems  Farm-gate emissions  Fertilizers Manufacturing  \
# 0               0.027891             0.432978                   0.000611
#
#    Food Household Consumption  Food Packaging  Food Processing  ...  \
# 0                    0.012786        0.000321         0.002079  ...
#
#    On-farm electricity use     Other  Pre- and post- production     Waste  \
# 0                 0.001155  0.002341                   0.116606  0.146425
#
#    Waste - food systems  cluster       Area_x    PIB_Cap  Area Code  \
# 0              0.092093        0  Afghanistan  469.91909          2
#
#    Annex I countries
# 0                0.0
#
# [1 rows x 29 columns]

# %%
plot = pd.crosstab(index=X_processed['cluster'], columns=X_processed['Annex I countries']).apply(lambda r: r/r.sum() *100,
                                              axis=1).plot(kind='bar')

# %%
X_processed[X_processed["Area_x"]=="China"]
# Out:
#     index     AFOLU  Emissions on agricultural land    Energy  \
# 39  China  0.012129                        0.540246  7.382154
#
#     Energy - food systems  Farm-gate emissions  Fertilizers Manufacturing  \
# 39               0.691875             0.540246                   0.089645
#
#     Food Household Consumption  Food Packaging  Food Processing  ...  \
# 39                    0.320241        0.075597         0.004406  ...
#
#     On-farm electricity use     Other  Pre- and post- production     Waste  \
# 39                 0.075067  0.043497                   0.752177  0.334761
#
#     Waste - food systems  cluster  Area_x       PIB_Cap  Area Code  \
# 39               0.14305        1   China  10238.512141        351
#
#     Annex I countries
# 39                0.0
#
# [1 rows x 29 columns]

# %% [markdown]
# Hemos conseguido un par de clusters con prácticamente todos sus integrantes no están en el anexo I Kioto, creo que el anexo I son los países más industrializados, así que con pocas variables quedan definidos.

# %% [markdown]
# # Clustering en la tabla de Alimentos

# %% [markdown]
# ## Tabla de Alimentos

# %%
agrup_prod = pd.read_csv("/content/drive/MyDrive/Formació/MASTER NUCLIO/Capstone Project/datasets/Agrupacion productos FoodBalanceSheets.csv")
agrup_prod
# Out:
#      Código Grupo de Productos      Grupo de Productos  Código Producto  \
# 0                         2905  Cereales - Exc Cerveza             2511
# 1                         2901              Gran Total             2511
# 2                         2903     Productos Vegetales             2511
# 3                         2905  Cereales - Exc Cerveza             2807
# 4                         2901              Gran Total             2807
# ..                         ...                     ...              ...
# 289                       2928              Miscelaneo             2680
# 290                       2903     Productos Vegetales             2680
# 291                       2901              Gran Total             2899
# 292                       2928              Miscelaneo             2899
# 293                       2903     Productos Vegetales             2899
#
#                  Producto  Coeficiente  Código HS  Código HS07  Código HS12  \
# 0       Trigo y productos            1        NaN          NaN          NaN
# 1       Trigo y productos            1        NaN          NaN          NaN
# 2       Trigo y productos            1        NaN          NaN          NaN
# 3       Arroz y productos            1        NaN          NaN          NaN
# 4       Arroz y productos            1        NaN          NaN          NaN
# ..                    ...          ...        ...          ...          ...
# 289  Alimentos infantiles            1        NaN          NaN          NaN
# 290  Alimentos infantiles            1        NaN          NaN          NaN
# 291            Miscelaneo            1        NaN          NaN          NaN
# 292            Miscelaneo            1        NaN          NaN          NaN
# 293            Miscelaneo            1        NaN          NaN          NaN
#
#     Código CPC
# 0        S2511
# 1        S2511
# 2        S2511
# 3        S2807
# 4        S2807
# ..         ...
# 289      S2680
# 290      S2680
# 291      S2899
# 292      S2899
# 293      S2899
#
# [294 rows x 9 columns]

# %%
ls_prod_veg = list(agrup_prod[agrup_prod["Grupo de Productos"]=="Productos Vegetales"]["Código Producto"])
ls_prod_anim = list(agrup_prod[agrup_prod["Grupo de Productos"]=="Productos Animales"]["Código Producto"])

# %%
ls_prod_anim
# Out:
# [2731,
#  2732,
#  2733,
#  2734,
#  2735,
#  2736,
#  2740,
#  2743,
#  2737,
#  2781,
#  2782,
#  2744,
#  2848,
#  2761,
#  2762,
#  2763,
#  2764,
#  2765,
#  2766,
#  2767,
#  2768,
#  2769,
#  2775]

# %%
df_alim.columns
# Out:
# Index(['Area', 'Item Code', 'Item', 'Element Code', 'Element', 'Year Code',
#        'Year', 'Unit', 'Value', 'Flag'],
#       dtype='object')

# %%
df_alim.isnull().sum()
# Out:
# Area Code            0
# Area                 0
# Item Code            0
# Item                 0
# Element Code         0
# Element              0
# Year Code            0
# Year                 0
# Unit                 0
# Value           106668
# Flag                 0
# dtype: int64

# %%
df_alim["Item Code"].hist()

# %%
# Miramos qué agrupaciones de alimentos tenemos

df_alim[df_alim["Item Code"]>2700]["Item"].unique()
# Out:
# array(['Grand Total', 'Vegetal Products', 'Animal Products',
#        'Cereals - Excluding Beer', 'Rice and products', 'Starchy Roots',
#        'Sugar Crops', 'Sugar & Sweeteners', 'Honey', 'Pulses', 'Treenuts',
#        'Oilcrops', 'Vegetable Oils', 'Vegetables',
#        'Fruits - Excluding Wine', 'Stimulants', 'Spices',
#        'Alcoholic Beverages', 'Meat', 'Bovine Meat', 'Mutton & Goat Meat',
#        'Pigmeat', 'Poultry Meat', 'Meat, Other', 'Offals',
#        'Offals, Edible', 'Animal fats', 'Butter, Ghee', 'Cream',
#        'Fats, Animals, Raw', 'Eggs', 'Milk - Excluding Butter',
#        'Fish, Seafood', 'Freshwater Fish', 'Miscellaneous',
#        'Fish, Body Oil', 'Fish, Liver Oil', 'Demersal Fish',
#        'Pelagic Fish', 'Marine Fish, Other', 'Crustaceans', 'Cephalopods',
#        'Molluscs, Other', 'Aquatic Products, Other',
#        'Aquatic Animals, Others', 'Aquatic Plants',
#        'Meat, Aquatic Mammals'], dtype=object)

# %%
df_alim = df_alim.reset_index()

# %%
df_alim["Area Code"].hist()

# %%
df_alim.Element.unique()
# Out:
# array(['Total Population - Both sexes', 'Domestic supply quantity',
#        'Food supply (kcal/capita/day)',
#        'Protein supply quantity (g/capita/day)',
#        'Fat supply quantity (g/capita/day)', 'Production',
#        'Import Quantity', 'Stock Variation', 'Export Quantity', 'Feed',
#        'Seed', 'Losses', 'Processing', 'Other uses (non-food)',
#        'Tourist consumption', 'Residuals', 'Food',
#        'Food supply quantity (kg/capita/yr)'], dtype=object)

# %% [markdown]
# Nos fijamos en el año 2019 por ser el 2020 considerado un outlier debido a la pandemia.  Podríamos hacer un promedio de los últimos 5 años.

# %% [markdown]
# Se podría quizás hacer agrupación de Productos Animales y por otro lado los Vegetales y VEr si ha diferencias.

# %%
AÑO_CLUSTER = 2019
TARGET_ELEMENTS = ['Domestic supply quantity',
       'Production',
       'Import Quantity','Export Quantity', 'Feed',
       'Seed', 'Losses', 'Processing', 'Other uses (non-food)',
       'Tourist consumption', 'Residuals', 'Food']

# %%
# Seleccionamos el año 2019, y los Items sin agrupaciones ni la poblacion i Elemets escogidos. Sólo países, no agrupaciones.

df_alim_2019_select = df_alim[(df_alim['Item Code'] < 2900) & (df_alim['Item Code'] > 2501) & (df_alim["Year"]== AÑO_CLUSTER) & (df_alim['Element'].isin(TARGET_ELEMENTS)) & (df_alim["Area Code"]<1000) ]

# %%
 #df_alim[df_alim['Item']=="Grand Total"].Element.unique()
 #df_alim[df_alim['Item'].isin(TARGET_ITEMS)].Element.unique()
 #df_alim[df_alim['Element Code']==664].Item.unique()

# %%
df_alim_2019_select.Item.sort_values().unique()
# Out:
# array(['Alcohol, Non-Food', 'Apples and products',
#        'Aquatic Animals, Others', 'Aquatic Plants', 'Bananas',
#        'Barley and products', 'Beans', 'Beer', 'Beverages, Alcoholic',
#        'Beverages, Fermented', 'Bovine Meat', 'Butter, Ghee',
#        'Cassava and products', 'Cephalopods', 'Cereals, Other',
#        'Citrus, Other', 'Cloves', 'Cocoa Beans and products',
#        'Coconut Oil', 'Coconuts - Incl Copra', 'Coffee and products',
#        'Cottonseed', 'Cottonseed Oil', 'Cream', 'Crustaceans', 'Dates',
#        'Demersal Fish', 'Eggs', 'Fats, Animals, Raw', 'Fish, Body Oil',
#        'Fish, Liver Oil', 'Freshwater Fish', 'Fruits, other',
#        'Grapefruit and products', 'Grapes and products (excl wine)',
#        'Groundnut Oil', 'Groundnuts', 'Honey', 'Infant food',
#        'Lemons, Limes and products', 'Maize Germ Oil',
#        'Maize and products', 'Marine Fish, Other',
#        'Meat, Aquatic Mammals', 'Meat, Other', 'Milk - Excluding Butter',
#        'Millet and products', 'Miscellaneous', 'Molluscs, Other',
#        'Mutton & Goat Meat', 'Nuts and products', 'Oats',
#        'Offals, Edible', 'Oilcrops Oil, Other', 'Oilcrops, Other',
#        'Olive Oil', 'Olives (including preserved)', 'Onions',
#        'Oranges, Mandarines', 'Palm Oil', 'Palm kernels',
#        'Palmkernel Oil', 'Peas', 'Pelagic Fish', 'Pepper', 'Pigmeat',
#        'Pimento', 'Pineapples and products', 'Plantains',
#        'Potatoes and products', 'Poultry Meat',
#        'Pulses, Other and products', 'Rape and Mustard Oil',
#        'Rape and Mustardseed', 'Rice and products', 'Ricebran Oil',
#        'Roots, Other', 'Rye and products', 'Sesame seed',
#        'Sesameseed Oil', 'Sorghum and products', 'Soyabean Oil',
#        'Soyabeans', 'Spices, Other', 'Sugar (Raw Equivalent)',
#        'Sugar beet', 'Sugar cane', 'Sugar non-centrifugal',
#        'Sunflower seed', 'Sunflowerseed Oil', 'Sweet potatoes',
#        'Sweeteners, Other', 'Tea (including mate)',
#        'Tomatoes and products', 'Vegetables, other', 'Wheat and products',
#        'Wine', 'Yams'], dtype=object)

# %%
# Comprobamos que ha cogido bien el Elemento

df_alim_2019_select.Element.unique()
# Out:
# array(['Production', 'Import Quantity', 'Export Quantity',
#        'Domestic supply quantity', 'Feed', 'Seed', 'Losses', 'Residuals',
#        'Food', 'Other uses (non-food)', 'Processing',
#        'Tourist consumption'], dtype=object)

# %%
df_alim_2019_select.isnull().sum()
# Out:
# Area Code       0
# Area            0
# Item Code       0
# Item            0
# Element Code    0
# Element         0
# Year Code       0
# Year            0
# Unit            0
# Value           0
# Flag            0
# dtype: int64

# %%
df_alim_2019_select["Area Code"].hist()

# %%
df_alim_2019_select.head()
# Out:
#      Area Code         Area  Item Code                Item  Element Code  \
# 285          2  Afghanistan       2511  Wheat and products          5511
# 295          2  Afghanistan       2511  Wheat and products          5611
# 311          2  Afghanistan       2511  Wheat and products          5911
# 321          2  Afghanistan       2511  Wheat and products          5301
# 331          2  Afghanistan       2511  Wheat and products          5521
#
#                       Element  Year Code  Year         Unit   Value Flag
# 285                Production       2019  2019  1000 tonnes  4890.0   Im
# 295           Import Quantity       2019  2019  1000 tonnes  2526.0   Im
# 311           Export Quantity       2019  2019  1000 tonnes     0.0   Im
# 321  Domestic supply quantity       2019  2019  1000 tonnes  7519.0    S
# 331                      Feed       2019  2019  1000 tonnes   249.0   Im

# %%
# Comprobamos las unidades

df_alim_2019_select.Unit.unique()
# Out:
# array(['1000 tonnes'], dtype=object)

# %%
# Comprobamos nulos

df_alim_2019_select.isnull().sum()
# Out:
# Area Code       0
# Area            0
# Item Code       0
# Item            0
# Element Code    0
# Element         0
# Year Code       0
# Year            0
# Unit            0
# Value           0
# Flag            0
# dtype: int64

# %%
# Hacemos pivot table para poner los Items como columnas

df_alim_2019_select_transp = df_alim_2019_select.pivot_table(index="Area",columns="Element",values="Value",aggfunc="sum")
df_alim_2019_select_transp.head(1)
# Out:
# Element      Domestic supply quantity  Export Quantity   Feed     Food  \
# Area
# Afghanistan                   17996.0           1151.0  515.0  14764.0
#
# Element      Import Quantity  Losses  Other uses (non-food)  Processing  \
# Area
# Afghanistan           5039.0  1375.0                   37.0       955.0
#
# Element      Production  Residuals   Seed  Tourist consumption
# Area
# Afghanistan     13999.0     -164.0  510.0                  NaN

# %%
# Out:
# 17996.0

# %%
# Miramos nulos

df_alim_2019_select_transp.isnull().sum()
# Out:
# Element
# Domestic supply quantity      0
# Export Quantity               0
# Feed                          0
# Food                          0
# Import Quantity               0
# Losses                        0
# Other uses (non-food)         0
# Processing                    0
# Production                    0
# Residuals                     0
# Seed                          0
# Tourist consumption         137
# dtype: int64

# %%
# Quitamos la variable "Tourist Consumption" porque es donde hay más nulos.

df_alim_2019_select_transp.drop("Tourist consumption", axis="columns", inplace=True)

# %%
#df_alim[(df_alim['Item Code'] < 2900) & (df_alim['Item Code'] > 2501) & (df_alim['Element']=="Tourist consumption") & (df_alim["Area"]=="Spain") & (df_alim["Value"]>0) ]
df_alim[(df_alim['Item Code'] < 2900) & (df_alim['Item Code'] > 2501) & (df_alim['Element']=="Tourist consumption") & (df_alim["Area"]=="Spain") & (df_alim["Value"]>0) ]
# Out:
# Empty DataFrame
# Columns: [Area Code, Area, Item Code, Item, Element Code, Element, Year Code, Year, Unit, Value, Flag]
# Index: []

# %%
# Out:
# Index(['Antigua and Barbuda', 'Bahamas', 'Barbados', 'Belgium', 'Belize',
#        'Botswana', 'Cabo Verde', 'Cambodia', 'China', 'China, Hong Kong SAR',
#        'China, Macao SAR', 'Comoros', 'Costa Rica', 'Croatia', 'Cuba',
#        'Cyprus', 'Czechia', 'Dominica', 'Dominican Republic', 'Egypt',
#        'Estonia', 'Fiji', 'France', 'French Polynesia', 'Germany', 'Greece',
#        'Grenada', 'Guatemala', 'Honduras', 'Hungary', 'Iceland', 'Indonesia',
#        'Ireland', 'Italy', 'Jamaica', 'Kenya', 'Kiribati',
#        'Lao People's Democratic Republic', 'Latvia', 'Lithuania', 'Luxembourg',
#        'Malaysia', 'Maldives', 'Malta', 'Mauritius', 'Nepal', 'Netherlands',
#        'New Caledonia', 'Romania', 'Saint Kitts and Nevis', 'Saint Lucia',
#        'Saint Vincent and the Grenadines', 'Samoa', 'Sao Tome and Principe',
#        'Seychelles', 'Slovenia', 'Solomon Islands', 'Spain', 'Sweden',
#        'Trinidad and Tobago',
#        'United Kingdom of Great Britain and Northern Ireland', 'Vanuatu'],
#       dtype='object', name='Area')

# %%
df_alim_2019_select_transp.shape
# Out:
# (179, 11)

# %%
# Observamos los nulos del dataset entero, a ver si vemos algo interesante 


df_turism_cons = df_alim[(df_alim['Item Code'] < 2900) & (df_alim['Item Code'] > 2501) & (df_alim['Element']=="Tourist consumption") & (df_alim["Area Code"]<1000) ]
df_turism_cons_tran = df_turism_cons.pivot_table(index="Year",columns="Area",values="Value",aggfunc="sum")
gb_df_ = df_turism_cons_tran.isnull()
order_of_columns = list(gb_df_.sum().sort_values().index)
gb_df_ = gb_df_[order_of_columns]

plt.figure(figsize = (20, 10))
plot = sns.heatmap(gb_df_, cbar = True, cmap = "inferno")
plot.set_title("Null sales by item_id and day");

# %% [markdown]
# PAra rellenar los nulos podríamos usar la media, pero como hay tantos países, eliminamos la variable

# %% [markdown]
# La base de dataos iniciano no tenía nulos. SE han creado con la pivot_table

# %%
# cuantas filas tenemos?
df_alim_2019_select_transp.shape
# Out:
# (179, 11)

# %%
df_clust = df_alim_2019_select_transp

# %%
print(df_clust.shape)
# Out:
# (179, 11)

# %%
df_pop.Element.unique()
# Out:
# array(['Total Population - Both sexes', 'Total Population - Male',
#        'Total Population - Female', 'Rural population',
#        'Urban population'], dtype=object)

# %%
# Hay agrupaciones de paises? Si

df_pop["Area Code"].hist()

# %%
df_pop_both_2019 = df_pop[(df_pop.Element == 'Total Population - Both sexes') & (df_pop.Year == 2019) & (df_pop["Area Code"] < 1000)]
print(df_pop_both_2019.shape)
# Out:
# (237, 12)

# %%
df_pop_both_2019.columns
# Out:
# Index(['Area Code', 'Area', 'Item Code', 'Item', 'Element Code', 'Element',
#        'Year Code', 'Year', 'Unit', 'Value', 'Flag', 'Note'],
#       dtype='object')

# %%
df_pop_both_2019.head()
# Out:
#       Area Code            Area  Item Code                       Item  \
# 69            2     Afghanistan       3010  Population - Est. & Proj.
# 724           3         Albania       3010  Population - Est. & Proj.
# 1379          4         Algeria       3010  Population - Est. & Proj.
# 2034          5  American Samoa       3010  Population - Est. & Proj.
# 2387          6         Andorra       3010  Population - Est. & Proj.
#
#       Element Code                        Element  Year Code  Year  \
# 69             511  Total Population - Both sexes       2019  2019
# 724            511  Total Population - Both sexes       2019  2019
# 1379           511  Total Population - Both sexes       2019  2019
# 2034           511  Total Population - Both sexes       2019  2019
# 2387           511  Total Population - Both sexes       2019  2019
#
#               Unit      Value Flag  Note
# 69    1000 persons  38041.754    X   NaN
# 724   1000 persons   2880.917    X   NaN
# 1379  1000 persons  43053.054    X   NaN
# 2034  1000 persons     55.312    X   NaN
# 2387  1000 persons     77.142    X   NaN

# %%
# Hacemos pivot table

df_pop_both_2019_pivot = df_pop_both_2019.pivot_table(index="Area",columns="Element",values="Value",aggfunc="mean")

# %%
df_pop_both_2019_pivot.head()
# Out:
# Element         Total Population - Both sexes
# Area
# Afghanistan                         38041.754
# Albania                              2880.917
# Algeria                             43053.054
# American Samoa                         55.312
# Andorra                                77.142

# %%
# Comprobamos la población de España
df_pop_both_2019_pivot.loc["Spain"]
# Out:
# Element
# Total Population - Both sexes    46736.776
# Name: Spain, dtype: float64

# %%
# En la tabla de poblacion hay más Areas que en la de Emisiones. Haremos un merge left de la tabla de emisiones, para que no falte ningun Area
print(df_clust.shape)
df_clust_pop_2019 = pd.merge(df_clust, df_pop_both_2019_pivot, on = "Area", how="left")
print(df_clust_pop_2019.shape)
# Out:
# (179, 11)
# (179, 12)

# %%
# Comprobamos si hay alguna fila que no se le ha podido asignar población.

df_clust_pop_2019[df_clust_pop_2019["Total Population - Both sexes"].isnull()]
# Out:
# Empty DataFrame
# Columns: [Domestic supply quantity, Export Quantity, Feed, Food, Import Quantity, Losses, Other uses (non-food), Processing, Production, Residuals, Seed, Total Population - Both sexes]
# Index: []

# %%
df_clust_pop_2019.columns
# Out:
# Index(['Domestic supply quantity', 'Export Quantity', 'Feed', 'Food',
#        'Import Quantity', 'Losses', 'Other uses (non-food)', 'Processing',
#        'Production', 'Residuals', 'Seed', 'Total Population - Both sexes'],
#       dtype='object', name='Element')

# %% [markdown]
# Comprobamos la correlación entre ellos y eliminaremos columnas que sean combinaciones lineales de las demás.

# %%
corr = df_clust_pop_2019.corr()
corr.style.background_gradient(cmap="coolwarm")
# Out:
# <style type="text/css">
# #T_c79b4_row0_col0, #T_c79b4_row0_col8, #T_c79b4_row1_col1, #T_c79b4_row2_col2, #T_c79b4_row3_col3, #T_c79b4_row4_col4, #T_c79b4_row5_col5, #T_c79b4_row6_col6, #T_c79b4_row7_col7, #T_c79b4_row8_col0, #T_c79b4_row8_col8, #T_c79b4_row9_col9, #T_c79b4_row10_col10, #T_c79b4_row11_col11 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_c79b4_row0_col1 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_c79b4_row0_col2, #T_c79b4_row11_col8 {
#   background-color: #c83836;
#   color: #f1f1f1;
# }
# #T_c79b4_row0_col3, #T_c79b4_row5_col8, #T_c79b4_row8_col5, #T_c79b4_row11_col3 {
#   background-color: #be242e;
#   color: #f1f1f1;
# }
# #T_c79b4_row0_col4 {
#   background-color: #e0654f;
#   color: #f1f1f1;
# }
# #T_c79b4_row0_col5 {
#   background-color: #c12b30;
#   color: #f1f1f1;
# }
# #T_c79b4_row0_col6 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_c79b4_row0_col7, #T_c79b4_row0_col10, #T_c79b4_row7_col10 {
#   background-color: #e9785d;
#   color: #f1f1f1;
# }
# #T_c79b4_row0_col9 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_c79b4_row0_col11, #T_c79b4_row3_col2, #T_c79b4_row8_col3 {
#   background-color: #c53334;
#   color: #f1f1f1;
# }
# #T_c79b4_row1_col0 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_c79b4_row1_col2, #T_c79b4_row4_col1, #T_c79b4_row6_col7 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_c79b4_row1_col3 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_c79b4_row1_col4 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_c79b4_row1_col5 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_c79b4_row1_col6 {
#   background-color: #f5a081;
#   color: #000000;
# }
# #T_c79b4_row1_col7, #T_c79b4_row2_col7 {
#   background-color: #efcebd;
#   color: #000000;
# }
# #T_c79b4_row1_col8 {
#   background-color: #f0cdbb;
#   color: #000000;
# }
# #T_c79b4_row1_col9, #T_c79b4_row9_col0, #T_c79b4_row9_col1, #T_c79b4_row9_col2, #T_c79b4_row9_col3, #T_c79b4_row9_col4, #T_c79b4_row9_col5, #T_c79b4_row9_col6, #T_c79b4_row9_col7, #T_c79b4_row9_col8, #T_c79b4_row9_col10, #T_c79b4_row9_col11 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_c79b4_row1_col10 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_c79b4_row1_col11 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_c79b4_row2_col0 {
#   background-color: #cb3e38;
#   color: #f1f1f1;
# }
# #T_c79b4_row2_col1 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_c79b4_row2_col3, #T_c79b4_row3_col8 {
#   background-color: #c73635;
#   color: #f1f1f1;
# }
# #T_c79b4_row2_col4 {
#   background-color: #cd423b;
#   color: #f1f1f1;
# }
# #T_c79b4_row2_col5 {
#   background-color: #e16751;
#   color: #f1f1f1;
# }
# #T_c79b4_row2_col6 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_c79b4_row2_col8 {
#   background-color: #d0473d;
#   color: #f1f1f1;
# }
# #T_c79b4_row2_col9 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_c79b4_row2_col10 {
#   background-color: #f6a385;
#   color: #000000;
# }
# #T_c79b4_row2_col11, #T_c79b4_row8_col7 {
#   background-color: #e26952;
#   color: #f1f1f1;
# }
# #T_c79b4_row3_col0, #T_c79b4_row3_col11, #T_c79b4_row5_col0 {
#   background-color: #c0282f;
#   color: #f1f1f1;
# }
# #T_c79b4_row3_col1 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_c79b4_row3_col4, #T_c79b4_row3_col5 {
#   background-color: #d95847;
#   color: #f1f1f1;
# }
# #T_c79b4_row3_col6 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_c79b4_row3_col7 {
#   background-color: #f7b396;
#   color: #000000;
# }
# #T_c79b4_row3_col9 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_c79b4_row3_col10 {
#   background-color: #ec7f63;
#   color: #f1f1f1;
# }
# #T_c79b4_row4_col0, #T_c79b4_row7_col0 {
#   background-color: #e36b54;
#   color: #f1f1f1;
# }
# #T_c79b4_row4_col2, #T_c79b4_row8_col2 {
#   background-color: #cc403a;
#   color: #f1f1f1;
# }
# #T_c79b4_row4_col3, #T_c79b4_row5_col2 {
#   background-color: #dc5d4a;
#   color: #f1f1f1;
# }
# #T_c79b4_row4_col5 {
#   background-color: #f39577;
#   color: #000000;
# }
# #T_c79b4_row4_col6 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_c79b4_row4_col7 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_c79b4_row4_col8, #T_c79b4_row8_col10 {
#   background-color: #e7745b;
#   color: #f1f1f1;
# }
# #T_c79b4_row4_col9 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_c79b4_row4_col10, #T_c79b4_row8_col6 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_c79b4_row4_col11, #T_c79b4_row10_col3 {
#   background-color: #ee8669;
#   color: #f1f1f1;
# }
# #T_c79b4_row5_col1, #T_c79b4_row7_col4 {
#   background-color: #f5c4ac;
#   color: #000000;
# }
# #T_c79b4_row5_col3 {
#   background-color: #d75445;
#   color: #f1f1f1;
# }
# #T_c79b4_row5_col4, #T_c79b4_row11_col7 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_c79b4_row5_col6 {
#   background-color: #f49a7b;
#   color: #000000;
# }
# #T_c79b4_row5_col7 {
#   background-color: #e97a5f;
#   color: #f1f1f1;
# }
# #T_c79b4_row5_col9 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_c79b4_row5_col10 {
#   background-color: #f59c7d;
#   color: #000000;
# }
# #T_c79b4_row5_col11, #T_c79b4_row7_col8, #T_c79b4_row11_col2 {
#   background-color: #dd5f4b;
#   color: #f1f1f1;
# }
# #T_c79b4_row6_col0 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_c79b4_row6_col1 {
#   background-color: #f29274;
#   color: #f1f1f1;
# }
# #T_c79b4_row6_col2, #T_c79b4_row10_col1 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_c79b4_row6_col3 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_c79b4_row6_col4 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_c79b4_row6_col5 {
#   background-color: #f59f80;
#   color: #000000;
# }
# #T_c79b4_row6_col8 {
#   background-color: #f5c1a9;
#   color: #000000;
# }
# #T_c79b4_row6_col9 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_c79b4_row6_col10 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_c79b4_row6_col11 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_c79b4_row7_col1 {
#   background-color: #f7ac8e;
#   color: #000000;
# }
# #T_c79b4_row7_col2 {
#   background-color: #f7b093;
#   color: #000000;
# }
# #T_c79b4_row7_col3 {
#   background-color: #f59d7e;
#   color: #000000;
# }
# #T_c79b4_row7_col5 {
#   background-color: #e57058;
#   color: #f1f1f1;
# }
# #T_c79b4_row7_col6 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_c79b4_row7_col9 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_c79b4_row7_col11, #T_c79b4_row10_col8, #T_c79b4_row11_col4 {
#   background-color: #eb7d62;
#   color: #f1f1f1;
# }
# #T_c79b4_row8_col1 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_c79b4_row8_col4 {
#   background-color: #e46e56;
#   color: #f1f1f1;
# }
# #T_c79b4_row8_col9 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_c79b4_row8_col11 {
#   background-color: #ca3b37;
#   color: #f1f1f1;
# }
# #T_c79b4_row10_col0 {
#   background-color: #ec8165;
#   color: #f1f1f1;
# }
# #T_c79b4_row10_col2 {
#   background-color: #f6a283;
#   color: #000000;
# }
# #T_c79b4_row10_col4 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_c79b4_row10_col5 {
#   background-color: #f7a98b;
#   color: #000000;
# }
# #T_c79b4_row10_col6 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_c79b4_row10_col7 {
#   background-color: #f29072;
#   color: #f1f1f1;
# }
# #T_c79b4_row10_col9 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_c79b4_row10_col11 {
#   background-color: #df634e;
#   color: #f1f1f1;
# }
# #T_c79b4_row11_col0 {
#   background-color: #c43032;
#   color: #f1f1f1;
# }
# #T_c79b4_row11_col1 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_c79b4_row11_col5 {
#   background-color: #de614d;
#   color: #f1f1f1;
# }
# #T_c79b4_row11_col6 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_c79b4_row11_col9 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_c79b4_row11_col10 {
#   background-color: #da5a49;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c79b4_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Element</th>
#       <th class="col_heading level0 col0" >Domestic supply quantity</th>
#       <th class="col_heading level0 col1" >Export Quantity</th>
#       <th class="col_heading level0 col2" >Feed</th>
#       <th class="col_heading level0 col3" >Food</th>
#       <th class="col_heading level0 col4" >Import Quantity</th>
#       <th class="col_heading level0 col5" >Losses</th>
#       <th class="c

# %% [markdown]
# Hay bastante correlación en algunas, com en la producción con la "Domestic Supply", lo que indicaría que un gran porcentage de la producción es para connsumo propio. Tendríamos de todos modos ver las variables por cápita porque puede ser que cuanta más gente hay en el país, más consume y más produce.

# %% [markdown]
# Dividimos todas las columnas por la población. Lo hacemos de una forma un tanto rara... no sé hacerlo de otra forma, pero funciona. En la misma instrucción eliminamos la variable de la población.

# %%
df_clust_pop_2019_per_cap = (df_clust_pop_2019.T / df_clust_pop_2019["Total Population - Both sexes"]).T.drop("Total Population - Both sexes",axis="columns")

# %%
corr = df_clust_pop_2019_per_cap.corr()
corr.style.background_gradient(cmap="coolwarm")
# Out:
# <style type="text/css">
# #T_f375f_row0_col0, #T_f375f_row1_col1, #T_f375f_row2_col2, #T_f375f_row3_col3, #T_f375f_row4_col4, #T_f375f_row5_col5, #T_f375f_row6_col6, #T_f375f_row7_col7, #T_f375f_row8_col8, #T_f375f_row9_col9, #T_f375f_row10_col10 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_f375f_row0_col1, #T_f375f_row8_col2 {
#   background-color: #f6bfa6;
#   color: #000000;
# }
# #T_f375f_row0_col2 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_f375f_row0_col3 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_f375f_row0_col4, #T_f375f_row4_col7, #T_f375f_row5_col1 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_f375f_row0_col5 {
#   background-color: #f7a889;
#   color: #000000;
# }
# #T_f375f_row0_col6, #T_f375f_row1_col10, #T_f375f_row2_col7 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_f375f_row0_col7, #T_f375f_row7_col0 {
#   background-color: #d65244;
#   color: #f1f1f1;
# }
# #T_f375f_row0_col8 {
#   background-color: #ca3b37;
#   color: #f1f1f1;
# }
# #T_f375f_row0_col9 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_f375f_row0_col10 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_f375f_row1_col0 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_f375f_row1_col2 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_f375f_row1_col3, #T_f375f_row10_col3 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_f375f_row1_col4 {
#   background-color: #f5c4ac;
#   color: #000000;
# }
# #T_f375f_row1_col5 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_f375f_row1_col6 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_f375f_row1_col7 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_f375f_row1_col8 {
#   background-color: #ee8468;
#   color: #f1f1f1;
# }
# #T_f375f_row1_col9 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_f375f_row2_col0 {
#   background-color: #f7b396;
#   color: #000000;
# }
# #T_f375f_row2_col1 {
#   background-color: #f4c5ad;
#   color: #000000;
# }
# #T_f375f_row2_col3 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_f375f_row2_col4, #T_f375f_row4_col0 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_f375f_row2_col5 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_f375f_row2_col6 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_f375f_row2_col8, #T_f375f_row8_col5 {
#   background-color: #f7b194;
#   color: #000000;
# }
# #T_f375f_row2_col9, #T_f375f_row9_col4 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_f375f_row2_col10 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# #T_f375f_row3_col0, #T_f375f_row6_col0 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_f375f_row3_col1 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_f375f_row3_col2 {
#   background-color: #f7b599;
#   color: #000000;
# }
# #T_f375f_row3_col4 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_f375f_row3_col5 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_f375f_row3_col6 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_f375f_row3_col7, #T_f375f_row10_col5 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_f375f_row3_col8 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_f375f_row3_col9 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_f375f_row3_col10 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_f375f_row4_col1 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_f375f_row4_col2, #T_f375f_row10_col0 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_f375f_row4_col3, #T_f375f_row8_col3 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_f375f_row4_col5 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_f375f_row4_col6 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_f375f_row4_col8 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_f375f_row4_col9, #T_f375f_row5_col10 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_f375f_row4_col10, #T_f375f_row10_col9 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_f375f_row5_col0 {
#   background-color: #f6a586;
#   color: #000000;
# }
# #T_f375f_row5_col2, #T_f375f_row6_col7 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_f375f_row5_col3 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_f375f_row5_col4, #T_f375f_row8_col9, #T_f375f_row9_col0, #T_f375f_row9_col1, #T_f375f_row9_col2, #T_f375f_row9_col3, #T_f375f_row9_col5, #T_f375f_row9_col6, #T_f375f_row9_col7, #T_f375f_row9_col8, #T_f375f_row9_col10 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_f375f_row5_col6 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_f375f_row5_col7, #T_f375f_row10_col2 {
#   background-color: #f5c1a9;
#   color: #000000;
# }
# #T_f375f_row5_col8 {
#   background-color: #f7a98b;
#   color: #000000;
# }
# #T_f375f_row5_col9 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_f375f_row6_col1 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_f375f_row6_col2 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_f375f_row6_col3 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_f375f_row6_col4 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_f375f_row6_col5 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_f375f_row6_col8 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_f375f_row6_col9, #T_f375f_row7_col10 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_f375f_row6_col10 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_f375f_row7_col1 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_f375f_row7_col2 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_f375f_row7_col3 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_f375f_row7_col4 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_f375f_row7_col5 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_f375f_row7_col6 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_f375f_row7_col8 {
#   background-color: #e36b54;
#   color: #f1f1f1;
# }
# #T_f375f_row7_col9 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_f375f_row8_col0 {
#   background-color: #cb3e38;
#   color: #f1f1f1;
# }
# #T_f375f_row8_col1 {
#   background-color: #f08b6e;
#   color: #f1f1f1;
# }
# #T_f375f_row8_col4 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_f375f_row8_col6 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_f375f_row8_col7 {
#   background-color: #e36c55;
#   color: #f1f1f1;
# }
# #T_f375f_row8_col10 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_f375f_row10_col1 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_f375f_row10_col4 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_f375f_row10_col6 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_f375f_row10_col7 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_f375f_row10_col8 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# </style>
# <table id="T_f375f_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Element</th>
#       <th class="col_heading level0 col0" >Domestic supply quantity</th>
#       <th class="col_heading level0 col1" >Export Quantity</th>
#       <th class="col_heading level0 col2" >Feed</th>
#       <th class="col_heading level0 col3" >Food</th>
#       <th class="col_heading level0 col4" >Import Quantity</th>
#       <th class="col_heading level0 col5" >Losses</th>
#       <th class="col_heading level0 col6" >Other uses (non-food)</th>
#       <th class="col_heading level0 col7" >Processing</th>
#       <th class="col_heading level0 col8" >Production</th>
#       <th class="col_heading level0 col9" >Residuals</th>
#       <th class="col_heading level0 col10" >Seed</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Element</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f375f_level0_row0" class="row_heading level0 row0" >Domestic suppl

# %% [markdown]
# Efectivamente ya no hay tanta correlación!!

# %%
# Otra forma de hacerlo sería con un for

#for col in df_emis_pop_2019.columns:
#   df_emis_pop_2019[col+"_per_cap"] = df_emis_pop_2019[col] / df_emis_pop_2019["Total Population - Both sexes"]

# %% [markdown]
# Las siguientes dos instrucciones eran para comprobar que dividía bien.

# %%
df_clust_pop_2019[:3]
# Out:
# Element      Domestic supply quantity  Export Quantity     Feed      Food  \
# Area
# Afghanistan                  17996.00          1151.00   515.00  14764.00
# Albania                       4956.07           176.02   724.17   3456.90
# Algeria                      46658.71           699.27  5512.00  33425.66
#
# Element      Import Quantity  Losses  Other uses (non-food)  Processing  \
# Area
# Afghanistan          5039.00  1375.0                  37.00       955.0
# Albania               961.40   354.0                 134.00       234.0
# Algeria             16692.15  4080.0                2100.04      1109.0
#
# Element      Production  Residuals   Seed  Total Population - Both sexes
# Area
# Afghanistan    13999.00     -164.0  510.0                      38041.754
# Albania         4244.70       -2.0   51.0                       2880.917
# Algeria        31153.83       -3.0  438.0                      43053.054

# %%
df_clust_pop_2019_per_cap[:3]
# Out:
# Element      Domestic supply quantity  Export Quantity      Feed      Food  \
# Area
# Afghanistan                  0.473059         0.030256  0.013538  0.388100
# Albania                      1.720310         0.061099  0.251368  1.199930
# Algeria                      1.083749         0.016242  0.128028  0.776383
#
# Element      Import Quantity    Losses  Other uses (non-food)  Processing  \
# Area
# Afghanistan         0.132460  0.036144               0.000973    0.025104
# Albania             0.333713  0.122878               0.046513    0.081224
# Algeria             0.387711  0.094767               0.048778    0.025759
#
# Element      Production  Residuals      Seed
# Area
# Afghanistan    0.367990  -0.004311  0.013406
# Albania        1.473385  -0.000694  0.017703
# Algeria        0.723615  -0.000070  0.010173

# %%
df_final = df_clust_pop_2019_per_cap.copy(deep = True)
columns = list(df_final.columns)
index = list(df_final.index)
cols_to_filter = list(df_final.columns)

# %%
# separamos el pipeline del a loop, para no tener que volver a hacer los primeros 5 pasos para cada k de la loop
pipe = Pipeline(steps = [
#    ("Imputer", KNNImputer()),    ## En este caso no tenemos nulos a imputar
    ("ArrayToDataFrame", ArrayToDataFrame(columns, index = index)),
#    ("FeatureGenerator", FeatureGenerator()),
    ("OutlierFilter", OutlierFilter(q = 0.99, col_to_filter = cols_to_filter)),
    ("StandardScaler", StandardScaler())
])

# %%
df_scaled_transformed_no_outliers = pipe.fit_transform(df_final)

# %%
CALCULATE_ELBOW = True

if CALCULATE_ELBOW:
    st = time.time()

    sse = {}

    for k in range(2, 15):

        print(f"Fitting pipe with {k} clusters")

        clustering_model = KMeans(n_clusters = k)

        clustering_model.fit(df_scaled_transformed_no_outliers)

        sse[k] = clustering_model.inertia_

    et = time.time()
    print("Elbow curve took {} minutes.".format(round((et - st)/60), 2))
# Out:
# Fitting pipe with 2 clusters
# Fitting pipe with 3 clusters
# Fitting pipe with 4 clusters
# Fitting pipe with 5 clusters
# Fitting pipe with 6 clusters
# Fitting pipe with 7 clusters
# Fitting pipe with 8 clusters
# Fitting pipe with 9 clusters
# Fitting pipe with 10 clusters
# Fitting pipe with 11 clusters
# Fitting pipe with 12 clusters
# Fitting pipe with 13 clusters
# Fitting pipe with 14 clusters
# Elbow curve took 0 minutes.

# %%
if CALCULATE_ELBOW:
    fig = plt.figure(figsize = (16, 8))
    ax = fig.add_subplot()

    x_values = list(sse.keys())
    y_values = list(sse.values())

    ax.plot(x_values, y_values, label = "Inertia/dispersión de los clústers")
    fig.suptitle("Variación de la dispersión de los clústers en función de la k", fontsize = 16);

# %% [markdown]
# La curba no acaba de hacer forma de codo. Quizás deberíamos usar variables de diferentes datasets.

# %%
# Creamos de nuevo el pipeline usando 3 clusters

n_clusters = 4

pipe = Pipeline(steps = [
#    ("Imputer", KNNImputer()),
    ("ArrayToDataFrame", ArrayToDataFrame(columns, index = index)),
#    ("FeatureGenerator", FeatureGenerator()),
    ("OutlierFilter", OutlierFilter(q = 0.99, col_to_filter = cols_to_filter)),
    ("StandardScaler", StandardScaler()),
    ("Clustering", KMeans(n_clusters = n_clusters))
])

# %%
df_final.shape
# Out:
# (179, 11)

# %%
pipe.fit(df_final)
# Out:
# Pipeline(steps=[('ArrayToDataFrame',
#                  ArrayToDataFrame(columns=['Domestic supply quantity',
#                                            'Export Quantity', 'Feed', 'Food',
#                                            'Import Quantity', 'Losses',
#                                            'Other uses (non-food)',
#                                            'Processing', 'Production',
#                                            'Residuals', 'Seed'],
#                                   index=['Afghanistan', 'Albania', 'Algeria',
#                                          'Angola', 'Antigua and Barbuda',
#                                          'Argentina', 'Armenia', 'Australia',
#                                          'Austria', 'Azerbaijan', 'Bahamas',
#                                          '...
#                                          'Burundi', 'Cabo Verde', 'Cambodia',
#                                          'Cameroon', 'Canada',
#                                          'Central African Republic', 'Chad', ...])),
#                 ('OutlierFilter',
#                  OutlierFilter(col_to_filter=['Domestic supply quantity',
#                                               'Export Quantity', 'Feed', 'Food',
#                                               'Import Quantity', 'Losses',
#                                               'Other uses (non-food)',
#                                               'Processing', 'Production',
#                                               'Residuals', 'Seed'],
#                                q=0.99)),
#                 ('StandardScaler', StandardScaler()),
#                 ('Clustering', KMeans(n_clusters=4))])

# %%
# creamos un dataframe escalado con los pasos 1, 3 y 5
X_processed = pipe[:1].transform(df_final)
X_scaled = pipe["StandardScaler"].transform(X_processed)

X_scaled.shape
# Out:
# (179, 11)

# %%
# hacemos el predict, en este caso tendremos para cada cliente su centroide/clúster.
print(pipe["Clustering"].predict(X_scaled)[:20])
labels = pipe["Clustering"].predict(X_scaled)
# Out:
# [0 3 3 0 0 1 3 1 2 3 0 0 0 2 2 1 3 3 3 0]

# %%
pd.Series(labels).value_counts()
# Out:
# 0    71
# 3    57
# 2    29
# 1    22
# dtype: int64

# %%
# cuantos hay de cada grupo

plt.hist(labels,bins=n_clusters)
# Out:
# (array([71., 22., 29., 57.]),
#  array([0.  , 0.75, 1.5 , 2.25, 3.  ]),
#  <a list of 4 Patch objects>)

# %%
# le asignamos al DataFrame procesado los centroides. (antes del escalado de variable)
# SI LO HACEMOS AL ESCALADO LOS NÚMEROS PERDERAN SU SIGNIFICADO ESCALA Y SERÁN MÁS DÍFICILES DE INTERPRETAR.
X_processed["cluster"] = labels

# %%
X_processed.shape
# Out:
# (179, 12)

# %%
X_processed.columns
# Out:
# Index(['Domestic supply quantity', 'Export Quantity', 'Feed', 'Food',
#        'Import Quantity', 'Losses', 'Other uses (non-food)', 'Processing',
#        'Production', 'Residuals', 'Seed', 'cluster'],
#       dtype='object')

# %%
# visualizamos nuestros grupos en base a las variables del modelo RFM, para ver que tal han quedado.

for col in X_processed.columns[:-1]:
  print(col)
  plt.figure(figsize=(15,5))
  sns.boxplot(
    data = X_processed, 
    x = 'cluster',
    y = col
)
# Out:
# Domestic supply quantity
# Export Quantity
# Feed
# Food
# Import Quantity
# Losses
# Other uses (non-food)
# Processing
# Production
# Residuals
# Seed

# %%
X_processed.columns
# Out:
# Index(['Domestic supply quantity', 'Export Quantity', 'Feed', 'Food',
#        'Import Quantity', 'Losses', 'Other uses (non-food)', 'Processing',
#        'Production', 'Residuals', 'Seed', 'cluster'],
#       dtype='object')

# %%
# visualizbamos nuestros grupos en base a las variables del modelo RFM, para ver que tal han quedado.
selected_columns = ['Production', 'Domestic supply quantity', 'Export Quantity','Import Quantity']

sns.pairplot(X_processed, vars = selected_columns, hue = 'cluster');

# %% [markdown]
# Consumo interno y producción son las vars que parecen más correladas

# %%
# visualizamos nuestros grupos en base a las variables del modelo RFM, para ver que tal han quedado.
selected_columns = ['Food', 'Other uses (non-food)', 'Domestic supply quantity']

sns.pairplot(X_processed, vars = selected_columns, hue = 'cluster');

# %% [markdown]
# Cluster 1: Los que más consumen per cápita. El cluster 0 los que menos consumen por cápita El cluser 3 está just despúes que el 0 en consumo doméstico

# %%
# Out:
#                                   index  Domestic supply quantity  \
# 0                           Afghanistan                  0.473059
# 1                               Albania                  1.720310
# 2                               Algeria                  1.083749
# 3                                Angola                  0.916322
# 4                   Antigua and Barbuda                  0.910336
# ..                                  ...                       ...
# 174  Venezuela (Bolivarian Republic of)                  0.743613
# 175                            Viet Nam                  1.188296
# 176                               Yemen                  0.341812
# 177                              Zambia                  0.875812
# 178                            Zimbabwe                  0.569385
#
#      Export Quantity      Feed      Food  Import Quantity    Losses  \
# 0           0.030256  0.013538  0.388100         0.132460  0.036144
# 1           0.061099  0.251368  1.199930         0.333713  0.122878
# 2           0.016242  0.128028  0.776383         0.387711  0.094767
# 3           0.003363  0.070775  0.624465         0.116097  0.103188
# 4           0.000927  0.000206  0.600198         0.734364  0.000000
# ..               ...       ...       ...              ...       ...
# 174         0.001301  0.065261  0.500729         0.177068  0.038540
# 175         0.295554  0.191603  0.700054         0.242224  0.090118
# 176         0.013059  0.018998  0.301396         0.232295  0.010562
# 177         0.030892  0.045845  0.422320         0.031374  0.045910
# 178         0.019450  0.003459  0.276345         0.032977  0.025742
#
#      Other uses (non-food)  Processing  Production  Residuals      Seed  \
# 0                 0.000973    0.025104    0.367990  -0.004311  0.013406
# 1                 0.046513    0.081224    1.473385  -0.000694  0.017703
# 2                 0.048778    0.025759    0.723615  -0.000070  0.010173
# 3                 0.005247    0.103251    0.790642   0.000000  0.009238
# 4                 0.021623    0.000000    0.197492   0.020594  0.000000
# ..                     ...         ...         ...        ...       ...
# 174               0.002177    0.138414    0.576156  -0.002385  0.000877
# 175               0.027674    0.179687    1.336927  -0.017147  0.016265
# 176               0.004856    0.005109    0.119004  -0.000686  0.001577
# 177               0.096523    0.265438    0.815703  -0.004815  0.004815
# 178               0.001506    0.282681    0.514890  -0.024513  0.004165
#
#      cluster
# 0          0
# 1          3
# 2          3
# 3          0
# 4          0
# ..       ...
# 174        0
# 175        3
# 176        0
# 177        0
# 178        0
#
# [179 rows x 13 columns]

# %%
# HAcemos un merge del PIB per cápita

AÑO_CLUSTER = 2019
df_PIB_Dol_Cap_2019 = df_PIB_Dol_Cap[df_PIB_Dol_Cap["Year"] == AÑO_CLUSTER][["Area", "Value"]]

print(X_processed.shape)
X_processed = pd.merge(X_processed.reset_index(), df_PIB_Dol_Cap_2019, left_on="index", right_on= "Area", how="left")
print(X_processed.shape)
# Out:
# (179, 12)
# (179, 15)

# %%
X_processed.head()
# Out:
#                  index  Domestic supply quantity  Export Quantity      Feed  \
# 0          Afghanistan                  0.473059         0.030256  0.013538
# 1              Albania                  1.720310         0.061099  0.251368
# 2              Algeria                  1.083749         0.016242  0.128028
# 3               Angola                  0.916322         0.003363  0.070775
# 4  Antigua and Barbuda                  0.910336         0.000927  0.000206
#
#        Food  Import Quantity    Losses  Other uses (non-food)  Processing  \
# 0  0.388100         0.132460  0.036144               0.000973    0.025104
# 1  1.199930         0.333713  0.122878               0.046513    0.081224
# 2  0.776383         0.387711  0.094767               0.048778    0.025759
# 3  0.624465         0.116097  0.103188               0.005247    0.103251
# 4  0.600198         0.734364  0.000000               0.021623    0.000000
#
#    Production  Residuals      Seed  cluster                 Area         Value
# 0    0.367990  -0.004311  0.013406        0          Afghanistan    469.919090
# 1    1.473385  -0.000694  0.017703        3              Albania   5303.197823
# 2    0.723615  -0.000070  0.010173        3              Algeria   3975.510381
# 3    0.790642   0.000000  0.009238        0               Angola   2670.850732
# 4    0.197492   0.020594  0.000000        0  Antigua and Barbuda  17112.821135

# %%
X_processed = X_processed.rename(columns={"Value": "PIB_Cap"})
X_processed.head()
# Out:
#                  index  Domestic supply quantity  Export Quantity      Feed  \
# 0          Afghanistan                  0.473059         0.030256  0.013538
# 1              Albania                  1.720310         0.061099  0.251368
# 2              Algeria                  1.083749         0.016242  0.128028
# 3               Angola                  0.916322         0.003363  0.070775
# 4  Antigua and Barbuda                  0.910336         0.000927  0.000206
#
#        Food  Import Quantity    Losses  Other uses (non-food)  Processing  \
# 0  0.388100         0.132460  0.036144               0.000973    0.025104
# 1  1.199930         0.333713  0.122878               0.046513    0.081224
# 2  0.776383         0.387711  0.094767               0.048778    0.025759
# 3  0.624465         0.116097  0.103188               0.005247    0.103251
# 4  0.600198         0.734364  0.000000               0.021623    0.000000
#
#    Production  Residuals      Seed  cluster                 Area       PIB_Cap
# 0    0.367990  -0.004311  0.013406        0          Afghanistan    469.919090
# 1    1.473385  -0.000694  0.017703        3              Albania   5303.197823
# 2    0.723615  -0.000070  0.010173        3              Algeria   3975.510381
# 3    0.790642   0.000000  0.009238        0               Angola   2670.850732
# 4    0.197492   0.020594  0.000000        0  Antigua and Barbuda  17112.821135

# %%
X_processed.isnull().sum()
# Out:
# index                       0
# Domestic supply quantity    0
# Export Quantity             0
# Feed                        0
# Food                        0
# Import Quantity             0
# Losses                      0
# Other uses (non-food)       0
# Processing                  0
# Production                  0
# Residuals                   0
# Seed                        0
# cluster                     0
# Area                        1
# PIB_Cap                     1
# dtype: int64

# %%
X_processed.dropna(inplace=True)

# %%
X_processed.shape
# Out:
# (178, 15)

# %%
plt.figure(figsize=(15,5))
sns.boxenplot(
    data = X_processed, 
    x = 'cluster',
    y = "PIB_Cap"
)

# %%
X_processed[["index","cluster"]].rename(columns={"index": "Area"}).to_csv("Cluster_Paises_Produccion_Imp_Exp.csv")

# %%
X_processed.head(1)
# Out:
#          index  Domestic supply quantity  Export Quantity      Feed    Food  \
# 0  Afghanistan                  0.473059         0.030256  0.013538  0.3881
#
#    Import Quantity    Losses  Other uses (non-food)  Processing  Production  \
# 0          0.13246  0.036144               0.000973    0.025104     0.36799
#
#    Residuals      Seed  cluster         Area    PIB_Cap
# 0  -0.004311  0.013406        0  Afghanistan  469.91909

# %%
a = df_alim[["Area Code", "Area"]].drop_duplicates()
print(a.shape)
a = pd.merge(a,df_paises_Kyoto, on="Area Code", how="left")
print(a.shape)

# %%
df_paises_Kyoto.head()
# Out:
# Country Group  Area Code         Country  Annex I countries
# 0                      1         Armenia                0.0
# 1                      2     Afghanistan                0.0
# 2                      3         Albania                0.0
# 3                      4         Algeria                0.0
# 4                      5  American Samoa                1.0

# %%
a.head(5)
# Out:
#    Area Code                 Area              Country  Annex I countries
# 0          2          Afghanistan          Afghanistan                0.0
# 1          3              Albania              Albania                0.0
# 2          4              Algeria              Algeria                0.0
# 3          7               Angola               Angola                0.0
# 4          8  Antigua and Barbuda  Antigua and Barbuda                0.0

# %%
# hacemos merge con la información del Anexo I

print(X_processed.shape)
X_processed = pd.merge(X_processed, a, left_on="index", right_on= "Area", how="left")
print(X_processed.shape)
# Out:
# (178, 15)
# (178, 19)

# %%
X_processed.head(1)
# Out:
#          index  Domestic supply quantity  Export Quantity      Feed    Food  \
# 0  Afghanistan                  0.473059         0.030256  0.013538  0.3881
#
#    Import Quantity    Losses  Other uses (non-food)  Processing  Production  \
# 0          0.13246  0.036144               0.000973    0.025104     0.36799
#
#    Residuals      Seed  cluster       Area_x    PIB_Cap  Area Code  \
# 0  -0.004311  0.013406        0  Afghanistan  469.91909          2
#
#         Area_y      Country  Annex I countries
# 0  Afghanistan  Afghanistan                0.0

# %%
X_processed.drop(["Area_y","Country"], axis="columns", inplace = True)
X_processed.head(1)
# Out:
#          index  Domestic supply quantity  Export Quantity      Feed    Food  \
# 0  Afghanistan                  0.473059         0.030256  0.013538  0.3881
#
#    Import Quantity    Losses  Other uses (non-food)  Processing  Production  \
# 0          0.13246  0.036144               0.000973    0.025104     0.36799
#
#    Residuals      Seed  cluster       Area_x    PIB_Cap  Area Code  \
# 0  -0.004311  0.013406        0  Afghanistan  469.91909          2
#
#    Annex I countries
# 0                0.0

# %%
plot = pd.crosstab(index=X_processed['cluster'], columns=X_processed['Annex I countries']).apply(lambda r: r/r.sum() *100,
                                              axis=1).plot(kind='bar')

# %% [markdown]
# Aquí parece que hay algo más de información! Hemos conseguido dividir los paises del Anexo 1 mendiante lo que importan, producen y exportan per cápita.

# %% [markdown]
# # Continuamos ahora con las emisiones por proceso?... lo que pasa que no sé si tendríamos que hacer por cápita o por kilo de alimento procesado, para ver cuan repectuoso es
#
# # También podríamos probar la producción del país o importación y exportacion. Con estas tres variables podríamos intentar un cluster

# %% [markdown]
# INACABADO.....
#
# Cojo el pickle con la información de Import_Export por país y continentes.

# %%
unpickled_df = pd.read_pickle("/content/drive/MyDrive/Formació/MASTER NUCLIO/Capstone Project/datasets/df_Import_Export_Continentes.pkl")

# %%
unpickled_df.shape
# Out:
# (8622, 9)

# %%
unpickled_df.head()
# Out:
# Grupo de países  Reporter Country Code Reporter Countries  Year Code  \
# 0                                    2        Afghanistan       2009
# 1                                    2        Afghanistan       2010
# 2                                    2        Afghanistan       2011
# 3                                    2        Afghanistan       2014
# 4                                    2        Afghanistan       2015
#
# Grupo de países  Américas       Asia    Europa  Oceanía   África  \
# 0                 42795.0  1249016.0  129430.0    151.0   3324.0
# 1                 89333.0  1117140.0   29063.0    757.0  13314.0
# 2                 63995.0  1150962.0   14128.0    816.0  31800.0
# 3                 65068.0  3345901.0   49020.0    176.0     76.0
# 4                 66864.0  4935864.0   51525.0    222.0     59.0
#
# Grupo de países          Element
# 0                Import Quantity
# 1                Import Quantity
# 2                Import Quantity
# 3                Import Quantity
# 4                Import Quantity

# %%
unpickled_df.Element.unique()
# Out:
# array(['Import Quantity', 'Export Quantity'], dtype=object)
